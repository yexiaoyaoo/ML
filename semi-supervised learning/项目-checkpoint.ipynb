# %%
import pandas as pd
import jieba
import jieba.posseg as pseg
import re
from snownlp import SnowNLP

path = r"‪评论数据.csv"
#文件路径有一个不可见的字符\u202a，这个字符是一个控制字符，用来表示从左到右的文本方向。
#但是这个字符会导致文件路径无效，所以你需要去掉它。你可以手动输入文件路径，或者使用replace方法去掉\u202a

# 去掉\u202a
path = path.replace("\u202a", "")

# 读取csv文件
data = pd.read_csv(path,encoding="ANSI")

# 显示前五行
data.head()
# Out:
#    序号                                                 评论
# 0   1  飞卢小说的更新速度相当快，实时更新，是一款相当方便的电子书阅读器。界面构造简约而不简单，非常...
# 1   2                      很好，有多种功能，而且界面好看不单调用着不错，你值得拥有。
# 2   3  为什么打不开了？更新完后打开就黑屏！后台根本没问题！软件打不开界面！昨天从新下载能用！今天又...
# 3   4                        一款相当不错的手游软件，界面漂亮，使用方便，值得拥有！
# 4   5                 新版本终于不再闪退了，界面优化的也好了很多，于是更想购物了，OMG！

# %%
# 定义一个函数，读取文件内容，并返回一个列表，每个元素为一个字典，包含各个字段
def load_file(filename):
    lst = []
    with open(filename, 'r', encoding='utf-8') as f:
        for line in f:
            dic = {}
            fields = line.strip().split(',')
            dic['words'] = fields[0].split('+')
            dic['speeches'] = fields[1].split('+')
            dic['weights'] = [float(w) for w in fields[2].split('+')]
            dic['distance'] = int(fields[3])
            dic['feedback'] = fields[4]
            lst.append(dic)
    return lst

# %%
#选取评论对象和评论观点的规则
obj_rules = [
    ('([\u4e00-\u9fa5]+\/r\/[\u4e00-\u9fa5]+\/n\/[\u4e00-\u9fa5]+\/n\/)', 1),
    ('([\u4e00-\u9fa5]+\/n\/[\u4e00-\u9fa5]+\/n\/[\u4e00-\u9fa5]+\/n\/)', 2),
    ('([\u4e00-\u9fa5]+\/r\/[\u4e00-\u9fa5]+\/n\/)', 3),
    ('([\u4e00-\u9fa5]+\/n\/[\u4e00-\u9fa5]+\/n\/)', 4),
    ('([\u4e00-\u9fa5]+\/v\/[\u4e00-\u9fa5]+\/(v|vd|vn)\/[\u4e00-\u9fa5]+\/n\/)', 5),
    ('([\u4e00-\u9fa5]+\/n\/[\u4e00-\u9fa5]+\/(v|vd|vn)\/)', 6),
    ('([\u4e00-\u9fa5]+\/n\/[\u4e00-\u9fa5]+\/(a|ad)\/)', 7),
    ('([\u4e00-\u9fa5]+\/(a|ad)\/[\u4e00-\u9fa5]+\/n\/)', 8),
    ('([\u4e00-\u9fa5]+\/n\/)', 9),
    ('([\u4e00-\u9fa5]+\/(v|vd|vn)\/)', 10)
]
opinion_rules = [
    ('([\u4e00-\u9fa5]+\/(a|ad)\/[\u4e00-\u9fa5]+\/(a|ad)\/)', 1),
    ('([\u4e00-\u9fa5]+\/d\/[\u4e00-\u9fa5]+\/(a|ad)\/)', 2),  
    ('([\u4e00-\u9fa5]+\/(n)\/[\u4e00-\u9fa5]+\/(a|ad)\/)', 3),  
    ('([\u4e00-\u9fa5]+\/(a|ad)\/[\u4e00-\u9fa5]+\/n\/)', 4),  
    ('([\u4e00-\u9fa5]+\/d\/[\u4e00-\u9fa5]+\/v\/[\u4e00-\u9fa5]+\/d\/[\u4e00-\u9fa5]+\/n\/)', 5),  
    ('([\u4e00-\u9fa5]+\/d\/[\u4e00-\u9fa5]+\/v\/[\u4e00-\u9fa5]+\/d\/[\u4e00-\u9fa5]+\/v\/)', 6),  
    ('([\u4e00-\u9fa5]+\/d\/[\u4e00-\u9fa5]+\/v\/)', 7),
    ('([\u4e00-\u9fa5]+\/d\/)', 8),
    ('([\u4e00-\u9fa5]+\/(a|ad)\/)', 9),
    ('([\u4e00-\u9fa5]+\/(v|vd)\/)', 10),
]

# %%
#对评论计算得出其评论对象与评论观点
def extract_obj_opinion(comment):
    # 对评论进行分词和标注，得到一个列表，每个元素是一个(word, flag)对
    words = pseg.lcut(comment)

    # 初始化评价对象和评价观点为空字符串
    obj = ""
    opinion = ""

    # 初始化评价对象和评价观点的优先级为最低值11（表中最高为10）
    obj_priority = 11
    opinion_priority = 11

    # 遍历每个(word, flag)对，拼接成一个字符串，用"/"分隔每个对，方便匹配规则
    word_flag_str = "/".join([word + "/" + flag for word, flag in words])+'/'

    # 遍历评价对象抽取规则，按优先级从高到低排序
    for rule, priority in sorted(obj_rules, key=lambda x: x[1]):
        # 如果当前规则的优先级高于已抽取的评价对象的优先级，则尝试匹配该规则
        if priority < obj_priority:
            # 尝试在word_flag_str中匹配该规则，返回一个match对象或None
            match = re.findall(rule, word_flag_str)
            # 如果匹配成功，则更新评价对象和优先级，只取第一个匹配的结果
            if match:
                obj = match
                obj_priority = priority
                print(f"评论对象为：{obj},{priority}")
                break  # 跳出循环，不再匹配其他规则

    # 遍历评价观点抽取规则，按优先级从高到低排序
    for rule, priority in sorted(opinion_rules, key=lambda x: x[1]):
        # 如果当前规则的优先级高于已抽取的评价观点的优先级，则尝试匹配该规则
        if priority < opinion_priority:
            # 尝试在word_flag_str中匹配该规则，返回一个match对象或None
            match = re.findall(rule, word_flag_str)
            # 如果匹配成功，则更新评价观点和优先级，只取第一个匹配的结果
            if match:
                opinion = match
                opinion_priority = priority
                print(f"评价观点为{opinion},{priority}")
                break  # 跳出循环，不再匹配其他规则

    # 如果评价对象或评价观点为空字符串，则表示没有找到匹配的规则，返回None
    if not obj or not opinion:
        #print("miss")
        return None

# %%
# 定义一个函数，计算用户评论与评论种子之间的综合匹配值，返回一个字典，键为使用反馈类型，值为综合匹配值
def match_score(text):
    # 对用户评论进行分词和词性标注
    seg_list = pseg.lcut(text)
    # 初始化结果字典
    result = {}
    # 遍历每个评论种子
    for seed in comment_seed:
        # 初始化词匹配值和词性匹配值
        word_match = 0
        speech_match = 0
        # 初始化匹配成功的词或词性的位置列表
        pos_word = []
        pos_speech = []
        # 初始化当前遍历的索引值和上一次匹配成功的索引值
        index = 0
        last_index = 0
        # 遍历每个词语和其词性
        for word, flag in seg_list:
            # 如果词语在评论种子中，说明是词匹配
            if word in seed['words']:
                # 更新词匹配值
                word_match += seed['weights'][seed['words'].index(word)]
                # 更新位置列表
                pos_word.append(index)
                # 更新上一次匹配成功的索引值
                last_index = index
            # 如果词性在评论种子中，说明是词性匹配
            if flag in seed['speeches']:
                # 获取当前遍历的索引值与上一次匹配成功的索引值之间的差值
                diff = index - last_index
                # 如果差值小于评论种子中的词性个数，且与评论种子中相同位置的词性相同，更新词性匹配值和位置列表
                if diff < len(seed['speeches']) and flag == seed['speeches'][diff]:
                    speech_match += seed['weights'][diff]
                    pos_speech.append(index)
            # 更新当前遍历的索引值
            index += 1
        # 计算用户评论和评论种子匹配成功的词或词性之间的最大距离
        word_dis = max(pos_word) - min(pos_word) if pos_word else float('inf')
        speech_dis = max(pos_speech) - min(pos_speech) if pos_speech else float('inf')
        # 计算综合匹配值，如果最大距离超过评论种子的距离限制，则综合匹配值为0
        both_match = 0.5 * (word_match + speech_match) if word_dis <= seed['distance'] and speech_dis <= seed['distance'] else 0
        # 将综合匹配值存入结果字典，键为使用反馈类型
        result[seed['feedback']] = both_match
    # 返回结果字典
    return result

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   序号      500 non-null    int64
#  1   评论      500 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 7.9+ KB

# %%
data['评论']
# Out:
# 0      飞卢小说的更新速度相当快，实时更新，是一款相当方便的电子书阅读器。界面构造简约而不简单，非常...
# 1                          很好，有多种功能，而且界面好看不单调用着不错，你值得拥有。
# 2      为什么打不开了？更新完后打开就黑屏！后台根本没问题！软件打不开界面！昨天从新下载能用！今天又...
# 3                            一款相当不错的手游软件，界面漂亮，使用方便，值得拥有！
# 4                     新版本终于不再闪退了，界面优化的也好了很多，于是更想购物了，OMG！
#                              ...
# 495                           每次出行都能在以前收藏的记录里找到地址直接导航很方便
# 496                              有没有人和我一样微信漂流瓶扔出去无法收到回复。
# 497                                 没见过这么垃圾的软件，这么多广告直接无语
# 498                          按自己需求设置快捷功能，更贴合个人使用习惯。感谢百度~
# 499                                    为什么我现在更新之后图片一直看不见
# Name: 评论, Length: 500, dtype: object

# %%
for comment in data['评论']:
    print(comment)
    extract_obj_opinion(comment)
    print('\n')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\28294\AppData\Local\Temp\jieba.cache
# 飞卢小说的更新速度相当快，实时更新，是一款相当方便的电子书阅读器。界面构造简约而不简单，非常适合读者，是一款便利的读书软件和看书软件
# Loading model cost 0.613 seconds.
# Prefix dict has been built successfully.
# 评论对象为：['电子书/n/阅读器/n/', '读书/n/软件/n/'],4
# 评价观点为[('相当/d/快/a/', 'a'), ('相当/d/方便/a/', 'a'), ('不/d/简单/a/', 'a')],2
#
#
# 很好，有多种功能，而且界面好看不单调用着不错，你值得拥有。
# 评论对象为：[('界面/n/好看/v/', 'v')],6
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 为什么打不开了？更新完后打开就黑屏！后台根本没问题！软件打不开界面！昨天从新下载能用！今天又打不开了？什么鬼？倒闭了？
# 评论对象为：['什么/r/鬼/n/'],3
# 评价观点为[('后台/n/根本/a/', 'n', 'a')],3
#
#
# 一款相当不错的手游软件，界面漂亮，使用方便，值得拥有！
# 评论对象为：['手游/n/软件/n/'],4
# 评价观点为[('相当/d/不错/a/', 'a')],2
#
#
# 新版本终于不再闪退了，界面优化的也好了很多，于是更想购物了，OMG！
# 评论对象为：[('界面/n/优化/vn/', 'vn')],6
# 评价观点为[('新/a/版本/n/', 'a')],4
#
#
# 翻译准确，内容丰富。
# 评论对象为：[('内容/n/丰富/a/', 'a')],7
# 评价观点为[('内容/n/丰富/a/', 'n', 'a')],3
#
#
# 好看的贴纸太少
# 评论对象为：[('好看/v/', 'v'), ('贴纸/v/', 'v')],10
# 评价观点为[('太/d/少/a/', 'a')],2
#
#
# 一般般吧，可是没银行卡怎么抢红包????
# 评论对象为：[('没/v/', 'v')],10
# 评价观点为[('没/v/', 'v')],10
#
#
# 地图包含了各种交通形式，只是步行用的最多，各种交互和使用习惯了之后都很方便。
# 评论对象为：['各种/r/交通/n/形式/n/'],1
# 评价观点为[('很/d/方便/a/', 'a')],2
#
#
# 非常不错不错的东西，找了不错不错久了 支持支持！！很好 功能实用！！界面简洁！！速度很快。挺很好得
# 评论对象为：[('功能/n/实用/v/', 'v')],6
# 评价观点为[('不错/a/不错/a/', 'a', 'a'), ('不错/a/不错/a/', 'a', 'a')],1
#
#
# 还是喜欢用老版本的，1.85包括以前的版本用得都很顺手，后来出的要么很卡，要么界面不顺手。我觉得还不如不出新的，越出越差。我还是钟爱老的版本啊。坚决不下新版本
# 评论对象为：['老/n/版本/n/'],4
# 评价观点为[('越/d/差/a/', 'a')],2
#
#
# 非常实用，不会的单词可以搜
# 评论对象为：['单词/n/'],9
# 评价观点为['非常/d/实用/v/'],7
#
#
# 用是好用，可以给个好评！问题是广告太多了，真心受不了！！夜间模式也没了
# 评论对象为：[('问题/n/是/v/', 'v')],6
# 评价观点为['也/d/没了/v/'],7
#
#
# 发现有两个毛病，一个是别人把头像改了别人看不出来，还有一个是发签名出现错误
# 评论对象为：[('签名/v/出现/v/错误/n/', 'v')],5
# 评价观点为[('发现/v/', 'v'), ('有/v/', 'v'), ('是/v/', 'v'), ('改/v/', 'v'), ('看不出来/v/', 'v'), ('还有/v/', 'v'), ('是/v/', 'v'), ('发/v/', 'v'), ('签名/v/', 'v'), ('出现/v/', 'v')],10
#
#
# 界面简单明快，所以用起来才更加的舒服安逸，用户基数很大，已经找到了好几个发展对象了
# 评论对象为：['用户/n/基数/n/'],4
# 评价观点为[('简单/a/明快/a/', 'a', 'a')],1
#
#
# 界面看起来很好看舒服好看，就是看界面有种很熟悉的感觉，团队很强大，希望平台越来越好。
# 评论对象为：[('界面/n/看起来/v/', 'v')],6
# 评价观点为[('越来越/d/好/a/', 'a')],2
#
#
# 怎么资料里面不显示关注的兴趣部落了？
# 评论对象为：['怎么/r/资料/n/'],3
# 评价观点为['不/d/显示/v/'],7
#
#
# 更新了，没有以前的照相好看了，怎么回事
# 评论对象为：[('没有/v/', 'v'), ('好看/v/', 'v')],10
# 评价观点为['照相/d/好看/v/'],7
#
#
# 真的超级无敌的拼多多是不错的团购软件，经常在软件上拼团购水果，价格实惠，品质好，不错好实惠。来吧来吧
# 评论对象为：[('拼/v/团购/v/水果/n/', 'v')],5
# 评价观点为[('不错/a/好/a/', 'a', 'a')],1
#
#
# 这个很棒赞一个。来啊。 功能实用！界面简洁！速度很快。挺好的 我刚从市场上看到这个，很不错。
# 评论对象为：[('功能/n/实用/v/', 'v')],6
# 评价观点为[('挺/d/好/a/', 'a')],2
#
#
# 特别好用的在线直播软件，界面设计简洁，在线播放流畅，感觉是目前最好用的软件之一！
# 评论对象为：[('感觉/n/是/v/', 'v')],6
# 评价观点为[('界面设计/n/简洁/a/', 'n', 'a')],3
#
#
# 蛮有用的 周边信息都能找到
# 评论对象为：['信息/n/'],9
# 评价观点为['蛮/d/有用/v/', '都/d/能/v/'],7
#
#
# 金山很好用，英语老师推荐所以才会下载的，内容全面，我最喜欢的板块是听力部分，不仅有VOA，还有四六级真题，所以第一次评论APP，真的值得一试！
# 评论对象为：['内容/n/全面/n/', '听力/n/部分/n/'],4
# 评价观点为['才/d/会/v/', '最/d/喜欢/v/', '真的/d/值得/v/'],7
#
#
# 以前可以换昵称，搞得现在昵称都不能换，我本以为QQ号好的可现在垃圾
# 评论对象为：[('号/n/好/a/', 'a')],7
# 评价观点为[('号/n/好/a/', 'n', 'a')],3
#
#
# 修改个头像都换不了，
# 评论对象为：[('个头/n/像/v/', 'v')],6
# 评价观点为['都/d/换/v/'],7
#
#
# 好是好了点，就是还有个地方要改进。要是能把话框改成有趣的像QQ那样的气泡就好了，而且还要免费的！
# 评论对象为：['话/n/框/n/'],4
# 评价观点为[('就/d/好/a/', 'a')],2
#
#
# 很喜欢汤唯小姐姐的声音，期待他的语音包哦！
# 评论对象为：[('语音/n/包哦/v/', 'v')],6
# 评价观点为[('喜欢/v/', 'v'), ('期待/v/', 'v'), ('包哦/v/', 'v')],10
#
#
# 详尽的公交路线查询乘车很方便，即使换乘也不用担心找不到站台，准确率高，不错加油
# 评论对象为：[('找/v/不到/v/站台/n/', 'v')],5
# 评价观点为[('准确率/n/高/a/', 'n', 'a')],3
#
#
# 好，但界面没有任意页面可选
# 评论对象为：[('没有/v/任意/v/页面/n/', 'v')],5
# 评价观点为[('好/a/', 'a')],9
#
#
# 老是强制出现连权限禁了都可以弹出来可以啊
# 评论对象为：[('权限/n/禁/v/', 'v')],6
# 评价观点为['都/d/'],8
#
#
# 为什么显示完拇指玩界面就黑屏
# 评论对象为：[('显示/v/完/v/拇指/n/', 'v')],5
# 评价观点为['就/d/'],8
#
#
# 很不错，兼容格式多，界面朴实实用，操作简单！！
# 评论对象为：[('界面/n/朴实/a/', 'a')],7
# 评价观点为[('界面/n/朴实/a/', 'n', 'a')],3
#
#
# 界面简洁美观，智能分类很强大，占用内存小，很不错一款软件，推荐！！
# 评论对象为：['智能/n/分类/n/'],4
# 评价观点为[('界面/n/简洁/a/', 'n', 'a'), ('内存/n/小/a/', 'n', 'a')],3
#
#
# 特别好，贴纸很多很多，能瘦脸，能大眼，女生拍照必备！！
# 评论对象为：[('女生/n/拍照/v/', 'v')],6
# 评价观点为[('特别/d/好/a/', 'a')],2
#
#
# 好评呀，很喜欢界面设计，简洁大方，继续加油，实用
# 评论对象为：[('简洁/a/大方/n/', 'a')],8
# 评价观点为[('简洁/a/大方/n/', 'a')],4
#
#
# 界面很不错。用的很不错。看着也很顺眼！ 我觉得应该有个抓娃娃排行榜，膜拜一下大神.....
# 评论对象为：['娃娃/n/排行榜/n/'],4
# 评价观点为[('很/a/不错/a/', 'a', 'a')],1
#
#
# 更新后，收付款打不开扫描码，想找客服都不知道在哪找。。。
# 评论对象为：[('打不开/v/扫描/v/码/n/', 'v'), ('想/v/找/v/客服/n/', 'v')],5
# 评价观点为['不/d/知道/v/'],7
#
#
# 为什么版本这么低，好多贴纸都没有
# 评论对象为：['为什么/r/版本/n/'],3
# 评价观点为['都/d/没有/v/'],7
#
#
# 好用，就是界面一般。
# 评论对象为：[('界面/n/一般/a/', 'a')],7
# 评价观点为[('界面/n/一般/a/', 'n', 'a')],3
#
#
# 自从下了这个软件！！每天就不错像看微信一样时不时的就会打开看看！！ 界面清爽。功能也很好 还很好。比上个版本好好。该去的东西一个不剩。该留的一个不少
# 评论对象为：['这个/r/软件/n/'],3
# 评价观点为[('就/d/不错/a/', 'a'), ('很/d/好/a/', 'a'), ('很/d/好/a/', 'a')],2
#
#
# 那个推荐好友真的很烦，每天几回去。可以调也好啊。
# 评论对象为：['好友/n/'],9
# 评价观点为[('真的/d/很烦/a/', 'a')],2
#
#
# 无论叫车还是开车都离不了他。
# 评论对象为：['车/n/'],9
# 评价观点为['都/d/离不了/v/'],7
#
#
# 现在无意间就看看，已经成为一种习惯. 直播可以在线互动.
# 评论对象为：['习惯/n/'],9
# 评价观点为['就/d/看看/v/', '已经/d/成为/v/'],7
#
#
# 卡在拇指玩界面怎么破
# 评论对象为：[('拇指/n/玩/v/', 'v')],6
# 评价观点为[('玩/v/', 'v'), ('破/v/', 'v')],10
#
#
# 应用操作简单，界面给力超好用一款非常好用的应用
# 评论对象为：[('力/n/超好/v/', 'v')],6
# 评价观点为['非常/d/好用/v/'],7
#
#
#  挺喜欢的，界面挺精美的，精彩的书需要懂它的人才有价值，所以喜欢看书的人都可以进来看看吧。
# 评论对象为：[('书/n/需要/v/', 'v'), ('人才/n/有/v/', 'v')],6
# 评价观点为[('挺/d/精美/a/', 'a')],2
#
#
# 不能忍，为什么一定要新手机登陆要旧手机验证，我呸，万一那旧手机坏了呢？里面的钱就拿不出来了啊。你是不是有毛病哦。你有短信验证还不行？你说你到底要怎样啊你一天天的这么作。一点也不考虑感受，提现还收钱。
# 评论对象为：[('手机/n/验证/v/', 'v'), ('短信/n/验证/v/', 'v')],6
# 评价观点为[('手机/n/坏/a/', 'n', 'a')],3
#
#
# 看新闻，选浙江新闻界面很不错，用的很不错，看着也很顺眼。
# 评论对象为：['新闻界/n/面/n/'],4
# 评价观点为[('很/a/不错/a/', 'a', 'a')],1
#
#
# 垃圾，qq登录登不上
# 评论对象为：['垃圾/n/'],9
# 评价观点为[('登录/v/', 'v')],10
#
#
# 界面简洁实用
# 评论对象为：[('界面/n/简洁/a/', 'a')],7
# 评价观点为[('界面/n/简洁/a/', 'n', 'a')],3
#
#
# 背景音乐特别好听玩起来也很有感觉你值得拥有
# 评论对象为：['背景音乐/n/', '感觉/n/'],9
# 评价观点为['特别/d/好听/v/', '很/d/有/v/'],7
#
#
# 现在要银行卡才能用钱，什么鬼啊，垃圾软件
# 评论对象为：['什么/r/鬼/n/'],3
# 评价观点为[('要/v/', 'v'), ('才能/v/', 'v'), ('用钱/v/', 'v')],10
#
#
# 新版小程序表情包发不了，越更新越烂
# 评论对象为：['程序/n/表情/n/'],4
# 评价观点为[('小/a/程序/n/', 'a')],4
#
#
# 很实用，很好，我就选它了呵呵，你们也要好样噢，很好真得很好，而且很好好，阅读起来很方便
# 评论对象为：[('实用/v/', 'v'), ('选/v/', 'v'), ('呵呵/v/', 'v'), ('要/v/', 'v'), ('阅读/v/', 'v'), ('起来/v/', 'v')],10
# 评价观点为[('很/d/好/a/', 'a'), ('很/d/好/a/', 'a')],2
#
#
# 为什么不能修改昵称？
# 评论对象为：[('不能/v/修改/v/昵称/n/', 'v')],5
# 评价观点为[('不能/v/', 'v'), ('修改/v/', 'v')],10
#
#
# 小说很多，广告也可以关闭，还能用阅读时长兑换现金。挺好的。
# 评论对象为：[('时/n/长/a/', 'a')],7
# 评价观点为[('挺/d/好/a/', 'a')],2
#
#
# 这个软件还是非常赞的，在学习上帮了不少忙，词和句的翻译都特别准确，很赞哦，五颗星好评?
# 评论对象为：['这个/r/软件/n/'],3
# 评价观点为[('特别/d/准确/a/', 'a')],2
#
#
# 很好，多一颗怕你骄傲，对了，把红包密码忘了
# 评论对象为：['红包/n/密码/n/'],4
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 一直都在使用这款小黑鱼软件，出门旅游可以用他提前预定酒店，使用方便快速简单，很适合各位经常出差的人使用赞
# 评论对象为：['这款/r/小/n/黑鱼/n/'],1
# 评价观点为[('快速/d/简单/a/', 'a')],2
#
#
# 为什么腾讯视频没有动漫那个分类了？
# 评论对象为：['那个/r/分类/n/'],3
# 评价观点为[('没有/v/', 'v')],10
#
#
# 超级赞哦！方便又不错！ 很方便，qq号直接登陆，很多看电视剧都能找到！~~~~
# 评论对象为：['电视剧/n/'],9
# 评价观点为[('又/d/不错/a/', 'a')],2
#
#
# 很不错，好玩，可以用语音
# 评论对象为：['语音/n/'],9
# 评价观点为[('不错/a/', 'a')],9
#
#
# 拼多多，是个最大的坑！一进界面，各种套路就开始搞你！最讨厌的一款软件！没有之一！！！
# 评论对象为：['各种/r/套路/n/'],3
# 评价观点为['就/d/开始/v/', '最/d/讨厌/v/'],7
#
#
# 界面不错，用起来很方便
# 评论对象为：[('界面/n/不错/a/', 'a')],7
# 评价观点为[('界面/n/不错/a/', 'n', 'a')],3
#
#
# 新手机上得第一个应用软件好玩好。 很好得应用！！建议大家下载！！ 常喜欢这个界面。感觉看起来特别得舒心。太棒了！！
# 评论对象为：['这个/r/界面/n/'],3
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 非常好用，拍出来特别有美感
# 评论对象为：[('拍/v/', 'v'), ('出来/v/', 'v'), ('有/v/', 'v')],10
# 评价观点为[('非常/d/好/a/', 'a')],2
#
#
# 像我们这种没绑定银行卡的封号后无法登陆自己的微信
# 评论对象为：[('无法/n/登陆/v/', 'v')],6
# 评价观点为[('像/v/', 'v'), ('没/v/', 'v'), ('绑定/v/', 'v'), ('登陆/v/', 'v')],10
#
#
# 对于喜欢干净的，简单的界面的孩子来说是个不错的选择！.
# 评论对象为：['界面/n/', '孩子/n/'],9
# 评价观点为[('干净/a/', 'a'), ('简单/a/', 'a'), ('不错/a/', 'a')],9
#
#
# 昨晚手机被恶意软件侵袭一直在安装软件的信息 在百度上查是怎么回事 它说可能手机有病毒了 后来下载360急救箱 病毒都没了 赞赞赞
# 评论对象为：[('说/v/可能/v/手机/n/', 'v')],5
# 评价观点为['都/d/没了/v/'],7
#
#
# 一进去就要vlp广告又长，坑钱啊
# 评论对象为：['坑/n/钱/n/'],4
# 评价观点为[('又/d/长/a/', 'a')],2
#
#
# 同事推荐的。我用过以后的确不错。阅读界面简单流畅。哈哈
# 评论对象为：[('同事/n/推荐/v/', 'v')],6
# 评价观点为[('简单/a/流畅/a/', 'a', 'a')],1
#
#
# 垃圾，本机不在身边就登不上去
# 评论对象为：['垃圾/n/', '本机/n/'],9
# 评价观点为['就/d/登不/v/'],7
#
#
# 真的特别好照片很漂亮
# 评论对象为：['照片/n/很漂亮/n/'],4
# 评价观点为[('特别/d/好/a/', 'a')],2
#
#
# 这个微信是很垃圾的，，登陆麻烦，，废话多。你知道你的密码和账号了，还要验证
# 评论对象为：['这个/r/微信/n/'],3
# 评价观点为['很/d/'],8
#
#
# 苹果都出6.6可以改微信号了，安卓为啥还不能？快更新可以改号
# 评论对象为：['苹果/n/', '信号/n/'],9
# 评价观点为['都/d/出/v/', '还/d/不能/v/'],7
#
#
# 活该好评和差评差不多，真的很无语对这个软件。动不动就闪退。几乎都要VIP！还很卡。追完双世宠妃就删????
# 评论对象为：['这个/r/软件/n/'],3
# 评价观点为['很/d/无/v/', '就/d/闪退/v/', '都/d/要/v/', '就/d/删/v/'],7
#
#
# 不如高德显示的信息全面了
# 评论对象为：['信息/n/全面/n/'],4
# 评价观点为[('显示/v/', 'v')],10
#
#
# 什么鬼，更新后怎么没有提示音了？我朋友给我发信息，都没有声音提示！！！
# 评论对象为：['我/r/朋友/n/给我发/n/'],1
# 评价观点为['都/d/没有/v/'],7
#
#
# 相比较而言，感觉比歪歪之类的好用，可以看到各种各样的视频直播
# 评论对象为：[('视频/n/直播/vn/', 'vn')],6
# 评价观点为[('相/v/', 'v'), ('好用/v/', 'v'), ('看到/v/', 'v')],10
#
#
# 好用，涂鸦笔线条太租了，能自主选择粗细就更好了。
# 评论对象为：['涂鸦/n/笔/n/线条/n/'],2
# 评价观点为['太/d/租/v/'],7
#
#
# 我喜欢这界面，够简洁，而且内容丰富
# 评论对象为：['这/r/界面/n/'],3
# 评价观点为[('内容/n/丰富/a/', 'n', 'a')],3
#
#
# 刚下载下，冲着这优质欢迎界面，觉得应该很值得信赖，我先使用几天试试看。
# 评论对象为：['这/r/优质/n/'],3
# 评价观点为['刚/d/下载/v/', '先/d/使用/v/'],7
#
#
# 玩的挺好就是最近手机系统更新之后游戏会在登陆360账号界面闪退，什么原因
# 评论对象为：['什么/r/原因/n/'],3
# 评价观点为['就是/d/', '更新/d/'],8
#
#
# 以后找不见路怎么办！就用百度地图随时随地查找公交车打滴，方便省事
# 评论对象为：['百度/n/地图/n/'],4
# 评价观点为[('方便/a/省事/n/', 'a')],4
#
#
# 界面设计的很漂亮，功能很强大，值得推荐！ 力顶
# 评论对象为：['界面设计/n/', '很漂亮/n/', '功能/n/', '力顶/n/'],9
# 评价观点为[('强大/a/', 'a')],9
#
#
# 初二开始用，到现在大二，还在用，虽然广告多了，好多书籍版权没有，但是现在也不怎么看男频类的了，用来看历史科普文学还是可以的
# 评论对象为：['书籍/n/版权/n/'],4
# 评价观点为['还/d/', '也/d/'],8
#
#
# 干嘛在朋友圈保存下来的照片和视频只能发给朋友，发不了朋友圈去呢？？？这是为什么？？？
# 评论对象为：[('只能/v/发给/vn/朋友/n/', 'vn'), ('发/v/不了/v/朋友圈/n/', 'v')],5
# 评价观点为[('保存/v/', 'v'), ('只能/v/', 'v'), ('发/v/', 'v'), ('不了/v/', 'v'), ('去/v/', 'v'), ('是/v/', 'v')],10
#
#
# 垃圾 没了vip下载视频速度特别慢就1两百 在其他软件2000多都上去了
# 评论对象为：['视频/n/速度/n/'],4
# 评价观点为[('特别/d/慢/a/', 'a')],2
#
#
# 更新到7.0连信息都发不出去了
# 评论对象为：['信息/n/'],9
# 评价观点为['更新/d/到/v/', '都/d/发不/v/'],7
#
#
# 后置拍完 有卡顿 然后变色.
# 评论对象为：[('后置/n/拍完/v/', 'v')],6
# 评价观点为[('拍完/v/', 'v'), ('有/v/', 'v')],10
#
#
# 太卡了，还不支持微信支付
# 评论对象为：[('支持/v/', 'v'), ('微信/vn/', 'vn'), ('支付/v/', 'v')],10
# 评价观点为['不/d/支持/v/'],7
#
#
# 非常好的直播应用，很多漂亮的妹子... 不错的平台，互动内容很多，有机会认识的漂亮的妹子帅哥也很多
# 评论对象为：[('机会/n/认识/v/', 'v')],6
# 评价观点为[('非常/d/好/a/', 'a')],2
#
#
# 整个界面都很清爽☆喜欢☆
# 评论对象为：['界面/n/'],9
# 评价观点为[('很/d/清爽/a/', 'a')],2
#
#
# 不错的看书软件。界面很舒服。流畅。
# 评论对象为：['软件/n/', '界面/n/'],9
# 评价观点为[('不错/a/', 'a'), ('舒服/a/', 'a'), ('流畅/a/', 'a')],9
#
#
# 很喜欢它的界面，很简洁，给人高大上的感觉！?
# 评论对象为：[('人/n/高大/a/', 'a')],7
# 评价观点为[('人/n/高大/a/', 'n', 'a')],3
#
#
# QQ运动连鼓励红包都领不到了
# 评论对象为：['红包/n/'],9
# 评价观点为['都/d/领/v/'],7
#
#
# 很不错。功能挺强大。很不错界面。值得推荐 这里的书越来越好看，内容越来越丰富多彩了
# 评论对象为：[('不错/a/界面/n/', 'a')],8
# 评价观点为[('挺/d/强大/a/', 'a')],2
#
#
# QQ真是太垃圾，不能修改资料，修改完不能保存
# 评论对象为：[('不能/v/修改/v/资料/n/', 'v')],5
# 评价观点为[('不能/v/', 'v'), ('修改/v/', 'v'), ('修改/v/', 'v'), ('完/v/', 'v'), ('不能/v/', 'v'), ('保存/v/', 'v')],10
#
#
# 特别垃圾的软件，拍照查单词就没有对过，再标准的英语字母都只能照出一堆乱码
# 评论对象为：[('拍照/v/查/v/单词/n/', 'v')],5
# 评价观点为['就/d/没有/v/', '都/d/只能/v/'],7
#
#
# 用过最好用的漫画软件了，界面简洁漫画好看
# 评论对象为：['漫画/n/软件/n/'],4
# 评价观点为[('界面/n/简洁/a/', 'n', 'a')],3
#
#
# 挺不错不错用得。很方便 很好人啦。 界面挺清新。很好很好！！
# 评论对象为：['好人/n/', '界面/n/'],9
# 评价观点为[('挺/d/清新/a/', 'a'), ('很好/d/很好/a/', 'a')],2
#
#
# 个性化的出行方案，蛮详细的啦！
# 评论对象为：['个性化/n/', '方案/n/'],9
# 评价观点为[('蛮/d/详细/ad/', 'ad')],2
#
#
# 界面很好。用的不错。看着也很顺眼！ 挺好的软件，帮助大家废物利用
# 评论对象为：['大家/n/废物利用/n/'],4
# 评价观点为[('很/d/好/a/', 'a'), ('挺/d/好/a/', 'a')],2
#
#
# 绿茶浏览器上网流畅，不卡顿，界面儿清新简洁，我非常喜欢
# 评论对象为：['绿茶/n/浏览器/n/', '界面/n/儿/n/'],4
# 评价观点为[('清新/a/简洁/a/', 'a', 'a')],1
#
#
# 小说也挺的我感觉这是我用过最用的读软件了不错，给个赞，明，很方便，而且全部免费，除了有部分小说章节漏掉之外，好吧，功能挺实用的.......
# 评论对象为：['部分/n/小说/n/章节/n/'],2
# 评价观点为['也/d/挺/v/', '挺/d/实用/v/'],7
#
#
# 垃圾，手机恢复出厂，或者清除数据，重新登陆，每次都要短信验证，还要好友验证，我的好友都在忙，我都不想联系他们，都已经有短信了还要用好友验证，真是很困难
# 评论对象为：[('手机/n/恢复/v/', 'v'), ('短信/n/验证/v/', 'v'), ('好友/n/验证/v/', 'v'), ('好友/n/验证/v/', 'v')],6
# 评价观点为['都/d/要/v/', '都/d/不想/v/', '已经/d/有/v/'],7
#
#
# 朋友推荐拼多多，说如何实惠，她们同学都在用这款软件购物，商品质量如何的不错。我现在也加入了。真实惠
# 评论对象为：['这款/r/软件/n/购物/n/'],1
# 评价观点为['也/d/加入/v/'],7
#
#
# 这个软件真的很烂。点击忘记密码，结果一直往登录界面跳转。害得我删了重新装。360有意刷下载量就把软件搞成这样，恶心
# 评论对象为：['这个/r/软件/n/'],3
# 评价观点为[('真的/d/很烂/a/', 'a')],2
#
#
# 低价购物买东西我都不看了哈哈真的很合算，懒人购物最高的助手，全正品服装海购，更有团购促销活动
# 评论对象为：['低价/n/购物/n/', '懒人/n/购物/n/'],4
# 评价观点为[('购物/n/最高/a/', 'n', 'a')],3
#
#
# 很少主动来评论，但是这个太不错太有用了！推荐大家下载使用～ 很好，有自己的产品特色，打开界面清新大方，可观赏性很强！赞~
# 评论对象为：['产品/n/特色/n/'],4
# 评价观点为[('太/d/不错/a/', 'a'), ('很/d/好/a/', 'a'), ('很/d/强/a/', 'a')],2
#
#
# 很不错的播放器，界面简洁，支持文件类型很多。
# 评论对象为：[('界面/n/简洁/a/', 'a')],7
# 评价观点为[('界面/n/简洁/a/', 'n', 'a')],3
#
#
# 我的微信也不知道什么原因，备注好友秒闪回原来的名字，好友取消置顶也秒闪回原来的位置。也不知道什么原因，反馈了好多次都没有回应。
# 评论对象为：['什么/r/原因/n/', '什么/r/原因/n/'],3
# 评价观点为['不/d/知道/v/', '不/d/知道/v/', '都/d/没有/v/'],7
#
#
# 软件现在是真的一点都不会用，我都后悔更新了，我觉得以前的比较好用，想找什么，什么都找的到，现在要找个东西，都要找好久都有可能找不到。
# 评论对象为：['软件/n/'],9
# 评价观点为[('比较/d/好/a/', 'a')],2
#
#
# 我就是冲着郭德纲来的，可惜就是在播放视频的时候画面和音频不同步。希望能够快点改进。
# 评论对象为：['时候/n/画面/n/'],4
# 评价观点为['快点/d/改进/v/'],7
#
#
# 会员影片太多，广告太长
# 评论对象为：['会员/n/影片/n/'],4
# 评价观点为[('太/d/长/a/', 'a')],2
#
#
# 非常好，尤其是私人电台。
# 评论对象为：['私人/n/电台/n/'],4
# 评价观点为[('非常/d/好/a/', 'a')],2
#
#
# 比较好用的一个 美颜贴纸都挺好
# 评论对象为：[('好用/v/', 'v'), ('贴纸/v/', 'v')],10
# 评价观点为[('挺/d/好/a/', 'a')],2
#
#
# 新手活动都点不了
# 评论对象为：[('新手/n/活动/vn/', 'vn')],6
# 评价观点为['都/d/'],8
#
#
# 翻译都很棒
# 评论对象为：[('翻译/v/', 'v')],10
# 评价观点为[('都/d/很棒/a/', 'a')],2
#
#
# 垃圾微信，改个支付密码麻烦死！密码输对了硬是通知错误！赶紧下架吧！
# 评论对象为：[('垃圾/n/微信/vn/', 'vn'), ('密码/n/输对/v/', 'v')],6
# 评价观点为['硬是/d/通知/v/'],7
#
#
# 嗯，翻译精准
# 评论对象为：['精准/n/'],9
# 评价观点为[('翻译/v/', 'v')],10
#
#
# 嗯这个应用好行，有些重要的事记录起
# 评论对象为：['事/n/记录/n/'],4
# 评价观点为[('好/a/行/n/', 'a')],4
#
#
# 现在不能改网名了，整个人都抑郁了
# 评论对象为：[('不能/v/改/v/网名/n/', 'v')],5
# 评价观点为[('都/d/抑郁/a/', 'a')],2
#
#
# 软件真得很不错，没想到还有这么不错不错得软件 原来得界面就很不错。改了干嘛？ 现在流行的软甲。赞一个
# 评论对象为：['软件/n/', '软件/n/', '界面/n/', '干嘛/n/', '软甲/n/'],9
# 评价观点为[('不错/a/不错/a/', 'a', 'a')],1
#
#
# 界面比以前好看很多
# 评论对象为：['界面/n/'],9
# 评价观点为[('好看/v/', 'v')],10
#
#
# 很好好得手机必备，太好样了，了还想 广告时间希望缩短 其他都还不错~~~~
# 评论对象为：['广告/n/时间/n/'],4
# 评价观点为[('还/d/不错/a/', 'a')],2
#
#
# 界面简单明了，多年使用，看盘很不错，让你轻松赚钱，确实方便。
# 评论对象为：['界面/n/'],9
# 评价观点为[('确实/ad/方便/a/', 'ad', 'a')],1
#
#
# 不能VR观看了？？？
# 评论对象为：[('不能/v/', 'v'), ('观看/v/', 'v')],10
# 评价观点为[('不能/v/', 'v'), ('观看/v/', 'v')],10
#
#
# 界面很清晰简单，不复杂，操作很也方便呢
# 评论对象为：['界面/n/'],9
# 评价观点为[('清晰/a/简单/a/', 'a', 'a')],1
#
#
# 使用特别方便。跟远在他乡的家人，时常可以面对面聊天儿。真的特别实用。
# 评论对象为：['家人/n/'],9
# 评价观点为[('特别/d/方便/a/', 'a')],2
#
#
# 小说app界面非常干净有序 可以找到很多想看的小说目录 而且还是 无广告 支持 这么好的app真的是太方便了
# 评论对象为：['小说/n/目录/n/'],4
# 评价观点为[('非常/d/干净/a/', 'a'), ('太/d/方便/a/', 'a')],2
#
#
# 界面很舒适，但是消息同步不及时，有时候群里发的信息半天看不到，望改进。
# 评论对象为：['界面/n/', '消息/n/', '信息/n/'],9
# 评价观点为['同步/d/', '不/d/'],8
#
#
# 看App Store时发现有这个夹娃娃应用，很好啊，原来夹娃娃可以在手机上这么玩，娃娃品种也是那么多，机器数量也是很多的，界面也是很给力，最近的特价抓娃娃专场也是不错的，抓娃娃还是很便宜啊。....
# 评论对象为：['这个/r/夹/n/娃娃/n/'],1
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 太棒了，女神节来了，拼多多购物平台各种给力，各种促销活动陆续上线
# 评论对象为：['购物/n/平台/n/'],4
# 评价观点为['陆续/d/'],8
#
#
# 其他都挺好的，不方便的就是不能微信支付，希望能有个微信支付
# 评论对象为：[('不能/v/', 'v'), ('微信/vn/', 'vn'), ('支付/v/', 'v'), ('希望/v/', 'v'), ('能/v/', 'v'), ('微信/vn/', 'vn'), ('支付/v/', 'v')],10
# 评价观点为[('都/d/挺好/a/', 'a'), ('不/d/方便/a/', 'a')],2
#
#
# 好用好用非常好用，哈哈，终于被我找到这么好用的软件了，软件页面简洁没有广告，界面简单易用一点都不复杂，CCTV手机电视cctv6的电影不少，看电影首选CCTV手机电视
# 评论对象为：['软件/n/页面/n/', '手机/n/电视/n/', '手机/n/电视/n/'],4
# 评价观点为[('非常/d/好/a/', 'a'), ('不/d/复杂/a/', 'a')],2
#
#
# 很不错，界面朴实实用，操作简单！！
# 评论对象为：[('界面/n/朴实/a/', 'a')],7
# 评价观点为[('界面/n/朴实/a/', 'n', 'a')],3
#
#
# 匿名没了？？？。
# 评论对象为：[('匿名/v/', 'v'), ('没/v/', 'v')],10
# 评价观点为[('匿名/v/', 'v'), ('没/v/', 'v')],10
#
#
# 别老是发那些广告烦死了
# 评论对象为：['那些/r/广告/n/'],3
# 评价观点为[('广告/n/烦死/a/', 'n', 'a')],3
#
#
# 界面挺清新的，功能也简单，用起来很方便
# 评论对象为：['界面/n/', '功能/n/'],9
# 评价观点为[('挺/d/清新/a/', 'a'), ('也/d/简单/a/', 'a')],2
#
#
# 很好用，有很多的贴纸，
# 评论对象为：[('有/v/', 'v'), ('贴纸/v/', 'v')],10
# 评价观点为['很好/d/'],8
#
#
# 界面很好，用的不错，看着也很顺眼。
# 评论对象为：['界面/n/'],9
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 破微信，刚刚注册的号登进来还要去解封实在是差，QQ好你十万倍
# 评论对象为：['信/n/'],9
# 评价观点为['刚刚/d/注册/v/'],7
#
#
# 可不可以把微信来电加震动 并且可以调大声音
# 评论对象为：['声音/n/'],9
# 评价观点为[('来电/v/', 'v'), ('加/v/', 'v'), ('调大/v/', 'v')],10
#
#
# 其实用习惯了就可以了。不错得！ 真的很好，没想到还有这么好好界面 相比一时贷，小黑鱼贷款平台放款快！
# 评论对象为：['黑鱼/n/贷款/n/平台/n/'],2
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 什么时候可以修改微信号啊？
# 评论对象为：['什么/r/时候/n/'],3
# 评价观点为[('修改/v/', 'v')],10
#
#
# 好东西，界面挺清新，不错不错吧
# 评论对象为：['界面/n/'],9
# 评价观点为[('不错/a/不错/a/', 'a', 'a')],1
#
#
# 合并后没有以前好用了，有一些贴纸都找不到了，而且相片的内存比以前大了。
# 评论对象为：['相片/n/', '内存/n/'],9
# 评价观点为['都/d/找/v/'],7
#
#
# 使用后感觉这个软件真的非常实用吧，界面清晰简洁也很出类拔萃，操作灵活多变。总体收益率也比其他软件高。以前朋友介绍过，不太好用，后来在朋友圈上看见许多人都发这软件的广告才用
# 评论对象为：['这个/r/软件/n/', '这/r/软件/n/'],3
# 评价观点为[('清晰/a/简洁/a/', 'a', 'a')],1
#
#
# 里面的资源 正版 画质音质都很好
# 评论对象为：['画质/n/音质/n/'],4
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 习惯5星吧，不比以前都好用了，现在怎么拍不了了?只能录像，知道都告诉下谢谢
# 评论对象为：['习惯/n/', '星/n/'],9
# 评价观点为['都/d/好用/v/', '都/d/告诉/v/'],7
#
#
# 杀毒很给力，界面再美观一下。
# 评论对象为：['力/n/', '界面/n/'],9
# 评价观点为['很/d/', '再/d/'],8
#
#
# 界面设计风格独特，分类齐全，功能设计贴心
# 评论对象为：['界面设计/n/风格/n/'],4
# 评价观点为[('风格/n/独特/a/', 'n', 'a')],3
#
#
# 功能实用！界面简洁！速度很快。挺不错的 书城书城很好。这书城书城棒极了！赞一个 大家放心下载，还不错。 很好，有多种功能，而且界面好看不单调
# 评论对象为：['这/r/书城/n/书城/n/'],1
# 评价观点为[('很/d/好/a/', 'a'), ('还/d/不错/a/', 'a'), ('很/d/好/a/', 'a')],2
#
#
# 给满分是不可能的，这么多年的微信了还只能发10秒的视频，10秒能看到什么？干脆叫动图算了。应该允许发送不超过10分钟的视频。还有就是朋友圈发动态时还必须要发一张图片，不发图片就发不了文字，这是在扯蛋。
# 评论对象为：[('发/v/不了/v/文字/n/', 'v')],5
# 评价观点为['满分/d/是/v/不/d/可能/v/'],6
#
#
# 解绑手机号都不行?垃圾
# 评论对象为：['手机号/n/', '垃圾/n/'],9
# 评价观点为['都/d/不行/v/'],7
#
#
# 视频资源还是挺多的，就是免费片源有点少了。
# 评论对象为：['视频/n/资源/n/'],4
# 评价观点为[('有点/n/少/a/', 'n', 'a')],3
#
#
# 泰捷视频可以看直播的，您可以在安装完后，在主界面选择“添加应用”，里面有直播软件绑定即可，能看免费的国内外直播频道！
# 评论对象为：[('有/v/直播/vn/软件/n/', 'vn')],5
# 评价观点为['即可/d/'],8
#
#
# 很不错本该满分，但是有些功能不需要太花哨得样子。纯个人意见 对于喜欢干净得。简单得界面得孩子来说是个很好得选择！ 不错不错吗？。我就用你了！！ 非常好用。在所有得看书软件里面。最好用得一个。 更好好的
# 评论对象为：['有些/r/功能/n/'],3
# 评价观点为[('不错/a/不错/a/', 'a', 'a')],1
#
#
# 什么滤镜，真的不能忍，好好的把你照成网红，果断差评
# 评论对象为：[('差/a/评/n/', 'a')],8
# 评价观点为[('果断/d/差/a/', 'a')],2
#
#
# 为什么我的三星s7e微信没有指纹支付这个选项？
# 评论对象为：['这个/r/选项/n/'],3
# 评价观点为[('没有/v/', 'v'), ('支付/v/', 'v')],10
#
#
# 天了噜。是同类应用软件中的王者啊呢 很棒啊呢。速度很快。界面也很个性真挺好得 挺优惠券app好用的，功能都很完善
# 评论对象为：['同类/n/', '王者/n/', '速度/n/', '界面/n/', '个性/n/', '优惠券/n/', '功能/n/'],9
# 评价观点为[('挺/d/好/a/', 'a')],2
#
#
# 为何没法换头像
# 评论对象为：['头像/n/'],9
# 评价观点为[('没法/v/', 'v')],10
#
#
# 为什么今天一直卡在这个界面啊
# 评论对象为：['这个/r/界面/n/'],3
# 评价观点为['一直/d/'],8
#
#
# 感觉挺很好，挺全面的 能看到好看的电影，而且资源很多，喜欢~~~~
# 评论对象为：['感觉/n/', '全面/n/', '电影/n/', '资源/n/'],9
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 很好用，既可以追剧，也可以看体育直播。
# 评论对象为：[('追剧/v/', 'v'), ('看/v/', 'v'), ('体育/vn/', 'vn'), ('直播/vn/', 'vn')],10
# 评价观点为['很好/d/', '也/d/'],8
#
#
# 不错不错，体验了各种模式都有很棒，特别是语音识别，开车用这个，太方便啦~
# 评论对象为：['各种/r/模式/n/'],3
# 评价观点为[('不错/a/不错/a/', 'a', 'a')],1
#
#
# 习惯性在这里找想看的电视了
# 评论对象为：['习惯性/n/', '电视/n/'],9
# 评价观点为[('找/v/', 'v'), ('想看/v/', 'v')],10
#
#
# 每天必看。有啥好好玩好好用得早知道 太很好了，顶一下 界面设计的很漂亮。功能很强大。值得推荐！！力顶
# 评论对象为：['界面设计/n/', '很漂亮/n/', '功能/n/', '力顶/n/'],9
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 建议拍摄时间长一点。。。其他的我觉得很棒。。。
# 评论对象为：[('建议/n/拍摄/v/', 'v')],6
# 评价观点为[('时间/n/长/a/', 'n', 'a')],3
#
#
# 挺好的，功能挺全的，除了有的收费，其他挺好的。赞一个！
# 评论对象为：['功能/n/', '收费/n/'],9
# 评价观点为[('挺/d/好/a/', 'a'), ('挺/d/全/a/', 'a'), ('挺/d/好/a/', 'a')],2
#
#
# 简直不能太赞了，书的品种齐全！软件很好，最喜欢爱奇艺阅读app的手势书签功能了，想收就收，很方便界面很漂亮，是我喜欢的风格哦！很方便，可以看到最近小伙伴推荐的好书
# 评论对象为：['手势/n/书签/n/功能/n/'],2
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 辣鸡微信，创号都还要好友辅助，而且无论怎样辅助都不能创号，辣鸡微信
# 评论对象为：[('辣鸡/n/微信/vn/', 'vn'), ('好友/n/辅助/vn/', 'vn'), ('辣鸡/n/微信/vn/', 'vn')],6
# 评价观点为['都/d/不能/v/'],7
#
#
# 刚注册就被封，我还没如好友呢，你叫我怎么解封
# 评论对象为：['好友/n/'],9
# 评价观点为['刚/d/注册/v/', '还/d/没如/v/'],7
#
#
# 为什么我提供了照片到不到他的店里去
# 评论对象为：[('照片/n/到/v/', 'v'), ('店里/n/去/v/', 'v')],6
# 评价观点为[('提供/v/', 'v'), ('到/v/', 'v'), ('不到/v/', 'v'), ('去/v/', 'v')],10
#
#
# 界面很不错，书籍也齐全。
# 评论对象为：['界面/n/', '书籍/n/'],9
# 评价观点为['也/d/'],8
#
#
# uc折腾的已经无爱，刚才看uc评论 一堆托，太失望了 。欧朋的设置界面和塞班那会的版本好像，有点怀念。 好久没用欧朋，下来看看
# 评论对象为：[('版本/n/好像/v/', 'v'), ('有点/n/怀念/v/', 'v')],6
# 评价观点为['已经/d/无爱/v/', '太/d/失望/v/'],7
#
#
# 不能更改微信号，不能分组！没有QQ使用方便
# 评论对象为：['微/n/信号/n/'],4
# 评价观点为[('不能/v/', 'v'), ('更改/v/', 'v'), ('不能/v/', 'v'), ('没有/v/', 'v')],10
#
#
# 看个视频看不了 别的视频软件（b站腾讯视频之类的）蓝光一点都不卡
# 评论对象为：['别的/r/视频/n/软件/n/'],1
# 评价观点为['都/d/', '不/d/'],8
#
#
# 不错的看书软件。界面很舒服。流畅。
# 评论对象为：['软件/n/', '界面/n/'],9
# 评价观点为[('不错/a/', 'a'), ('舒服/a/', 'a'), ('流畅/a/', 'a')],9
#
#
# 下载视频真慢
# 评论对象为：['视频/n/'],9
# 评价观点为['真慢/d/'],8
#
#
# 界面简单，功能也简单，用起来很方便
# 评论对象为：[('界面/n/简单/a/', 'a')],7
# 评价观点为[('也/d/简单/a/', 'a')],2
#
#
# 我觉得都更改不了名字有点儿不太好。
# 评论对象为：[('更改/v/不了/v/名字/n/', 'v')],5
# 评价观点为['都/d/更改/v/'],7
#
#
# 用腾讯会员已经下载到手机的视频，在腾讯会员过期后不能看？what？没见过这么坑的软件！！！
# 评论对象为：['这么/r/坑/n/'],3
# 评价观点为['已经/d/下载/v/'],7
#
#
# 为啥不能改资料，也没有提示i什么楼逼东西
# 评论对象为：['什么/r/楼/n/'],3
# 评价观点为['也/d/没有/v/'],7
#
#
# 很好啊～界面看着超级舒服！没有那么多花花绿绿的，视觉享受。
# 评论对象为：[('界面/n/看着/v/', 'v')],6
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 实景地图展示非常的好、画面清晰！！！
# 评论对象为：['实景/n/地图/n/'],4
# 评价观点为[('画面/n/清晰/a/', 'n', 'a')],3
#
#
# 不能换头像
# 评论对象为：['头像/n/'],9
# 评价观点为[('不能/v/', 'v')],10
#
#
# 垃圾越做越垃圾，上传个名片背景墙照片都传不上去，明明网络很好还尼玛显示网络有问题
# 评论对象为：['名片/n/背景墙/n/照片/n/'],2
# 评价观点为['都/d/传/v/'],7
#
#
# 好棒！拍照好可爱！喜欢！！！
# 评论对象为：[('拍照/v/', 'v'), ('可爱/v/', 'v'), ('喜欢/v/', 'v')],10
# 评价观点为[('好/a/棒/a/', 'a', 'a')],1
#
#
# 最棒的应用，我们店好多服务员都在用吧，约会神器呀，简单的界面的孩子来说是个不错的选择，新版本太棒了
# 评论对象为：['我们/r/店/n/'],3
# 评价观点为[('最/d/棒/a/', 'a')],2
#
#
# 朋友推荐的，非常不错哦，全景3D很有帮助，界面简洁，速度快
# 评论对象为：[('朋友/n/推荐/v/', 'v')],6
# 评价观点为[('非常/d/不错/a/', 'a')],2
#
#
# 准确的路线规划和完善的语音提示都是导航过程中不可缺少的功能 百度地图一直做的很棒！
# 评论对象为：['路线/n/规划/n/', '百度/n/地图/n/'],4
# 评价观点为['都/d/是/v/', '一直/d/做/v/'],7
#
#
# 界面挺清新。挺好挺好 给力的app。挺好 在应用强推里下的。感觉还不错 挺的应用app，值得强推给大家！
# 评论对象为：['界面/n/', '力/n/', '感觉/n/', '大家/n/'],9
# 评价观点为[('挺/d/清新/a/', 'a'), ('挺/d/好/a/', 'a'), ('挺/d/好/a/', 'a'), ('挺/d/好/a/', 'a'), ('还/d/不错/a/', 'a')],2
#
#
# 新版界面很不错，我很喜欢这种感觉，适合！
# 评论对象为：['这种/r/感觉/n/'],3
# 评价观点为['很/d/喜欢/v/'],7
#
#
# 一直卡在界面上。进不去。怎么办
# 评论对象为：['卡/n/', '界面/n/'],9
# 评价观点为['一直/d/'],8
#
#
# 用着真不错，界面很舒服哦，很好！
# 评论对象为：['界面/n/'],9
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 支持，章节很清晰非常实用界面可以再增加点功能会更不错得人啊呢！
# 评论对象为：[('功能/n/会/v/', 'v')],6
# 评价观点为[('更/d/不错/a/', 'a')],2
#
#
# 为什么更新了微信，视频看不到对方了
# 评论对象为：[('视频/n/看不到/v/', 'v')],6
# 评价观点为['更新/d/'],8
#
#
# 一直脸部识别失败，怎么调都不行
# 评论对象为：[('脸部/n/识别/v/', 'v')],6
# 评价观点为['都/d/不行/v/'],7
#
#
# 简洁，不错用，挺喜欢的 从内容的广度和深度来看。背后开发的团队绝对付出了很大的血本和努力啦。希望这款软件会越来越很好。我会一如既往的支持你们的！！ 界面设计的很华丽，功能非常强大，个人觉得很棒！
# 评论对象为：[('软件/n/会/v/', 'v'), ('个人/n/觉得/v/', 'v')],6
# 评价观点为[('很/d/好/a/', 'a'), ('非常/d/强大/a/', 'a')],2
#
#
# 挺不错，好玩又有趣，简约风的界面我很喜欢。
# 评论对象为：['风/n/', '界面/n/'],9
# 评价观点为[('又/d/有趣/a/', 'a')],2
#
#
# 界面挺清新的，功能也简单，用起来很方便
# 评论对象为：['界面/n/', '功能/n/'],9
# 评价观点为[('挺/d/清新/a/', 'a'), ('也/d/简单/a/', 'a')],2
#
#
# 为什么每次配图的时候，一按插入到说说就返回到登录界面
# 评论对象为：[('到/v/登录/v/界面/n/', 'v')],5
# 评价观点为['就/d/返回/v/'],7
#
#
# 我是一个强迫症，最不能忍的就是兴趣部落里官方推荐的那些东西，每次打开都有红点，然后就看见恶心的兴趣部落有我最恶心的官方推送！！！！！移除这个板块还移除不了
# 评论对象为：['这个/r/板块/n/'],3
# 评价观点为['最/d/不能/v/', '都/d/有/v/', '就/d/看见/v/', '还/d/移除/v/'],7
#
#
# 我就想知道 维修时间都过了 怎么头像依然换不了 我都下载卸载n遍了
# 评论对象为：['怎么/r/头像/n/'],3
# 评价观点为['就/d/想/v/', '都/d/下载/v/'],7
#
#
# 新版好丑啊啊啊啊
#
#
# 不错不错东西呀！！界面简单方便我喜欢得调调 书类种类齐全，追书神器，很不错的看书软件。
# 评论对象为：['书类/n/种类/n/'],4
# 评价观点为[('不错/a/不错/a/', 'a', 'a'), ('简单/a/方便/a/', 'a', 'a')],1
#
#
# 用了几款直播软件，真心觉得这个软件好用，不卡，界面简洁美观，喜欢，呵呵！
# 评论对象为：['这个/r/软件/n/'],3
# 评价观点为[('软件/n/好/a/', 'n', 'a'), ('界面/n/简洁/a/', 'n', 'a')],3
#
#
# 所有人开播都有直播状态， 有很多不同分类的视频直播. 界面非常优美，...
# 评论对象为：[('有/v/直播/vn/状态/n/', 'vn')],5
# 评价观点为[('非常/d/优美/a/', 'a')],2
#
#
# 界面看着挺清爽的，用起来很舒服，先去找个游戏群聊唠会去，然后等开新区充钱，有折扣就是好
# 评论对象为：[('界面/n/看着/v/', 'v'), ('游戏/n/群聊/v/', 'v')],6
# 评价观点为[('挺/d/清爽/a/', 'a'), ('就是/d/好/a/', 'a')],2
#
#
# 刚刚下载，就登录不了，好TM的烦
# 评论对象为：[('下载/v/', 'v'), ('登录/v/', 'v'), ('不了/v/', 'v')],10
# 评价观点为['刚刚/d/下载/v/', '就/d/登录/v/'],7
#
#
# 挺很好界面流畅，很有意思！ 更新几次以后，新系统明显比之前的好用多了！
# 评论对象为：[('界面/n/流畅/a/', 'a'), ('系统/n/明显/a/', 'a')],7
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 界面清爽，资源丰富！呵呵广泛覆盖挺好的？看小说好多年，很多书都有，为了晚上看的时候可以调夜间模式保护眼睛下的。不错哦感觉免费的。。
# 评论对象为：[('模式/n/保护/v/', 'v'), ('感觉/n/免费/vn/', 'vn')],6
# 评价观点为[('挺/d/好/a/', 'a')],2
#
#
# 很不错，兼容格式多，界面朴实实用，操作简单！！
# 评论对象为：[('界面/n/朴实/a/', 'a')],7
# 评价观点为[('界面/n/朴实/a/', 'n', 'a')],3
#
#
# 希望增加扫描翻译短文或者可以翻译短文的功能。
# 评论对象为：[('扫描/v/翻译/v/短文/n/', 'v')],5
# 评价观点为[('希望/v/', 'v'), ('增加/v/', 'v'), ('扫描/v/', 'v'), ('翻译/v/', 'v'), ('翻译/v/', 'v')],10
#
#
# 这个应用软件确实很好用。感觉很得满意。希望大家都喜欢！！ 我觉得挺有意思的。你们觉得呢 挺好好得应用软件界面流畅。很有意思！！
# 评论对象为：[('界面/n/流畅/a/', 'a')],7
# 评价观点为[('界面/n/流畅/a/', 'n', 'a')],3
#
#
# 从三年级就开始玩QQ，现在高二，我觉得真的挺好使，除了不能手机支付
# 评论对象为：[('手机/n/支付/v/', 'v')],6
# 评价观点为['就/d/开始/v/', '挺/d/好使/v/'],7
#
#
# 我是纵横书界多年的老书虫，对于手机阅读器的要求是很高的。界面设计要好看，网络阅读一定有本地阅读要给力，翻页速度一定要快，所有这些实用的功能都必须要有，咱在看小说的时候才能爽，这款阅读软件完全能满足需求
# 评论对象为：['老/n/书虫/n/', '手机/n/阅读器/n/', '翻页/n/速度/n/'],4
# 评价观点为[('界面设计/n/要好看/a/', 'n', 'a'), ('软件/n/完全/ad/', 'n', 'ad')],3
#
#
# 更新之后，界面更漂亮了
# 评论对象为：['界面/n/'],9
# 评价观点为[('更/d/漂亮/a/', 'a')],2
#
#
# 用过了才感觉不错的。 界面清爽。功能也很好！！很好！！ 不错不错用，方便
# 评论对象为：[('感觉/n/不错/a/', 'a'), ('界面/n/清爽/a/', 'a')],7
# 评价观点为[('不错/a/不错/a/', 'a', 'a')],1
#
#
# 也还行吧。就是有很多动漫不能看。继续努力
# 评论对象为：[('动漫/n/不能/v/', 'v')],6
# 评价观点为['也/d/还行/v/', '就是/d/有/v/'],7
#
#
# 云顶天天赚界面整齐，符合用户的操作习惯
# 评论对象为：['界面/n/', '用户/n/', '习惯/n/'],9
# 评价观点为['整齐/d/'],8
#
#
# 真心很实用，没有花哨的界面
# 评论对象为：['花哨/n/', '界面/n/'],9
# 评价观点为['真心/d/'],8
#
#
# 常喜欢这个界面，感觉看起来特别的舒心，太棒了！ 反应速度快，用起来顺手。 非常好得东西。找了好久了
# 评论对象为：['这个/r/界面/n/'],3
# 评价观点为[('非常/d/好/a/', 'a')],2
#
#
# 主播数量比较多，类型也多 界面非常优美 现在天天觉得已经离不开这个软件了.
# 评论对象为：['这个/r/软件/n/'],3
# 评价观点为[('非常/d/优美/a/', 'a')],2
#
#
# 不错一个软件赞一个，阅读器界面做的挺好的。
# 评论对象为：['阅读器/n/界面/n/'],4
# 评价观点为[('不错/a/', 'a'), ('挺好/a/', 'a')],9
#
#
# 不如其他视频软件，虽说大王卡免流量了，可是能免费看的没几个，而且更新不及时，没有新片，果断卸载
# 评论对象为：['其他/r/视频/n/软件/n/'],1
# 评价观点为['果断/d/卸载/v/'],7
#
#
# 对于喜欢干净的，简单的界面的孩子来说是个不错的选择！.
# 评论对象为：['界面/n/', '孩子/n/'],9
# 评价观点为[('干净/a/', 'a'), ('简单/a/', 'a'), ('不错/a/', 'a')],9
#
#
# 为啥不可以换头像？？
# 评论对象为：['头像/n/'],9
# 评价观点为['不/d/'],8
#
#
# 发一条消息就无响应???找一个表情就无响应???在下输了??
# 评论对象为：['消息/n/', '表情/n/'],9
# 评价观点为['就/d/无/v/', '就/d/无/v/'],7
#
#
# 大家都用的到的拼团电商，很实惠而且方便，嘴馋的时候随时下单还有不菲的优惠力度
# 评论对象为：['大家/n/都用/n/', '拼团/n/电商/n/'],4
# 评价观点为['随时/d/'],8
#
#
# 比较喜欢阅读各类小说，这个软件我比较需要，很人性化,阅读的时候能设置界面颜色，而且还有护眼功能呢
# 评论对象为：['各类/r/小说/n/', '这个/r/软件/n/'],3
# 评价观点为['比较/d/喜欢/v/', '比较/d/需要/v/'],7
#
#
# 开通vip了，还有7 天到期，不管看vip视频了
# 评论对象为：['视频/n/'],9
# 评价观点为['到期/d/'],8
#
#
# 各种热门的网文都有并且全本免费小说,里面有别的软件搜不到的小说,为开发人员点32个赞~,太棒了,界面干净、书架版块分的很清晰。
# 评论对象为：['各种/r/热门/n/', '别的/r/软件/n/'],3
# 评价观点为[('很/a/清晰/a/', 'a', 'a')],1
#
#
# 能不能在别人删了我的时候 在我的通讯录里也消失。。。。。
# 评论对象为：['时候/n/', '通讯录/n/', '消失/n/'],9
# 评价观点为['也/d/'],8
#
#
# 还不错，值得推荐的软件！界面设计很贴心。挺好的应用，软件界面挺好看的，今天刚下的，感觉非常不错，用上挺顺手的，赞！第一次评价，分类很多，而且内容新颖，这下不发愁晚上睡觉没事干了！加油给力
# 评论对象为：['软件/n/界面/n/'],4
# 评价观点为[('还/d/不错/a/', 'a'), ('挺/d/好/a/', 'a'), ('非常/d/不错/a/', 'a')],2
#
#
# 为啥头像一直换不了，谁看永远都是一个头像
# 评论对象为：['为啥/r/头像/n/'],3
# 评价观点为['一直/d/'],8
#
#
# 界面简单但是功能却非常强大！咨询了客服各个问题.客服都详细给我解答了，点赞
# 评论对象为：['各个/r/问题/n/'],3
# 评价观点为[('非常/d/强大/a/', 'a'), ('都/d/详细/ad/', 'ad')],2
#
#
# 广告太多，还跳优酷
# 评论对象为：['广告/n/'],9
# 评价观点为['还/d/跳/v/'],7
#
#
# 用着真不错，界面很舒服
# 评论对象为：['界面/n/'],9
# 评价观点为[('舒服/a/', 'a')],9
#
#
# 这个软件很不错不错用非常不错不错！！ 一直用这个来着，感觉非常很好 界面设计得很华丽，功能很强大，个人觉得很棒，我喜欢。
# 评论对象为：['这个/r/软件/n/'],3
# 评价观点为[('不错/a/不错/a/', 'a', 'a'), ('不错/a/不错/a/', 'a', 'a')],1
#
#
# 挺好的建议把那个充值改的更低点。就好了谢谢
# 评论对象为：['那个/r/充值/n/'],3
# 评价观点为[('挺/d/好/a/', 'a'), ('就/d/好/a/', 'a')],2
#
#
# 还是没有两倍
# 评论对象为：[('没有/v/', 'v')],10
# 评价观点为[('没有/v/', 'v')],10
#
#
# 小度查找充电桩好方便，小度是最胖的！！！！哈哈
# 评论对象为：[('小度/n/查找/v/', 'v'), ('小度/n/是/v/', 'v')],6
# 评价观点为[('好/a/方便/a/', 'a', 'a')],1
#
#
# 没有内容，没有资源，充了会员上当啊
# 评论对象为：[('会员/n/上当/v/', 'v')],6
# 评价观点为[('没有/v/', 'v'), ('没有/v/', 'v'), ('充/v/', 'v'), ('上当/v/', 'v')],10
#
#
# 绿茶浏览器上网快速、流畅，界面简洁清新，非常喜欢！
# 评论对象为：['绿茶/n/浏览器/n/'],4
# 评价观点为[('简洁/a/清新/a/', 'a', 'a')],1
#
#
# 交友软件性不错设计界面流程合理易懂非常好玩！
# 评论对象为：['交友/n/软件/n/性/n/'],2
# 评价观点为[('性/n/不错/a/', 'n', 'a')],3
#
#
# 新版本居然将vp电竞社区专区界面优化了，看来这次vp电竞全新改版真的蛮给力的，幸好更新了。
# 评论对象为：['社区/n/专区/n/界面/n/'],2
# 评价观点为[('新/a/版本/n/', 'a')],4
#
#
# 看漫画的夜间模式不要用到界面上啊…太暗了…要瞎了…
# 评论对象为：['漫画/n/', '模式/n/', '界面/n/', '太暗/n/'],9
# 评价观点为[('看/v/', 'v'), ('用到/v/', 'v'), ('要/v/', 'v'), ('瞎/v/', 'v')],10
#
#
# 在软件推荐里下得，感觉还很不错 从内容得广度和深度来看，希望这款软件会越来越好，我会一如既往得支持你们得。 界面简洁美观，智能分类很强大，占用内存小，很好一
# 评论对象为：['智能/n/分类/n/'],4
# 评价观点为[('很/d/不错/a/', 'a'), ('越来越/d/好/a/', 'a'), ('很/d/好/a/', 'a')],2
#
#
# 非常好好，建议大家下载，页面清新，看上去很好好 直播可以在线互动，界面很清新. 见过很多漂亮的妹子，但是没有见过如此清纯的嘛。 没钱就不要打赏，反正一样看的。有钱多打点。
# 评论对象为：['建议/n/大家/n/'],4
# 评价观点为[('页面/n/清新/a/', 'n', 'a')],3
#
#
# 腾讯王卡免流，不然都不想用，好多好看的东西都看不到，在爱奇艺那些APP都搜索得到，用户体验非常不好，好不喜欢这个。
# 评论对象为：['用户/n/体验/n/'],4
# 评价观点为[('爱奇/a/艺/n/', 'a')],4
#
#
# POI指引粹别方向可以更容易使用，骑车也可能有，方便不得了
# 评论对象为：['方向/n/', '骑车/n/'],9
# 评价观点为[('更/d/容易/a/', 'a')],2
#
#
# 在这儿买过一次后，就经常在这儿购物啦。这里的东西很多，种类齐全，实体店买不起的大牌还经常搞活动，真是很亲民呢
# 评论对象为：['这儿/r/购物/n/'],3
# 评价观点为['经常/d/搞/v/'],7
#
#
# QQ看点，怎么就自动退出来了。
# 评论对象为：['看点/n/'],9
# 评价观点为['就/d/'],8
#
#
# 广告太长了，
# 评论对象为：['广告/n/'],9
# 评价观点为[('太/d/长/a/', 'a')],2
#
#
# 很实用，比以前用过得几款应用软件好用多了，会一直支持得 比较不错不错用的一款软件，不错不错 界面和皮肤没得说。那么多年了。一直信任的东西。
# 评论对象为：['软件/n/', '界面/n/', '皮肤/n/', '信任/n/'],9
# 评价观点为[('不错/a/不错/a/', 'a', 'a'), ('不错/a/不错/a/', 'a', 'a')],1
#
#
# 信息太多不能像QQ一样删，要一个一个删除太麻烦
# 评论对象为：['信息/n/'],9
# 评价观点为['太/d/', '太/d/'],8
#
#
# 感觉界面比之前的普通版好，就是更新之后加的背景音乐感觉有点多余
# 评论对象为：['背景音乐/n/感觉/n/有点/n/'],2
# 评价观点为[('版/n/好/a/', 'n', 'a')],3
#
#
# 为什么一块进就显示断网了
# 评论对象为：[('进/v/', 'v'), ('显示/v/', 'v'), ('断网/v/', 'v')],10
# 评价观点为['就/d/显示/v/'],7
#
#
# 我艹你妈的烂微信。 我QQ登陆为什么就登不上。他妈的还说我QQ被盗。我还去把密码改了 结果还登录不上 烂微信 真的是
# 评论对象为：['你/r/妈/n/'],3
# 评价观点为['就/d/登不上/v/', '还/d/说/v/', '还/d/去/v/', '还/d/登录/v/', '真的/d/是/v/'],7
#
#
# 为什么现在没有发悄悄话的了
# 评论对象为：[('没有/v/发/v/悄悄话/n/', 'v')],5
# 评价观点为[('没有/v/', 'v'), ('发/v/', 'v')],10
#
#
# 多种语音通话。实在太好了。
# 评论对象为：['语音/n/通话/n/'],4
# 评价观点为[('实在/v/', 'v')],10
#
#
# 辣鸡应用不能忍！头一回打差评 简直不要太过分 恢复出厂设置再登录居然要扫描二维码后才能用！我特么上哪借手机去！去你大爷的微信！不玩了！
# 评论对象为：['你/r/大爷/n/'],3
# 评价观点为['再/d/登录/v/居然/d/要/v/'],6
#
#
# 一颗心都不想给，越来越垃圾，越更新越垃圾，新版本拍照还闪屏，之前都没有，现在更新了版本竟然这样，按拍照闪一下之后照片拍出来，然后特别模糊，本来拍的时候可清楚一闪屏就模糊，气死，我试了好多相机都不会这样
# 评论对象为：[('版本/n/拍照/v/', 'v'), ('照片/n/拍/v/', 'v'), ('时候/n/可/v/', 'v')],6
# 评价观点为[('特别/d/模糊/a/', 'a'), ('就/d/模糊/a/', 'a')],2
#
#
# 超喜欢这个图标，内容界面都更新了的，主要是价格比较优惠
# 评论对象为：['这个/r/图标/n/'],3
# 评价观点为['都/d/', '更新/d/', '比较/d/'],8
#
#
# 开了会员，却不能同时缓存三个视频，唉，有点失望
# 评论对象为：[('有点/n/失望/v/', 'v')],6
# 评价观点为['却/d/不能/v/'],7
#
#
# 干嘛要银行卡登录啊！我都没有银行卡，要我怎么用啊！给差评
# 评论对象为：[('干嘛/n/要/v/', 'v')],6
# 评价观点为['都/d/没有/v/'],7
#
#
# 我就不知道你们这些软件就那么喜欢更新，隔三差五又来
# 评论对象为：['这些/r/软件/n/'],3
# 评价观点为['不/d/知道/v/', '又/d/来/v/'],7
#
#
# 登陆申诉。超级麻烦。 ????
# 评论对象为：[('登陆/v/', 'v'), ('申诉/v/', 'v')],10
# 评价观点为[('登陆/v/', 'v'), ('申诉/v/', 'v')],10
#
#
# 签名，个人信息，礼物系统都不稳定？怎么回事？？？？？？？？？
# 评论对象为：['礼物/n/系统/n/'],4
# 评价观点为[('不/d/稳定/a/', 'a')],2
#
#
# 手机要会员所以我开通了但是电视上还他妈要超级会员怎么想的
# 评论对象为：['他/r/妈/n/'],3
# 评价观点为['还/d/'],8
#
#
# 广告太多，缓存完的还有广告，
# 评论对象为：['广告/n/', '广告/n/'],9
# 评价观点为['太/d/'],8
#
#
# 软件挺好，喜欢里面贴纸，就是识别功能太差，贴纸有时候对不上
# 评论对象为：['软件/n/', '功能/n/'],9
# 评价观点为[('挺/d/好/a/', 'a'), ('太/d/差/a/', 'a')],2
#
#
# 很好用，地图很全
# 评论对象为：['地图/n/'],9
# 评价观点为[('很/d/全/a/', 'a')],2
#
#
# 最新版本的界面好丑，聊天语音条的秒数这么突兀也不好看
# 评论对象为：['版本/n/', '界面/n/', '语音/n/', '秒数/n/'],9
# 评价观点为['不/d/好看/v/'],7
#
#
# 软件很好。这软件棒极了！赞一个 用着真很好，界面很舒服 不错不错是不错不错。就是装了之后每天刷不错不错几遍
# 评论对象为：['这/r/软件/n/棒极了/n/'],1
# 评价观点为[('不错/a/不错/a/', 'a', 'a'), ('不错/a/不错/a/', 'a', 'a'), ('不错/a/不错/a/', 'a', 'a')],1
#
#
# 拼团买特别划算，无论是商品质量还是物流速度，都让人放心，每天光顾拼多多已成了我生活的一部分
# 评论对象为：['物流/n/速度/n/'],4
# 评价观点为['特别/d/划算/v/', '都/d/让/v/'],7
#
#
# 操作太频繁！！！登不上去！！！！
# 评论对象为：[('操作/v/', 'v'), ('登不/v/', 'v')],10
# 评价观点为[('太/d/频繁/a/', 'a')],2
#
#
# 界面简洁实用
# 评论对象为：[('界面/n/简洁/a/', 'a')],7
# 评价观点为[('界面/n/简洁/a/', 'n', 'a')],3
#
#
# 申诉改密码用不了，还有什么用。垃圾。
# 评论对象为：[('申诉/v/改/v/密码/n/', 'v')],5
# 评价观点为[('申诉/v/', 'v'), ('改/v/', 'v'), ('不了/v/', 'v'), ('还有/v/', 'v')],10
#
#
# 改个资料都不能改，现在。
# 评论对象为：['资料/n/'],9
# 评价观点为['都/d/不能/v/'],7
#
#
# 你维护连头像都换不了？而且还是到月底都换不了？
# 评论对象为：['头像/n/'],9
# 评价观点为['都/d/换/v/', '都/d/换/v/'],7
#
#
# 很好，新片多更新， 视频加载快，界面也简介漂亮。 同样的网速，风行的播放速度是最快的，业界良心啊！！！
# 评论对象为：[('视频/n/加载/v/', 'v'), ('速度/n/是/v/', 'v')],6
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 只能说，非常不错的，能推荐的 很实用界面可以再增加点功能会更好的人啊！！ 不错，不错，不错，非常不错
# 评论对象为：[('功能/n/会/v/', 'v')],6
# 评价观点为[('非常/d/不错/a/', 'a'), ('非常/d/不错/a/', 'a')],2
#
#
# 这款狼人杀游戏界面清晰，游戏好玩易上手，音效也不错，值得一玩的游戏。
# 评论对象为：['这/r/款/n/狼/n/'],1
# 评价观点为[('也/d/不错/a/', 'a')],2
#
#
# 翻译的蛮好的
# 评论对象为：[('翻译/v/', 'v')],10
# 评价观点为[('蛮好/a/', 'a')],9
#
#
# 看一集电视剧都有怎么多广告
# 评论对象为：['电视剧/n/', '广告/n/'],9
# 评价观点为['都/d/有/v/'],7
#
#
# 自己做主播很不错，感觉得到了关注 相比较而言，感觉比歪歪之类的好用. 直播可以在线互动，界面很清新，功能强大，大赞哦
# 评论对象为：['感觉/n/', '界面/n/'],9
# 评价观点为[('很/d/不错/a/', 'a')],2
#
#
# 还行，就是不知道为什么发语音的时候会卡，也不是手机配置不行。
# 评论对象为：[('时候/n/会/v/', 'v'), ('手机/n/配置/v/', 'v')],6
# 评价观点为['不/d/知道/v/'],7
#
#
# app界面设计很好看～～真的很棒啦！！
# 评论对象为：['界面设计/n/'],9
# 评价观点为[('真的/d/很棒/a/', 'a')],2
#
#
# 朋友推荐的！用了之后！没想到效果不错！强力推荐 我觉得电影方面并不是很全！我不是说影院！是老片方面！很少！大多要转借其他的平台！~~~~
# 评论对象为：['电影/n/方面/n/', '老片/n/方面/n/'],4
# 评价观点为[('很/d/全/a/', 'a')],2
#
#
# 为什么现在没法改名字，没法改头像？
# 评论对象为：[('没法/v/改/v/头像/n/', 'v')],5
# 评价观点为[('没法/v/', 'v'), ('没法/v/', 'v'), ('改/v/', 'v')],10
#
#
# 海量书都很棒，最主要的是免费，里面的书特别多，并且还全本免费，小说情节非常生动，界面简洁大气。
# 评论对象为：['海量/n/书/n/', '小说/n/情节/n/'],4
# 评价观点为[('都/d/很棒/a/', 'a')],2
#
#
# 街景地图好像还蛮有创意的，
# 评论对象为：['街景/n/地图/n/'],4
# 评价观点为['蛮/d/有/v/'],7
#
#
# POP民认为挺方便的，不知道是谁弄出来的，不错！这是一款非常值得推荐的软件，非常方便你交到朋友，而且内容界面很丰富明了，里面有很多人在玩，值得推荐说实话，表里不一，呵呵呵，给五星真的是昧着良心交友很真
# 评论对象为：['内容/n/界面/n/'],4
# 评价观点为[('丰富/a/明/a/', 'a', 'a')],1
#
#
# 界面比较简洁，我喜欢占用手机内存少。
# 评论对象为：['手机/n/内存/n/'],4
# 评价观点为[('比较/d/简洁/a/', 'a')],2
#
#
# 铃声设置在哪里为什么没有了
# 评论对象为：[('铃声/n/设置/vn/', 'vn')],6
# 评价观点为[('没有/v/', 'v')],10
#
#
# 非常赞的团购平台，在这里可以买到物美价廉的东西，里面物品非常丰富，经常和朋友一起拼团，想要团购，就来拼多多吧
# 评论对象为：['平台/n/', '物品/n/', '朋友/n/', '拼团/n/'],9
# 评价观点为[('非常/d/丰富/a/', 'a')],2
#
#
# 贴纸很可爱，很漂亮
# 评论对象为：['很漂亮/n/'],9
# 评价观点为[('贴纸/v/', 'v'), ('可爱/v/', 'v')],10
#
#
# 手机号注册第二个微信之后，第一个微信不记得密码了那么要怎样才可以找回第一个微信，第一个微信没绑定QQ邮箱
# 评论对象为：[('手机号/n/注册/v/', 'v')],6
# 评价观点为['不/d/记得/v/'],7
#
#
# 功能强大。界面简洁。操作流畅。很不错 身边的朋友都在用直播，平台有很多帅哥漂亮的妹子，大家可以随时随地分享彼此的快乐。
# 评论对象为：[('平台/n/有/v/', 'v')],6
# 评价观点为[('界面/n/简洁/a/', 'n', 'a')],3
#
#
# 能不能设置一个好友推荐的开关。
# 评论对象为：[('好友/n/推荐/v/', 'v')],6
# 评价观点为[('能/v/', 'v'), ('不能/v/', 'v'), ('推荐/v/', 'v'), ('开关/v/', 'v')],10
#
#
# 要是能有留言功能就好了
# 评论对象为：[('有/v/留言/v/功能/n/', 'v')],5
# 评价观点为[('就/d/好/a/', 'a')],2
#
#
# 随便就封号？垃圾，两次了都
# 评论对象为：['封号/n/', '垃圾/n/'],9
# 评价观点为['随便/d/', '就/d/', '都/d/'],8
#
#
# 最近在登陆界面老是闪退
# 评论对象为：[('界面/n/老/a/', 'a')],7
# 评价观点为[('界面/n/老/a/', 'n', 'a')],3
#
#
# 不错！更新速度很快。客服也很细心..非常好。试起来特别顺手 挺好好得看书软件看书软件界面流畅，很有意思！ 很好用的看书软件看书软件，很强大 一直都有使用。希望越做越不错不错咯
# 评论对象为：['软件/n/界面/n/'],4
# 评价观点为[('不错/a/不错/a/', 'a', 'a')],1
#
#
# 更新后文字和图片不能一起发送
# 评论对象为：[('图片/n/不能/v/', 'v')],6
# 评价观点为['更新/d/'],8
#
#
# 头像不能更换玩
# 评论对象为：[('头像/n/不能/v/', 'v')],6
# 评价观点为[('不能/v/', 'v'), ('更换/v/', 'v'), ('玩/v/', 'v')],10
#
#
# 之前是小米手机自带的，现在换了红米，也照样下载，这个软件好就好在不用网络也能翻译单词，句子的话就需要网络了，但是挺好用的，可以翻译多种语言，还能听语音，背单词，大力推荐。（我给四颗星是怕它骄傲^_^）
# 评论对象为：['小米/n/手机/n/自带/n/'],2
# 评价观点为[('就/d/好/a/', 'a')],2
#
#
# 更新之后，界面更漂亮了
# 评论对象为：['界面/n/'],9
# 评价观点为[('更/d/漂亮/a/', 'a')],2
#
#
# 很不错的阅读软件，有很多的免费小说、故事，而且阅读界面看起来也很舒服，是不可多得的一个阅读神器！
# 评论对象为：[('界面/n/看起来/v/', 'v')],6
# 评价观点为[('很/d/舒服/a/', 'a')],2
#
#
# 朋友介绍的软件界面挺简单的。
# 评论对象为：['软件/n/界面/n/'],4
# 评价观点为[('挺/d/简单/a/', 'a')],2
#
#
# 界面设计得很华丽，功能很强大，个人觉得很棒！ 好软件
# 评论对象为：[('个人/n/觉得/v/', 'v')],6
# 评价观点为[('好/a/软件/n/', 'a')],4
#
#
# 有人气明星也在直播！界面设计也是高大上啊。
# 评论对象为：['有人/r/气/n/'],3
# 评价观点为['也/d/是/v/'],7
#
#
# 游戏界面和游戏设计是我玩过几种狼人杀里最好的，但是高素质玩家的游戏？你去进阶区看看，不是拿了狼人就离线，就是好人贴脸，经常三狼战群雄，举报了又怎么样？他们有很多号！游戏可玩性大打折扣，自己玩了就知道，鸡肋！！！！！
# 评论对象为：['狼/n/战/n/群雄/n/'],2
# 评价观点为['就/d/知道/v/'],7
#
#
# 新手注册指南??? #画面#超级棒 #安装问题#想必大家不知道怎么注册吧？??首先选择加速器，然后打开游戏，开始界面有3个登录方式1谷歌（我用的谷歌），2拳头（推荐），3脸书（注册麻烦不推荐），我们打开加速器然后下载拳头账号注册，用自己的邮箱（只要是邮箱都可以）qq邮箱，然后就可以了。祝大家游戏愉快！
# 评论对象为：['拳头/n/账号/n/', '大家/n/游戏/n/'],4
# 评价观点为[('游戏/n/愉快/a/', 'n', 'a')],3
#
#
# 美图一直是我想删不想删的软件，直到刚刚发现一个神奇的功能，可以消除图片上一些文字贴
# 评论对象为：[('文字/n/贴/v/', 'v')],6
# 评价观点为['一直/d/是/v/', '刚刚/d/发现/v/'],7
#
#
# 里面的直播都挺好看的，是一款不错的直播软件！界面也是我喜欢的风格
# 评论对象为：['软件/n/', '界面/n/', '风格/n/'],9
# 评价观点为['挺/d/好看/v/', '也/d/是/v/'],7
#
#
# 同学推荐的！用了之后！没想到效果不错！强力推荐 很好用，一直在用，挺方便的~~~~
# 评论对象为：[('同学/n/推荐/v/', 'v'), ('强力/n/推荐/v/', 'v')],6
# 评价观点为[('挺/d/方便/a/', 'a')],2
#
#
# 软件好好用啊，界面设计简洁一目了然，再也不用担心在外面看不到直播了。
# 评论对象为：[('界面设计/n/简洁/a/', 'a')],7
# 评价观点为[('界面设计/n/简洁/a/', 'n', 'a')],3
#
#
# 这个软件真不错，很多平时找不到的书一下就找到了，而且整个软件界面精良，看书不累，棒棒的
# 评论对象为：['这个/r/软件/n/'],3
# 评价观点为[('不/d/累/a/', 'a')],2
#
#
# QQ头像换不了，资料改不了，给一星算不错了！
# 评论对象为：[('资料/n/改不了/v/', 'v')],6
# 评价观点为[('星算/n/不错/a/', 'n', 'a')],3
#
#
# 微信怎么不能换主题呢？
# 评论对象为：['主题/n/'],9
# 评价观点为[('不能/v/', 'v')],10
#
#
# 如果有晚上模式就好了
# 评论对象为：['模式/n/'],9
# 评价观点为[('就/d/好/a/', 'a')],2
#
#
# 能不能更新一下，朋友圈发了，还能更改，不用删了重发！QQ空间都有这个功能！
# 评论对象为：['这个/r/功能/n/'],3
# 评价观点为['还/d/能/v/', '都/d/有/v/'],7
#
#
# 是一款不错的视频应用，还有很多视频直播，很喜欢。 直播可以在线互动，界面很清新 原本是不太相信这类软件的
# 评论对象为：[('视频/n/应用/v/', 'v'), ('视频/n/直播/vn/', 'vn'), ('原本/n/是/v/', 'v')],6
# 评价观点为['太/d/相信/v/'],7
#
#
# 我特别欣赏拼多多购物软件，可以和很多朋友一起拼团买水果非常的实惠，以后要网购只来这里了
# 评论对象为：['购物/n/软件/n/'],4
# 评价观点为['特别/d/欣赏/v/', '只/d/来/v/'],7
#
#
# 很好用的一款应用,设计风格不错,界面做的漂亮，非常喜欢，这个应用简直了
# 评论对象为：[('界面/n/做/v/', 'v')],6
# 评价观点为[('风格/n/不错/a/', 'n', 'a')],3
#
#
# 为什么oppoR7Plus录音和视频通话可以，不能发语音了，限权设置也是正常的，软件不支持吗
# 评论对象为：['视频/n/通话/n/'],4
# 评价观点为['也/d/是/v/', '不/d/支持/v/'],7
#
#
# 这个版本公众号视频无法全屏，全屏就是拉伸不会旋转！！！不知道是不是安卓8.0的原因
# 评论对象为：['这个/r/版本/n/公众/n/'],1
# 评价观点为['就是/d/拉伸/v/', '不/d/知道/v/'],7
#
#
# 为什么手机游戏界面上方会显示版本号和手机型号啊？有人知道吗？能关闭吗？强迫症看着真不舒服啊
# 评论对象为：['为什么/r/手机游戏/n/界面/n/'],1
# 评价观点为[('不/d/舒服/a/', 'a')],2
#
#
# 其实大家不用担心为什么改不了名，修改不了资料，其实最近微信QQ都是一样，正在有系统维护升级，大概一个月后左右就可以重新修改了，不用担心，不是手机故障，也不是应用问题。
# 评论对象为：['手机/n/故障/n/'],4
# 评价观点为['都/d/是/v/'],7
#
#
# 版权分立难免很多没有，但是播放体验真的好
# 评论对象为：['版/n/', '体验/n/'],9
# 评价观点为[('真的/d/好/a/', 'a')],2
#
#
# 七猫免费小说是一款非常好用免费阅读小说软件，品种多界面整洁，向大家推荐。
# 评论对象为：['猫/n/免费小说/n/', '小说/n/软件/n/'],4
# 评价观点为[('非常/d/好/a/', 'a')],2
#
#
# 数码产品，儿童用品还有食品都有，价格便宜和大超市一样的质量，拼多多真的不错
# 评论对象为：[('儿童用品/n/还有/v/', 'v'), ('大/n/超市/v/', 'v')],6
# 评价观点为[('真的/d/不错/a/', 'a')],2
#
#
# 很好的阅读器。。每次装机我必装的软件。主要是看书界面很舒服。。很养眼
# 评论对象为：['每次/r/装机/n/'],3
# 评价观点为['必/d/装/v/'],7
#
#
# 18.网上看到介绍HoloLens的视频知道了有信，我很惊讶，国内什么样的公司居然能做科幻片里的全息通讯？试了试你们的电话App，界面好评，拨打铃声好评，用户体验很不错，通话质量也很稳定，看好你们的未来！
# 评论对象为：['用户/n/体验/n/'],4
# 评价观点为[('很/d/惊讶/a/', 'a'), ('很/d/稳定/a/', 'a')],2
#
#
# 交互的界面设计的很个性
# 评论对象为：[('很/a/个性/n/', 'a')],8
# 评价观点为[('很/a/个性/n/', 'a')],4
#
#
# ,你如果能找到比这个更好的翻译软件
# 评论对象为：['软件/n/'],9
# 评价观点为['更好/d/'],8
#
#
# 挺不错的，使用起来很顺手，很流畅，界面设置很简洁，看着舒服，值得推荐
# 评论对象为：[('界面/n/设置/vn/', 'vn')],6
# 评价观点为['顺手/d/'],8
#
#
# 同样一样照片，用安卓手机发朋友圈就被压缩的很厉害，用苹果系统发朋友圈就很清晰。 同样是在微信里面调用相机拍照后发送图片，安卓的出片就是渣，苹果的出片就很好
# 评论对象为：['一样/r/照片/n/'],3
# 评价观点为[('很/a/厉害/a/', 'a', 'a')],1
#
#
# 提示零钱支付不了
# 评论对象为：[('零钱/n/支付/v/', 'v')],6
# 评价观点为[('提示/v/', 'v'), ('支付/v/', 'v'), ('不了/v/', 'v')],10
#
#
# 突然发现小度导航的小度语音模式很好用，很节省时间，
# 评论对象为：['小度/n/语音/n/模式/n/'],2
# 评价观点为['很好/d/'],8
#
#
# 基本没出现定位失败的情况了
# 评论对象为：[('没/v/出现/v/定位/n/', 'v')],5
# 评价观点为[('没/v/', 'v'), ('出现/v/', 'v'), ('失败/v/', 'v')],10
#
#
# 这次的版本界面更好看呢，排版也比之前好很多。
# 评论对象为：['版本/n/界面/n/'],4
# 评价观点为['更好/d/看/v/'],7
#
#
# 很赞的一款新闻客户端，界面制作的非常方便阅读，总体来说五星好评
# 评论对象为：['新闻/n/客户端/n/'],4
# 评价观点为[('非常/d/方便/a/', 'a')],2
#
#
# 为什么没有特别关心，要是有特别关心就好了。同意有的顶??????
# 评论对象为：['关心/n/', '关心/n/', '顶/n/'],9
# 评价观点为[('就/d/好/a/', 'a')],2
#
#
# 红包为啥发不了，好好的整什么银行卡绑定！
# 评论对象为：['红包/n/', '整/n/'],9
# 评价观点为['好好/d/'],8
#
#
# 在拼多多买的9.9特卖商品都到货了，物美价廉，很满意呢
# 评论对象为：['商品/n/'],9
# 评价观点为['都/d/到货/v/'],7
#
#
# 垃圾越来越差头像还不能换网名还不能改
# 评论对象为：[('差/a/头像/n/', 'a')],8
# 评价观点为[('越来越/d/差/a/', 'a')],2
#
#
# 不错，真是免费的，因为好多都是骗人的，写着免费的但还要钱，这里书也挺全的，好多地方没找到的，都在这找到啦，希望你们加油！不知道能不能听书，小界面比较舒服，图书查找很方便，小说分类挺详细的，最重要的是，免费小说现在真的很少了，良心啊。
# 评论对象为：['这里/r/书/n/'],3
# 评价观点为[('挺/d/全/a/', 'a'), ('比较/d/舒服/a/', 'a'), ('挺/d/详细/ad/', 'ad'), ('最/d/重要/a/', 'a')],2
#
#
# 界面不错，有Wifi传书就更好了
# 评论对象为：[('界面/n/不错/a/', 'a')],7
# 评价观点为[('界面/n/不错/a/', 'n', 'a')],3
#
#
# 不是为什么我的手机号没有了，密码是绝对对的就是登不上去，我用手机号短信验证成功了却不是我的微信，官方我就知道怎么回事，这个手机号是我的，微信是别人的怎么回事，我之前微信就是用这个手机号注册的。
# 评论对象为：['这个/r/手机号/n/', '这个/r/手机号/n/'],3
# 评价观点为['就是/d/登不/v/', '就/d/知道/v/'],7
#
#
# 没以前好了，辣鸡，用腾讯王卡看视频明明网络不卡，视频还是卡。比如看电视剧13集卡了，然后再看14集，14集可以缓冲，13集就是卡住，只有把腾讯视频清除数据，然后重新打开才可以看。，辣鸡
# 评论对象为：['网络/n/不卡/n/'],4
# 评价观点为['再/d/看/v/'],7
#
#
# 直播APP真的太好啦 界面整洁优美 懆作也很流畅 最主要是美颜功能敲强大的！
# 评论对象为：[('功能/n/敲/v/', 'v')],6
# 评价观点为[('整洁/a/优美/a/', 'a', 'a')],1
#
#
# 有时候微信视频录不到音
# 评论对象为：['视频/n/', '音/n/'],9
# 评价观点为[('不到/v/', 'v')],10
#
#
# 用着真不错，界面很舒服
# 评论对象为：['界面/n/'],9
# 评价观点为[('舒服/a/', 'a')],9
#
#
# 导航功能强大，我喜欢，但是汤唯语音里面真的太赞了！
# 评论对象为：['语音/n/'],9
# 评价观点为['太/d/赞/v/'],7
#
#
# 很好。在所有的软件里面。最好的一个。 常喜欢这个界面，感觉看起来特别的舒心，太棒了！
# 评论对象为：['这个/r/界面/n/'],3
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 朋友圈视频 只能发十秒
# 评论对象为：['朋友圈/n/视频/n/'],4
# 评价观点为[('只能/v/', 'v'), ('发/v/', 'v')],10
#
#
# 显示有问题头像气泡业务表示挂件都有问题
# 评论对象为：['问题/n/头像/n/气泡/n/'],2
# 评价观点为['都/d/有/v/'],7
#
#
# 非常棒，很方便！但是唯一的建议就是可以增加动画这一功能。
# 评论对象为：['建议/n/', '动画/n/', '功能/n/'],9
# 评价观点为['非常/d/', '就是/d/'],8
#
#
# 注册号的时候说不是最新版我去更新才他妈发现连个更新的标志都没
# 评论对象为：['他/r/妈/n/'],3
# 评价观点为['都/d/没/v/'],7
#
#
# 非常不错的一款读书读书软件，可以找到很多在其他软件上找不到的书，而且还是免费的，要是界面做得更Q一点就更好啦
# 评论对象为：['读书/n/读书/n/软件/n/'],2
# 评价观点为[('非常/d/不错/a/', 'a')],2
#
#
# 这个很棒！值得下载！极力推荐哦 想看的都有，不想看的也有！~~~~
# 评论对象为：[('值得/v/', 'v'), ('下载/v/', 'v'), ('想看/v/', 'v'), ('有/v/', 'v'), ('不想/v/', 'v'), ('看/v/', 'v'), ('有/v/', 'v')],10
# 评价观点为['都/d/有/v/', '也/d/有/v/'],7
#
#
# s看视频直接无语了卡死
# 评论对象为：[('视频/n/直接/ad/', 'ad')],7
# 评价观点为[('视频/n/直接/ad/', 'n', 'ad')],3
#
#
# 微信视频可以有美颜 那就可以吸引更多人用微信 不信可以试试 有了微信视频美颜 现在没有微信视频美颜，所以给了4个星
# 评论对象为：[('没有/v/微信/vn/视频/n/', 'vn')],5
# 评价观点为['就/d/', '更/d/', '不/d/'],8
#
#
# 拒绝点播 拒绝点播
# 评论对象为：[('拒绝/v/', 'v'), ('点播/v/', 'v'), ('拒绝/v/', 'v'), ('点播/v/', 'v')],10
# 评价观点为[('拒绝/v/', 'v'), ('点播/v/', 'v'), ('拒绝/v/', 'v'), ('点播/v/', 'v')],10
#
#
# 虽然腾讯的电视剧挺多，但是广告又臭又长真的不能认，同意的点个赞
# 评论对象为：['电视剧/n/', '广告/n/'],9
# 评价观点为['真的/d/不能/v/'],7
#
#
# 为什么界面没有换？？？？？？？？？？
# 评论对象为：['为什么/r/界面/n/'],3
# 评价观点为[('没有/v/', 'v')],10
#
#
# 真心很实用，没有花哨的界面界面设计的很漂亮，功能很强大，值得推荐！ 力顶
# 评论对象为：['界面/n/界面设计/n/'],4
# 评价观点为['真心/d/'],8
#
#
# 申请一个微信号非常复杂。
# 评论对象为：['微/n/信号/n/'],4
# 评价观点为[('申请/v/', 'v')],10
#
#
# 挺好用的，内容挺多的，知识拍照翻译不给力。
# 评论对象为：['内容/n/', '力/n/'],9
# 评价观点为['挺/d/', '不/d/'],8
#
#
# 不能发超过10S的视频，没有QQ好玩
# 评论对象为：['视频/n/'],9
# 评价观点为[('不能/v/', 'v'), ('发/v/', 'v'), ('超过/v/', 'v'), ('没有/v/', 'v'), ('好玩/v/', 'v')],10
#
#
# 挺好用的百度的境外地图足迹标记真厉害。
# 评论对象为：['地图/n/足迹/n/标记/n/'],2
# 评价观点为[('真/d/厉害/a/', 'a')],2
#
#
# 为什么我的不可以用语音红包
# 评论对象为：['语音/n/红包/n/'],4
# 评价观点为[('不/a/', 'a')],9
#
#
# 更新之后游戏界面都进不去了，闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退，，，
# 评论对象为：['游戏/n/界面/n/'],4
# 评价观点为['都/d/进不去/v/'],7
#
#
# 能不能开放个充值界面
# 评论对象为：['充值/n/界面/n/'],4
# 评价观点为[('能/v/', 'v'), ('不能/v/', 'v'), ('开放/v/', 'v')],10
#
#
# 好用，推荐下载对于喜欢干净的。简单的界面的孩子来说是个不错的选择！
# 评论对象为：['界面/n/', '孩子/n/'],9
# 评价观点为[('好/a/', 'a'), ('干净/a/', 'a'), ('简单/a/', 'a'), ('不错/a/', 'a')],9
#
#
# 腾讯他妈就是个垃圾，想着各种办法挣钱下载完的电影不用VIP 还看不了，真实恶心。省略一万字…………………………………
# 评论对象为：['他/r/妈/n/', '各种/r/办法/n/'],3
# 评价观点为['还/d/看/v/'],7
#
#
# 看视频会闪退，提示加载失败，而且不能转屏
# 评论对象为：[('视频/n/会/v/', 'v')],6
# 评价观点为[('看/v/', 'v'), ('会/v/', 'v'), ('闪退/v/', 'v'), ('提示/v/', 'v'), ('加载/v/', 'v'), ('失败/v/', 'v'), ('不能/v/', 'v')],10
#
#
# 关闭自动接收图片视频功能，希望加上去，一天流量受不了
# 评论对象为：['图片/n/视频/n/功能/n/'],2
# 评价观点为[('关闭/v/', 'v'), ('接收/v/', 'v'), ('希望/v/', 'v'), ('加上/v/', 'v'), ('去/v/', 'v')],10
#
#
# 识别不到人脸，怎么回事？
# 评论对象为：[('识别/v/不到/v/人脸/n/', 'v')],5
# 评价观点为[('识别/v/', 'v'), ('不到/v/', 'v')],10
#
#
# 大众点评很棒，界面美观使用方便，希望更多人知道它并且使用它，我个人觉得同类型的其他软件都不如大众点评。
# 评论对象为：['我/r/个人/n/'],3
# 评价观点为['更/d/', '都/d/'],8
#
#
# 胡乱剪辑
# 评论对象为：['胡乱/n/剪辑/n/'],4
#
#
# 很好 可以放好多格式 就是界面不够美观
# 评论对象为：[('界面/n/不够/v/', 'v')],6
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 界面清晰，新闻及时，体验友好，推送的内容一般都会打开看，很棒的一个客户端，也很有自己的特点，会一直用下去！
# 评论对象为：[('界面/n/清晰/a/', 'a'), ('体验/n/友好/a/', 'a'), ('内容/n/一般/a/', 'a')],7
# 评价观点为[('界面/n/清晰/a/', 'n', 'a'), ('体验/n/友好/a/', 'n', 'a'), ('内容/n/一般/a/', 'n', 'a')],3
#
#
# 昨天试着发了个团购申请，5分钟不到就人齐了，现在东西都收到了，太给力了
# 评论对象为：[('人/n/齐/a/', 'a')],7
# 评价观点为[('人/n/齐/a/', 'n', 'a')],3
#
#
# 说得很好不如用得很好。真心很好！！ 很好好。有多种功能。而且界面好好看不单调 我觉得这个应该会很不错。下来看看
# 评论对象为：[('界面/n/好好看/a/', 'a')],7
# 评价观点为[('很/d/好/a/', 'a'), ('很/d/好/a/', 'a'), ('很/d/好/a/', 'a'), ('很/d/不错/a/', 'a')],2
#
#
# 真的很好好哒，相信我，准没错 版面布局漂亮。有些内容很不错。就是更新有时稍慢。继续加油到五分吗？ 从不写评论。这个值得夸一夸 用着真不错。界面很舒服
# 评论对象为：['有些/r/内容/n/'],3
# 评价观点为[('布局/n/漂亮/a/', 'n', 'a')],3
#
#
# 界面非常简洁很耐看赞
# 评论对象为：['界面/n/'],9
# 评价观点为[('非常/d/简洁/a/', 'a')],2
#
#
# 界面挺清新，不错不错。 好的不能再好。赞赞赞。快下吧！！ 我觉得这个挺不错用的，个人非常喜欢！支持！
# 评论对象为：['界面/n/', '个人/n/'],9
# 评价观点为[('不错/a/不错/a/', 'a', 'a')],1
#
#
# 虽然我用的腾讯大王卡的看腾讯视频但是腾讯视频不论是标清还是高清画质真是垃圾到不能忍。我想所有用腾讯视频看视频的人都会这样子的吧。一直都优化你们视频画质！
# 评论对象为：['你们/r/视频/n/画质/n/'],1
# 评价观点为['都/d/会/v/'],7
#
#
# 希望可以开通直播
# 评论对象为：[('希望/v/', 'v'), ('开通/v/', 'v'), ('直播/vn/', 'vn')],10
# 评价观点为[('希望/v/', 'v'), ('开通/v/', 'v')],10
#
#
# QQ里面的打卡清零是个什么鬼
# 评论对象为：['什么/r/鬼/n/'],3
# 评价观点为[('打卡/v/', 'v'), ('是/v/', 'v')],10
#
#
# 非常好用的软件在手机上就能做表格和文档，很方便
# 评论对象为：[('能/v/做/v/表格/n/', 'v')],5
# 评价观点为['非常/d/好用/v/', '就/d/能/v/'],7
#
#
# 界面挺清新。很不错很不错！ 我不喜欢追剧，只喜欢看完结版小说。每次等人或等车时看小说打发时间。点赞。
# 评论对象为：['版/n/小说/n/'],4
# 评价观点为[('挺/d/清新/a/', 'a')],2
#
#
# 挺不错界面流畅。很有意思！ 给力的软件，继续加油哦，程序猿哥哥们，宝宝看我你们哦
# 评论对象为：[('界面/n/流畅/a/', 'a')],7
# 评价观点为[('界面/n/流畅/a/', 'n', 'a')],3
#
#
# 不带美颜了，以前多好
# 评论对象为：[('带/v/', 'v')],10
# 评价观点为['不/d/带/v/'],7
#
#
# 腊鸡还弄的有些字发不了
# 评论对象为：['有些/r/字/n/'],3
# 评价观点为['还/d/弄/v/'],7
#
#
# 界面清新不华丽，我喜欢
# 评论对象为：[('界面/n/清新/a/', 'a')],7
# 评价观点为[('界面/n/清新/a/', 'n', 'a')],3
#
#
# 不能免费蓝光画质
# 评论对象为：['画质/n/'],9
# 评价观点为[('不能/v/', 'v')],10
#
#
# 连个网名都不让改？
# 评论对象为：['网名/n/'],9
# 评价观点为['都/d/不让/v/'],7
#
#
# 非常不错不错用！！在所有得软件里面！！最不错不错用得一个！！ 功能强大。界面简洁。操作流畅。不错的软件 看不错不错这个APP，一定很牛逼的
# 评论对象为：[('牛/n/逼/v/', 'v')],6
# 评价观点为[('不错/a/不错/a/', 'a', 'a'), ('不错/a/不错/a/', 'a', 'a'), ('不错/a/不错/a/', 'a', 'a')],1
#
#
# 周源，你为何这么贪婪，现在这个版本界面能看吗？乱七八糟的一大堆你简直是侮辱用户的智商，作为一个老用户真想掐死你丫的
# 评论对象为：['这个/r/版本/n/界面/n/'],1
# 评价观点为[('老/a/用户/n/', 'a')],4
#
#
# 一款十分好的直播软件 里面的界面设计风格十分的特别 操作起来也十分的简单 在里面也能看到许多不同有趣的人 十分不错的直播软件
# 评论对象为：['界面设计/n/风格/n/'],4
# 评价观点为[('不同/a/有趣/a/', 'a', 'a')],1
#
#
# 同事推荐的。我用过以后的确不错。阅读界面简单流畅。哈哈
# 评论对象为：[('同事/n/推荐/v/', 'v')],6
# 评价观点为[('简单/a/流畅/a/', 'a', 'a')],1
#
#
# 节目资源丰富，界面简洁，想看央视节目这里都能很方便找到，特适合不看电视的手机党。
# 评论对象为：['节目/n/资源/n/', '手机/n/党/n/'],4
# 评价观点为[('很/d/方便/a/', 'a')],2
#
#
# 垃圾，广告超长 还有就VIP会员也有广告我也醉了
# 评论对象为：[('广告/n/超长/v/', 'v')],6
# 评价观点为['也/d/有/v/', '也/d/醉/v/'],7
#
#
# 希望可以设置星标朋友个性通知铃声
# 评论对象为：['星标/n/朋友/n/个性/n/'],2
# 评价观点为[('希望/v/', 'v'), ('通知/v/', 'v')],10
#
#
# 界面很不错不错。用得很不错。看着也很顺眼！！ 这样得软件我都不知道怎么样才能不给他好好评。很有意思得软件 很喜欢这个软件。觉得这个名字取的非常不错不错！！！！
# 评论对象为：['这个/r/软件/n/', '这个/r/名字/n/'],3
# 评价观点为[('不错/a/不错/a/', 'a', 'a'), ('不错/a/不错/a/', 'a', 'a')],1
#
#
# 一直和朋友在用拼多多 经常在商场拼团 东西齐全 价格便宜 物有所值
# 评论对象为：['商场/n/拼团/n/'],4
# 评价观点为['一直/d/', '经常/d/'],8
#
#
# 没有银行卡不可以改支付密码。
# 评论对象为：[('改/v/支付/v/密码/n/', 'v')],5
# 评价观点为['不/d/'],8
#
#
# 最近版本 股票代码输入那个界面颜色白的不能修改，没有以前的舒服，怎么越做越倒退了啊
# 评论对象为：['那个/r/界面/n/颜色/n/'],1
# 评价观点为[('颜色/n/白/a/', 'n', 'a')],3
#
#
# 很好。都是口口相传得。支持 这款交友软件设计得真心不错，界面清晰，好看，会员多，质量好，才玩没多久就让我遇到了我的白马王子，非常感谢
# 评论对象为：[('界面/n/清晰/a/', 'a'), ('质量/n/好/a/', 'a')],7
# 评价观点为[('很/d/好/a/', 'a'), ('真心/d/不错/a/', 'a')],2
#
#
# 精美的界面，柔和流畅舒服的运行方式，下载的好几款听书软件中唯一留下的一款，其他全部删除。
# 评论对象为：['其他/r/全部/n/'],3
# 评价观点为[('柔和/a/流畅/a/', 'a', 'a')],1
#
#
# 这个比任何地图的拥堵信息都准确，快速准确
# 评论对象为：['任何/r/地图/n/'],3
# 评价观点为[('都/d/准确/a/', 'a'), ('快速/d/准确/a/', 'a')],2
#
#
# 一个字好。两个字很好。三个字非常好！！ 很不错，挺全得，界面也不是很丑啦看着挺清新得 自从下了这个软件！！每天就不错像看一样时不时得就会打开看看！！
# 评论对象为：['这个/r/软件/n/'],3
# 评价观点为[('很/d/好/a/', 'a'), ('非常/d/好/a/', 'a'), ('挺/d/全/a/', 'a'), ('挺/d/清新/a/', 'a'), ('就/d/不错/a/', 'a')],2
#
#
# 超级赞哦！方便又不错不错用！ 超好好用的！！要什么有什么！棒棒哒 挺不错的应用界面流畅，很有意思！
# 评论对象为：[('界面/n/流畅/a/', 'a')],7
# 评价观点为[('不错/a/不错/a/', 'a', 'a')],1
#
#
# 太差 啥玩意 识别不了！！！ 烂
# 评论对象为：['啥/r/玩意/n/'],3
# 评价观点为[('太/d/差/a/', 'a')],2
#
#
# 视频发的太慢了，需要改进改进
# 评论对象为：[('视频/n/发/v/', 'v')],6
# 评价观点为[('太慢/a/', 'a')],9
#
#
# 很好的应用软件。很好的开发者 对于喜欢干净得。简单得界面得孩子来说是个很不错得选择！！ 一直用这个。超不错得
# 评论对象为：['开发者/n/', '界面/n/', '孩子/n/'],9
# 评价观点为[('很/d/不错/a/', 'a')],2
#
#
# 要想知道游戏界面的意思可以去4399看看，有翻译。
# 评论对象为：['游戏/n/界面/n/'],4
# 评价观点为[('要/v/', 'v'), ('想/v/', 'v'), ('知道/v/', 'v'), ('去/v/', 'v'), ('看看/v/', 'v'), ('有/v/', 'v'), ('翻译/v/', 'v')],10
#
#
# 魅族mx6 为什么能进游戏。。一直在初始化那个界面。
# 评论对象为：['那个/r/界面/n/'],3
# 评价观点为['一直/d/'],8
#
#
# 界面设计清爽简洁，适合国人使用习惯。免费书挺多挺好。
# 评论对象为：[('国人/n/使用/v/', 'v')],6
# 评价观点为[('清爽/a/简洁/a/', 'a', 'a')],1
#
#
# QQ头像不能换
# 评论对象为：[('头像/n/不能/v/', 'v')],6
# 评价观点为[('不能/v/', 'v')],10
#
#
# 之前以为和别的没啥区别，用了之后就着迷了，绝对清流，很喜欢界面设计。可以删掉很多别的鸡肋软件了
# 评论对象为：['别的/r/鸡肋/n/软件/n/'],1
# 评价观点为['就/d/着迷/v/'],7
#
#
# 后续会跟进大家的反馈优化界面~
# 评论对象为：[('会/v/跟进/v/大家/n/', 'v'), ('反馈/v/优化/vn/界面/n/', 'vn')],5
# 评价观点为[('后续/v/', 'v'), ('会/v/', 'v'), ('跟进/v/', 'v'), ('反馈/v/', 'v')],10
#
#
# 用起来很好但是我想知道就是B612旁边怎么改变图案
# 评论对象为：['图案/n/'],9
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 最近一段时间，我在使用360手机助手时发现，点击360手机助手后，进入界面时有很长一段时间是黑屏状态，需要删除数据后才能恢复正常，希望尽快解决此问题
# 评论对象为：['手机/n/助手/n/时/n/'],2
# 评价观点为[('很/d/长/a/', 'a')],2
#
#
# 界面整齐，符合用户的操作习惯
# 评论对象为：['界面/n/', '用户/n/', '习惯/n/'],9
# 评价观点为['整齐/d/'],8
#
#
# 贴纸超多，炒鸡卡哇伊??*，大爱
# 评论对象为：['鸡/n/'],9
# 评价观点为[('大/a/', 'a')],9
#
#
# 太好用了，除了开发工具之外全布界面都能覆盖，功能多，实用，必须五星
# 评论对象为：['全布/n/界面/n/'],4
# 评价观点为['太/d/好用/v/', '都/d/能/v/'],7
#
#
# 惨了，！！！朋友圈图片全打不开了！！！
# 评论对象为：['朋友圈/n/图片/n/'],4
# 评价观点为[('图片/n/全/a/', 'n', 'a')],3
#
#
# 为什么不能改写扣扣签名啊
# 评论对象为：[('不能/v/', 'v'), ('改写/v/', 'v'), ('扣扣/v/', 'v'), ('签名/v/', 'v')],10
# 评价观点为[('不能/v/', 'v'), ('改写/v/', 'v'), ('扣扣/v/', 'v'), ('签名/v/', 'v')],10
#
#
# 界面美观，功能完善
# 评论对象为：['界面/n/'],9
#
#
# 不能设置铃声，??跟随系统，怎么分开什么信息，有点差劲，希望改善可以选择自己喜欢的铃声
# 评论对象为：['什么/r/信息/n/'],3
# 评价观点为[('不能/v/', 'v'), ('跟随/v/', 'v'), ('分开/v/', 'v'), ('希望/v/', 'v'), ('改善/v/', 'v'), ('选择/v/', 'v'), ('喜欢/v/', 'v')],10
#
#
# 挺好界面流畅。很有意思！ 独立思考的人，用得上。不同于市面上其他新闻播报
# 评论对象为：['其他/r/新闻/n/'],3
# 评价观点为[('挺/d/好/a/', 'a')],2
#
#
# 可以出双键布局的界面吗？还有按键音太难听了
# 评论对象为：['双键/n/布局/n/', '按键/n/音太/n/'],4
# 评价观点为[('出/v/', 'v'), ('还有/v/', 'v'), ('难听/v/', 'v')],10
#
#
# 一直卡在标志界面
# 评论对象为：['标志/n/界面/n/'],4
# 评价观点为['一直/d/'],8
#
#
# 发一条消息就无响应???找一个表情就无响应???在下输了??
# 评论对象为：['消息/n/', '表情/n/'],9
# 评价观点为['就/d/无/v/', '就/d/无/v/'],7
#
#
# 界面合理的设计才没让眼睛不疲劳
# 评论对象为：[('界面/n/合理/vn/', 'vn')],6
# 评价观点为[('不/d/疲劳/a/', 'a')],2
#
#
# 挺好用的，就是拍照特效不太多
# 评论对象为：[('拍照/v/', 'v')],10
# 评价观点为['就是/d/拍照/v/'],7
#
#
# QQ登录居然提示有盗号风险，密码改了几十次还是提示风险。。。。申诉找回都失败，垃圾玩意！！！！
# 评论对象为：['盗号/n/风险/n/', '垃圾/n/玩意/n/'],4
# 评价观点为['居然/d/提示/v/', '都/d/失败/v/'],7
#
#
# 动不动就vlp，电视剧才看一半
# 评论对象为：['电视剧/n/'],9
# 评价观点为['才/d/看/v/'],7
#
#
# 快乐QQ扩列资格都没有
# 评论对象为：['资格/n/'],9
# 评价观点为['都/d/没有/v/'],7
#
#
# 更新之后，界面更漂亮了
# 评论对象为：['界面/n/'],9
# 评价观点为[('更/d/漂亮/a/', 'a')],2
#
#
# 很方便，只是广告太多，
# 评论对象为：['广告/n/'],9
# 评价观点为['太/d/'],8
#
#
# 播放看电视剧经常卡顿界面太差！央视出品的软件就不能好好做做吗？
# 评论对象为：[('播放/v/看/v/电视剧/n/', 'v')],5
# 评价观点为[('太/d/差/a/', 'a')],2
#
#
# 轻量的内容，简单的界面，比较适合我。希望能一直用下去
# 评论对象为：['轻量/n/', '内容/n/', '界面/n/'],9
# 评价观点为['比较/d/适合/v/'],7
#
#
# 对于喜欢干净的，简单的界面的孩子来说是个不错的选择！.
# 评论对象为：['界面/n/', '孩子/n/'],9
# 评价观点为[('干净/a/', 'a'), ('简单/a/', 'a'), ('不错/a/', 'a')],9
#
#
# 要是可以高清视频聊天就好了。
# 评论对象为：['视频/n/'],9
# 评价观点为[('就/d/好/a/', 'a')],2
#
#
# 刚下载下，冲着这优质欢迎界面，觉得应该很值得信赖，我先使用几天试试看。
# 评论对象为：['这/r/优质/n/'],3
# 评价观点为['刚/d/下载/v/', '先/d/使用/v/'],7
#
#
# 很不错不错很不错不错的，可别特别不错不错， 很不错，有自己得特色 真心很实用。没有花哨的界面
# 评论对象为：['特色/n/', '花哨/n/', '界面/n/'],9
# 评价观点为[('不错/a/不错/a/', 'a', 'a'), ('不错/a/不错/a/', 'a', 'a'), ('不错/a/不错/a/', 'a', 'a')],1
#
#
# 以前都很好用，可是从昨天开始，一发图片就闪退
# 评论对象为：['图片/n/'],9
# 评价观点为['很/d/好用/v/', '就/d/闪退/v/'],7
#
#
# 开了那么多个月的会员到头来连个资料都更改不了
# 评论对象为：['会员/n/', '资料/n/'],9
# 评价观点为['都/d/更改/v/'],7
#
#
# 界面很不错不错，用的很不错，看着也很顺眼。 超级有趣得应用。我挖我挖！！哈哈 很实用，是我用过的最好好软件
# 评论对象为：['界面/n/', '软件/n/'],9
# 评价观点为[('不错/a/不错/a/', 'a', 'a'), ('很/a/不错/a/', 'a', 'a')],1
#
#
# 界面设计太丑，吐槽吐槽吐槽
# 评论对象为：['界面设计/n/太丑/n/'],4
# 评价观点为[('吐/v/', 'v'), ('吐/v/', 'v'), ('吐/v/', 'v')],10
#
#
# 其实大家不用担心为什么改不了名，修改不了资料，其实最近微信QQ都是一样，正在有系统维护升级，大概一个月后左右就可以重新修改了，不用担心，不是手机故障，也不是应用问题。
# 评论对象为：['手机/n/故障/n/'],4
# 评价观点为['都/d/是/v/'],7
#
#
# 扁平化 界面真丑
# 评论对象为：['界面/n/'],9
# 评价观点为[('真/d/丑/a/', 'a')],2
#
#
# 确实很快。倒是界面有点过于单调了呢
# 评论对象为：['界面/n/有点/n/'],4
# 评价观点为['很快/d/'],8
#
#
# 这是我用过最方便的聊天东西，它不仅可以存钱，还可以视频聊天
# 评论对象为：['视频/n/'],9
# 评价观点为[('最/a/方便/a/', 'a', 'a')],1
#
#
# 界面非常优美 太好玩了，一发不可收拾啊。 用过一段时间才来评价的，整体感觉不错，速度还很快
# 评论对象为：['整体/n/感觉/n/'],4
# 评价观点为[('非常/d/优美/a/', 'a')],2
#
#
# 微信改版后，不显示有几天的信息没有阅读，不知读过了吗？很不方便！不如以前
# 评论对象为：[('信息/n/没有/v/', 'v')],6
# 评价观点为[('不/d/方便/a/', 'a')],2
#
#
# 不能改微信号，不能像QQ一样多个账号切换
# 评论对象为：[('不能/v/改微/vn/信号/n/', 'vn')],5
# 评价观点为[('不能/v/', 'v'), ('不能/v/', 'v'), ('像/v/', 'v'), ('切换/v/', 'v')],10
#
#
# 功能越来越完善了。界面设计的很漂亮，功能很强大，值得推荐！ 力顶
# 评论对象为：['功能/n/', '界面设计/n/', '很漂亮/n/', '功能/n/', '力顶/n/'],9
# 评价观点为['越来越/d/完善/v/'],7
#
#
# 界面简洁，懆作起来也很简单，各种类型的美女都有，看的我心花怒放啊，哈哈！！！
# 评论对象为：[('界面/n/简洁/a/', 'a')],7
# 评价观点为[('很/d/简单/a/', 'a')],2
#
#
# 为什么不能直播，以前都可以直播的，还我原先的QQ
# 评论对象为：[('不能/v/', 'v'), ('直播/vn/', 'vn'), ('直播/vn/', 'vn')],10
# 评价观点为['都/d/', '还/d/', '原先/d/'],8
#
#
# 用起来性能越来越不错不错 还算好用，符合我的使用习惯 非常实用界面可以再增加点功能会更好的人啊！！
# 评论对象为：[('功能/n/会/v/', 'v')],6
# 评价观点为[('不错/a/不错/a/', 'a', 'a')],1
#
#
# 有没有车都能用，现在百度不仅仅是行车导航，走路、跑步都可以用，很方便。
# 评论对象为：[('行车/n/导航/v/', 'v')],6
# 评价观点为['都/d/能/v/', '不仅仅/d/是/v/'],7
#
#
# 这个版本给老年人用合适，操作简单，图标大，界面比微信还简洁
# 评论对象为：['这个/r/版本/n/'],3
# 评价观点为[('还/d/简洁/a/', 'a')],2
#
#
# 比起之前用过的其他券商软件，国金证券佣金宝看行情非常便捷，完美，界面分配清晰，指标比较丰富
# 评论对象为：['其他/r/券商/n/软件/n/'],1
# 评价观点为[('非常/d/便捷/a/', 'a'), ('比较/d/丰富/a/', 'a')],2
#
#
# 特别喜欢 有很多表情都很可爱
# 评论对象为：['表情/n/'],9
# 评价观点为['特别/d/喜欢/v/', '很/d/可爱/v/'],7
#
#
# 为啥拍长视频没有声音
# 评论对象为：[('视频/n/没有/v/', 'v')],6
# 评价观点为[('拍长/v/', 'v'), ('没有/v/', 'v')],10
#
#
# 很好看。如果，有更多的特效就行了。
# 评论对象为：[('好看/v/', 'v'), ('有/v/', 'v')],10
# 评价观点为['更/d/'],8
#
#
# 全球交易系统肯定是有问题的。从昨天开始到现在，时好时坏！就卡在“模拟城市”界面好久！
# 评论对象为：['全球/n/交易系统/n/'],4
# 评价观点为['就/d/'],8
#
#
# 导航满意必须支持小度，希望语音识别可以变得更强大，加油
# 评论对象为：[('语音/n/识别/v/', 'v')],6
# 评价观点为[('更/d/强大/a/', 'a')],2
#
#
# qq头像为什么不可以换了？
# 评论对象为：['头像/n/'],9
# 评价观点为['不/d/'],8
#
#
# 导航时规划的路线希望能更多一些，让用户有更多的选择就好了
# 评论对象为：['时/n/规划/n/'],4
# 评价观点为[('就/d/好/a/', 'a')],2
#
#
# 软件里面各种交通工具的路线规划都有，搜什么都可以，太方便了
# 评论对象为：['路线/n/规划/n/'],4
# 评价观点为[('太/d/方便/a/', 'a')],2
#
#
# 很多好看的贴纸都不见了......体验一般......
# 评论对象为：[('体验/n/一般/a/', 'a')],7
# 评价观点为[('体验/n/一般/a/', 'n', 'a')],3
#
#
# 感觉还不错，就是不能关联其他账号
# 评论对象为：['其他/r/账号/n/'],3
# 评价观点为[('还/d/不错/a/', 'a')],2
#
#
# 才发现在拼多多拼团购物有那么多优惠折扣，真的是棒了
# 评论对象为：['拼团/n/购物/n/'],4
# 评价观点为['才/d/发现/v/', '真的/d/是/v/'],7
#
#
# 酷狗繁星新版本很好，界面清晰，给人不一样的感觉，能快速找到自己喜欢的主播，很适合新人使用。当然对于我们繁星老粉丝来说就更好啦。赞赞赞！
# 评论对象为：['我们/r/繁星/n/'],3
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 很好，天气准确，界面简单明了
# 评论对象为：[('天气/n/准确/a/', 'a')],7
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 界面挺清新的，功能也简单，用起来很方便
# 评论对象为：['界面/n/', '功能/n/'],9
# 评价观点为[('挺/d/清新/a/', 'a'), ('也/d/简单/a/', 'a')],2
#
#
# 可以找到自己喜欢的主播，总能看到各种搞笑有趣的直播，完爆了花椒映客之类的 直播可以在线互动，界面很清新 周围的朋友都在用，.
# 评论对象为：[('总能/n/看到/v/', 'v')],6
# 评价观点为['互动/d/', '都/d/'],8
#
#
# 棒棒哒，超级好用，但是如果，文本可以一次性多加一点就行了。所以我推荐picsart，虽然那个软件好，但是没有美图秀秀的字体！ (>^ω^<)
# 评论对象为：['那个/r/软件/n/'],3
# 评价观点为[('软件/n/好/a/', 'n', 'a')],3
#
#
# 终于找一个省心的导航真是不容易，百度算是比较不错的了，语音就可以操作导航，功能很全面。大爱汤唯！
# 评论对象为：[('百度/n/算是/v/', 'v')],6
# 评价观点为[('不/d/容易/a/', 'a'), ('比较/d/不错/a/', 'a')],2
#
#
# 互赞会消失，两人都已经赞过对方了但会在一方那边没显示！！第二天互赞标识就会消失！！
# 评论对象为：['消失/n/', '人/n/', '对方/n/', '标识/n/', '消失/n/'],9
# 评价观点为['互/d/赞会/v/', '已经/d/赞过/v/', '就/d/会/v/'],7
#
#
# 很好！希望有歌词！
# 评论对象为：[('希望/v/有/v/歌词/n/', 'v')],5
# 评价观点为[('很/d/好/a/', 'a')],2
#
#
# 2020.10.29历史性大更，换游戏引擎后，手机发热严重，贴吧说，已经炸了两部手机，画面刺眼，任务界面花里胡俏，总之就是灵魂三连问：你今天手机炸了吗？你今天眼睛瞎了吗？你今天弃坑了吗？
# 评论对象为：['游戏/n/引擎/n/', '任务/n/界面/n/'],4
# 评价观点为[('历史性/n/大/a/', 'n', 'a')],3
#
#
# 微信公众号免流量吗
# 评论对象为：[('公众/n/号免/v/', 'v')],6
# 评价观点为[('号免/v/', 'v')],10
#
#
# 每次出行都能在以前收藏的记录里找到地址直接导航很方便
# 评论对象为：[('地址/n/直接/ad/', 'ad')],7
# 评价观点为[('地址/n/直接/ad/', 'n', 'ad')],3
#
#
# 有没有人和我一样微信漂流瓶扔出去无法收到回复。
# 评论对象为：[('无法/n/收到/v/', 'v')],6
# 评价观点为[('有没有/v/', 'v'), ('扔出去/v/', 'v'), ('收到/v/', 'v'), ('回复/v/', 'v')],10
#
#
# 没见过这么垃圾的软件，这么多广告直接无语
# 评论对象为：['这么/r/垃圾/n/'],3
# 评价观点为[('广告/n/直接/ad/', 'n', 'ad')],3
#
#
# 按自己需求设置快捷功能，更贴合个人使用习惯。感谢百度~
# 评论对象为：[('个人/n/使用/v/', 'v')],6
# 评价观点为[('快捷/a/功能/n/', 'a')],4
#
#
# 为什么我现在更新之后图片一直看不见
# 评论对象为：['图片/n/'],9
# 评价观点为['一直/d/看不见/v/'],7

# %%
comment_seed = load_file('comment_seed.txt')
i=0
for index,comment in enumerate(data['评论']):
    
# 调用match_score函数，计算用户评论与评论种子之间的综合匹配值，并获取最大的综合匹配值和对应的使用反馈类型
    score_dict = match_score(comment)
    max_score = max(score_dict.values())
    max_feedback = max(score_dict, key=score_dict.get)
# 如果最大的综合匹配值大于0.5，则表示用户评论与某个评论种子匹配成功，将该使用反馈类型写入数据表格的label列中
    if max_score > 0.4:
        i=i+1
        print(f"{index+1},{comment}匹配种子成功,值为：{max_score}，{i}")
        print('\n')
# 否则，表示用户评论与所有评论种子匹配失败，调用extract_seed函数，从用户评论中抽取新的评论种子，并将它们加入到候选评论种子库中
    else:
        pass#print(f"{line}匹配种子不成功,值为：{max_score}")
# Out:
# 1,飞卢小说的更新速度相当快，实时更新，是一款相当方便的电子书阅读器。界面构造简约而不简单，非常适合读者，是一款便利的读书软件和看书软件匹配种子成功,值为：0.75，1
#
#
# 3,为什么打不开了？更新完后打开就黑屏！后台根本没问题！软件打不开界面！昨天从新下载能用！今天又打不开了？什么鬼？倒闭了？匹配种子成功,值为：0.5，2
#
#
# 4,一款相当不错的手游软件，界面漂亮，使用方便，值得拥有！匹配种子成功,值为：0.75，3
#
#
# 5,新版本终于不再闪退了，界面优化的也好了很多，于是更想购物了，OMG！匹配种子成功,值为：0.5，4
#
#
# 15,界面简单明快，所以用起来才更加的舒服安逸，用户基数很大，已经找到了好几个发展对象了匹配种子成功,值为：0.75，5
#
#
# 29,好，但界面没有任意页面可选匹配种子成功,值为：0.5，6
#
#
# 31,为什么显示完拇指玩界面就黑屏匹配种子成功,值为：0.5，7
#
#
# 39,好用，就是界面一般。匹配种子成功,值为：0.5，8
#
#
# 44,卡在拇指玩界面怎么破匹配种子成功,值为：0.75，9
#
#
# 45,应用操作简单，界面给力超好用一款非常好用的应用匹配种子成功,值为：0.75，10
#
#
# 46, 挺喜欢的，界面挺精美的，精彩的书需要懂它的人才有价值，所以喜欢看书的人都可以进来看看吧。匹配种子成功,值为：0.75，11
#
#
# 50,界面简洁实用匹配种子成功,值为：0.5，12
#
#
# 62,很不错，好玩，可以用语音匹配种子成功,值为：0.44999999999999996，13
#
#
# 63,拼多多，是个最大的坑！一进界面，各种套路就开始搞你！最讨厌的一款软件！没有之一！！！匹配种子成功,值为：0.5，14
#
#
# 64,界面不错，用起来很方便匹配种子成功,值为：0.5，15
#
#
# 68,对于喜欢干净的，简单的界面的孩子来说是个不错的选择！.匹配种子成功,值为：0.75，16
#
#
# 75,苹果都出6.6可以改微信号了，安卓为啥还不能？快更新可以改号匹配种子成功,值为：0.5，17
#
#
# 81,我喜欢这界面，够简洁，而且内容丰富匹配种子成功,值为：0.5，18
#
#
# 82,刚下载下，冲着这优质欢迎界面，觉得应该很值得信赖，我先使用几天试试看。匹配种子成功,值为：0.5，19
#
#
# 88,垃圾 没了vip下载视频速度特别慢就1两百 在其他软件2000多都上去了匹配种子成功,值为：0.75，20
#
#
# 93,整个界面都很清爽☆喜欢☆匹配种子成功,值为：0.5，21
#
#
# 94,不错的看书软件。界面很舒服。流畅。匹配种子成功,值为：0.5，22
#
#
# 95,很喜欢它的界面，很简洁，给人高大上的感觉！?匹配种子成功,值为：0.5，23
#
#
# 108,这个软件真的很烂。点击忘记密码，结果一直往登录界面跳转。害得我删了重新装。360有意刷下载量就把软件搞成这样，恶心匹配种子成功,值为：0.5，24
#
#
# 111,很不错的播放器，界面简洁，支持文件类型很多。匹配种子成功,值为：0.5，25
#
#
# 125,界面比以前好看很多匹配种子成功,值为：0.5，26
#
#
# 131,小说app界面非常干净有序 可以找到很多想看的小说目录 而且还是 无广告 支持 这么好的app真的是太方便了匹配种子成功,值为：1.0，27
#
#
# 132,界面很舒适，但是消息同步不及时，有时候群里发的信息半天看不到，望改进。匹配种子成功,值为：0.5，28
#
#
# 136,好用好用非常好用，哈哈，终于被我找到这么好用的软件了，软件页面简洁没有广告，界面简单易用一点都不复杂，CCTV手机电视cctv6的电影不少，看电影首选CCTV手机电视匹配种子成功,值为：0.5，29
#
#
# 137,很不错，界面朴实实用，操作简单！！匹配种子成功,值为：0.5，30
#
#
# 147,好东西，界面挺清新，不错不错吧匹配种子成功,值为：0.75，31
#
#
# 149,使用后感觉这个软件真的非常实用吧，界面清晰简洁也很出类拔萃，操作灵活多变。总体收益率也比其他软件高。以前朋友介绍过，不太好用，后来在朋友圈上看见许多人都发这软件的广告才用匹配种子成功,值为：0.75，32
#
#
# 152,杀毒很给力，界面再美观一下。匹配种子成功,值为：0.5，33
#
#
# 154,功能实用！界面简洁！速度很快。挺不错的 书城书城很好。这书城书城棒极了！赞一个 大家放心下载，还不错。 很好，有多种功能，而且界面好看不单调匹配种子成功,值为：0.75，34
#
#
# 158,泰捷视频可以看直播的，您可以在安装完后，在主界面选择“添加应用”，里面有直播软件绑定即可，能看免费的国内外直播频道！匹配种子成功,值为：0.5，35
#
#
# 162,天了噜。是同类应用软件中的王者啊呢 很棒啊呢。速度很快。界面也很个性真挺好得 挺优惠券app好用的，功能都很完善匹配种子成功,值为：0.5，36
#
#
# 164,为什么今天一直卡在这个界面啊匹配种子成功,值为：0.5，37
#
#
# 167,不错不错，体验了各种模式都有很棒，特别是语音识别，开车用这个，太方便啦~匹配种子成功,值为：0.44999999999999996，38
#
#
# 176,界面很不错，书籍也齐全。匹配种子成功,值为：0.5，39
#
#
# 177,uc折腾的已经无爱，刚才看uc评论 一堆托，太失望了 。欧朋的设置界面和塞班那会的版本好像，有点怀念。 好久没用欧朋，下来看看匹配种子成功,值为：0.5，40
#
#
# 180,不错的看书软件。界面很舒服。流畅。匹配种子成功,值为：0.5，41
#
#
# 186,很好啊～界面看着超级舒服！没有那么多花花绿绿的，视觉享受。匹配种子成功,值为：0.5，42
#
#
# 191,最棒的应用，我们店好多服务员都在用吧，约会神器呀，简单的界面的孩子来说是个不错的选择，新版本太棒了匹配种子成功,值为：0.5，43
#
#
# 194,界面挺清新。挺好挺好 给力的app。挺好 在应用强推里下的。感觉还不错 挺的应用app，值得强推给大家！匹配种子成功,值为：0.75，44
#
#
# 195,新版界面很不错，我很喜欢这种感觉，适合！匹配种子成功,值为：0.5，45
#
#
# 196,一直卡在界面上。进不去。怎么办匹配种子成功,值为：0.5，46
#
#
# 197,用着真不错，界面很舒服哦，很好！匹配种子成功,值为：0.5，47
#
#
# 198,支持，章节很清晰非常实用界面可以再增加点功能会更不错得人啊呢！匹配种子成功,值为：0.5，48
#
#
# 202,挺不错，好玩又有趣，简约风的界面我很喜欢。匹配种子成功,值为：0.5，49
#
#
# 204,为什么每次配图的时候，一按插入到说说就返回到登录界面匹配种子成功,值为：0.5，50
#
#
# 209,用了几款直播软件，真心觉得这个软件好用，不卡，界面简洁美观，喜欢，呵呵！匹配种子成功,值为：0.5，51
#
#
# 213,挺很好界面流畅，很有意思！ 更新几次以后，新系统明显比之前的好用多了！匹配种子成功,值为：0.5，52
#
#
# 214,界面清爽，资源丰富！呵呵广泛覆盖挺好的？看小说好多年，很多书都有，为了晚上看的时候可以调夜间模式保护眼睛下的。不错哦感觉免费的。。匹配种子成功,值为：0.5，53
#
#
# 219,我是纵横书界多年的老书虫，对于手机阅读器的要求是很高的。界面设计要好看，网络阅读一定有本地阅读要给力，翻页速度一定要快，所有这些实用的功能都必须要有，咱在看小说的时候才能爽，这款阅读软件完全能满足需求匹配种子成功,值为：0.75，54
#
#
# 220,更新之后，界面更漂亮了匹配种子成功,值为：0.75，55
#
#
# 223,云顶天天赚界面整齐，符合用户的操作习惯匹配种子成功,值为：0.5，56
#
#
# 224,真心很实用，没有花哨的界面匹配种子成功,值为：0.5，57
#
#
# 225,常喜欢这个界面，感觉看起来特别的舒心，太棒了！ 反应速度快，用起来顺手。 非常好得东西。找了好久了匹配种子成功,值为：0.5，58
#
#
# 226,主播数量比较多，类型也多 界面非常优美 现在天天觉得已经离不开这个软件了.匹配种子成功,值为：0.75，59
#
#
# 227,不错一个软件赞一个，阅读器界面做的挺好的。匹配种子成功,值为：0.5，60
#
#
# 229,对于喜欢干净的，简单的界面的孩子来说是个不错的选择！.匹配种子成功,值为：0.75，61
#
#
# 239,界面简单但是功能却非常强大！咨询了客服各个问题.客服都详细给我解答了，点赞匹配种子成功,值为：0.5，62
#
#
# 241,用着真不错，界面很舒服匹配种子成功,值为：0.5，63
#
#
# 248,交友软件性不错设计界面流程合理易懂非常好玩！匹配种子成功,值为：0.75，64
#
#
# 249,新版本居然将vp电竞社区专区界面优化了，看来这次vp电竞全新改版真的蛮给力的，幸好更新了。匹配种子成功,值为：0.5，65
#
#
# 250,看漫画的夜间模式不要用到界面上啊…太暗了…要瞎了…匹配种子成功,值为：0.5，66
#
#
# 260,感觉界面比之前的普通版好，就是更新之后加的背景音乐感觉有点多余匹配种子成功,值为：0.75，67
#
#
# 264,多种语音通话。实在太好了。匹配种子成功,值为：0.44999999999999996，68
#
#
# 267,超喜欢这个图标，内容界面都更新了的，主要是价格比较优惠匹配种子成功,值为：0.5，69
#
#
# 277,最新版本的界面好丑，聊天语音条的秒数这么突兀也不好看匹配种子成功,值为：0.5，70
#
#
# 281,界面简洁实用匹配种子成功,值为：0.5，71
#
#
# 286,只能说，非常不错的，能推荐的 很实用界面可以再增加点功能会更好的人啊！！ 不错，不错，不错，非常不错匹配种子成功,值为：0.5，72
#
#
# 287,这款狼人杀游戏界面清晰，游戏好玩易上手，音效也不错，值得一玩的游戏。匹配种子成功,值为：0.5，73
#
#
# 291,还行，就是不知道为什么发语音的时候会卡，也不是手机配置不行。匹配种子成功,值为：0.44999999999999996，74
#
#
# 298,界面比较简洁，我喜欢占用手机内存少。匹配种子成功,值为：0.75，75
#
#
# 303,功能强大。界面简洁。操作流畅。很不错 身边的朋友都在用直播，平台有很多帅哥漂亮的妹子，大家可以随时随地分享彼此的快乐。匹配种子成功,值为：0.5，76
#
#
# 307,最近在登陆界面老是闪退匹配种子成功,值为：0.5，77
#
#
# 308,不错！更新速度很快。客服也很细心..非常好。试起来特别顺手 挺好好得看书软件看书软件界面流畅，很有意思！ 很好用的看书软件看书软件，很强大 一直都有使用。希望越做越不错不错咯匹配种子成功,值为：0.5，78
#
#
# 312,更新之后，界面更漂亮了匹配种子成功,值为：0.75，79
#
#
# 314,朋友介绍的软件界面挺简单的。匹配种子成功,值为：1.0，80
#
#
# 317,游戏界面和游戏设计是我玩过几种狼人杀里最好的，但是高素质玩家的游戏？你去进阶区看看，不是拿了狼人就离线，就是好人贴脸，经常三狼战群雄，举报了又怎么样？他们有很多号！游戏可玩性大打折扣，自己玩了就知道，鸡肋！！！！！匹配种子成功,值为：0.75，81
#
#
# 320,里面的直播都挺好看的，是一款不错的直播软件！界面也是我喜欢的风格匹配种子成功,值为：0.5，82
#
#
# 323,这个软件真不错，很多平时找不到的书一下就找到了，而且整个软件界面精良，看书不累，棒棒的匹配种子成功,值为：0.5，83
#
#
# 331,为什么oppoR7Plus录音和视频通话可以，不能发语音了，限权设置也是正常的，软件不支持吗匹配种子成功,值为：0.65，84
#
#
# 333,为什么手机游戏界面上方会显示版本号和手机型号啊？有人知道吗？能关闭吗？强迫症看着真不舒服啊匹配种子成功,值为：0.5，85
#
#
# 336,七猫免费小说是一款非常好用免费阅读小说软件，品种多界面整洁，向大家推荐。匹配种子成功,值为：0.5，86
#
#
# 338,很好的阅读器。。每次装机我必装的软件。主要是看书界面很舒服。。很养眼匹配种子成功,值为：0.5，87
#
#
# 345,突然发现小度导航的小度语音模式很好用，很节省时间，匹配种子成功,值为：0.44999999999999996，88
#
#
# 347,这次的版本界面更好看呢，排版也比之前好很多。匹配种子成功,值为：0.5，89
#
#
# 353,不错，真是免费的，因为好多都是骗人的，写着免费的但还要钱，这里书也挺全的，好多地方没找到的，都在这找到啦，希望你们加油！不知道能不能听书，小界面比较舒服，图书查找很方便，小说分类挺详细的，最重要的是，免费小说现在真的很少了，良心啊。匹配种子成功,值为：0.75，90
#
#
# 354,界面不错，有Wifi传书就更好了匹配种子成功,值为：0.5，91
#
#
# 359,用着真不错，界面很舒服匹配种子成功,值为：0.5，92
#
#
# 366,非常不错的一款读书读书软件，可以找到很多在其他软件上找不到的书，而且还是免费的，要是界面做得更Q一点就更好啦匹配种子成功,值为：0.5，93
#
#
# 372,为什么界面没有换？？？？？？？？？？匹配种子成功,值为：0.5，94
#
#
# 379,更新之后游戏界面都进不去了，闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退，，，匹配种子成功,值为：0.5，95
#
#
# 380,能不能开放个充值界面匹配种子成功,值为：0.5，96
#
#
# 381,好用，推荐下载对于喜欢干净的。简单的界面的孩子来说是个不错的选择！匹配种子成功,值为：0.5，97
#
#
# 386,大众点评很棒，界面美观使用方便，希望更多人知道它并且使用它，我个人觉得同类型的其他软件都不如大众点评。匹配种子成功,值为：1.0，98
#
#
# 393,界面非常简洁很耐看赞匹配种子成功,值为：0.75，99
#
#
# 394,界面挺清新，不错不错。 好的不能再好。赞赞赞。快下吧！！ 我觉得这个挺不错用的，个人非常喜欢！支持！匹配种子成功,值为：0.75，100
#
#
# 399,界面挺清新。很不错很不错！ 我不喜欢追剧，只喜欢看完结版小说。每次等人或等车时看小说打发时间。点赞。匹配种子成功,值为：0.75，101
#
#
# 400,挺不错界面流畅。很有意思！ 给力的软件，继续加油哦，程序猿哥哥们，宝宝看我你们哦匹配种子成功,值为：0.5，102
#
#
# 403,界面清新不华丽，我喜欢匹配种子成功,值为：0.5，103
#
#
# 416,最近版本 股票代码输入那个界面颜色白的不能修改，没有以前的舒服，怎么越做越倒退了啊匹配种子成功,值为：0.75，104
#
#
# 418,精美的界面，柔和流畅舒服的运行方式，下载的好几款听书软件中唯一留下的一款，其他全部删除。匹配种子成功,值为：0.75，105
#
#
# 421,超级赞哦！方便又不错不错用！ 超好好用的！！要什么有什么！棒棒哒 挺不错的应用界面流畅，很有意思！匹配种子成功,值为：0.5，106
#
#
# 424,很好的应用软件。很好的开发者 对于喜欢干净得。简单得界面得孩子来说是个很不错得选择！！ 一直用这个。超不错得匹配种子成功,值为：0.5，107
#
#
# 425,要想知道游戏界面的意思可以去4399看看，有翻译。匹配种子成功,值为：0.5，108
#
#
# 430,后续会跟进大家的反馈优化界面~匹配种子成功,值为：0.5，109
#
#
# 432,最近一段时间，我在使用360手机助手时发现，点击360手机助手后，进入界面时有很长一段时间是黑屏状态，需要删除数据后才能恢复正常，希望尽快解决此问题匹配种子成功,值为：0.5，110
#
#
# 433,界面整齐，符合用户的操作习惯匹配种子成功,值为：0.5，111
#
#
# 435,太好用了，除了开发工具之外全布界面都能覆盖，功能多，实用，必须五星匹配种子成功,值为：0.5，112
#
#
# 438,界面美观，功能完善匹配种子成功,值为：0.5，113
#
#
# 440,挺好界面流畅。很有意思！ 独立思考的人，用得上。不同于市面上其他新闻播报匹配种子成功,值为：0.5，114
#
#
# 441,可以出双键布局的界面吗？还有按键音太难听了匹配种子成功,值为：0.5，115
#
#
# 442,一直卡在标志界面匹配种子成功,值为：0.5，116
#
#
# 444,界面合理的设计才没让眼睛不疲劳匹配种子成功,值为：0.5，117
#
#
# 449,更新之后，界面更漂亮了匹配种子成功,值为：0.75，118
#
#
# 451,播放看电视剧经常卡顿界面太差！央视出品的软件就不能好好做做吗？匹配种子成功,值为：0.75，119
#
#
# 452,轻量的内容，简单的界面，比较适合我。希望能一直用下去匹配种子成功,值为：0.75，120
#
#
# 453,对于喜欢干净的，简单的界面的孩子来说是个不错的选择！.匹配种子成功,值为：0.75，121
#
#
# 455,刚下载下，冲着这优质欢迎界面，觉得应该很值得信赖，我先使用几天试试看。匹配种子成功,值为：0.5，122
#
#
# 462,扁平化 界面真丑匹配种子成功,值为：0.75，123
#
#
# 463,确实很快。倒是界面有点过于单调了呢匹配种子成功,值为：0.5，124
#
#
# 465,界面非常优美 太好玩了，一发不可收拾啊。 用过一段时间才来评价的，整体感觉不错，速度还很快匹配种子成功,值为：0.75，125
#
#
# 471,用起来性能越来越不错不错 还算好用，符合我的使用习惯 非常实用界面可以再增加点功能会更好的人啊！！匹配种子成功,值为：0.5，126
#
#
# 473,这个版本给老年人用合适，操作简单，图标大，界面比微信还简洁匹配种子成功,值为：0.5，127
#
#
# 474,比起之前用过的其他券商软件，国金证券佣金宝看行情非常便捷，完美，界面分配清晰，指标比较丰富匹配种子成功,值为：0.75，128
#
#
# 487,很好，天气准确，界面简单明了匹配种子成功,值为：0.5，129
#
#
# 489,可以找到自己喜欢的主播，总能看到各种搞笑有趣的直播，完爆了花椒映客之类的 直播可以在线互动，界面很清新 周围的朋友都在用，.匹配种子成功,值为：0.5，130

# %%
# 定义能愿动词列表
modal_verbs = ['应该', '应当', '须得', '赞','乐意', '愿', '愿意', '希望', '想', '想要', '要', '要想', 
               '希望', '不能', '觉得', '要是', '可能', '乐于', '不如', '给力', '修改', '方便', '懒得', 
               '便于', '有助于', '不能', '易于', '善于', '适于', '宜于']

# %%
# 定义一个函数，用于判断一个句子是否包含能愿动词
def has_modal_verb(sentence):
  # 使用jieba进行分词和词性标注
  words = pseg.cut(sentence)
  # 遍历每个词和词性
  for word, flag in words:
    # 如果词是能愿动词，并且词性是动词，则返回True
    if word in modal_verbs :
      return True
  # 如果没有找到能愿动词，则返回False
  return False

# %%
# 定义一个函数，用于从一组用户评论中抽取包含能愿动词的评论模式
def extract_modal_verb_patterns(comments):
  # 定义一个空列表，用于存储评论模式
  patterns = []
  # 遍历每条用户评论
  for comment in comments:
    # 如果评论包含能愿动词，则将其加入评论模式列表
    if has_modal_verb(comment):
      patterns.append(comment)
  # 返回评论模式列表
  return patterns

# %%
#print(extract_modal_verb_patterns(data['评论']))
print(len(extract_modal_verb_patterns(data['评论'])))
# Out:
# 161

# %%
# 假设已经提取出了软件简介中的特征词列表
feature_words = ['界面', '功能', '速度', '稳定性','导航','地图','微信','支付','阅读','定位','翻译','头像',
                 '登入','铃声','改进','分类']

# %%
# 定义一个函数，用于判断一个句子是否包含特征词
def has_feature_word(sentence):
  # 使用jieba进行分词
  words = jieba.cut(sentence)
  # 遍历每个词
  for word in words:
    # 如果词是特征词，则返回True
    if word in feature_words:
      return True
  # 如果没有找到特征词，则返回False
  return False

# %%
# 定义一个函数，用于计算一个句子的情感值
def get_sentiment(sentence):
  # 使用snownlp进行情感分析
  s = SnowNLP(sentence)
  # 返回情感值，范围是0到1，越接近1表示越积极，越接近0表示越消极
  return s.sentiments

# %%
# 定义一个函数，用于从一组用户评论中抽取包含特征词并根据情感值判断使用反馈类型的评论模式
def extract_feature_word_patterns(comments):
  # 定义一个空列表，用于存储评论模式
  patterns = []
  # 遍历每条用户评论
  for comment in comments:
    # 如果评论包含特征词，则继续处理
    if has_feature_word(comment):
      # 计算评论的情感值
      sentiment = get_sentiment(comment)
      # 如果情感值大于0.5，则认为是正面评论，体现“软件满足的需求”
      if sentiment >0.85 or sentiment<0.15:
          patterns.append(comment)
          # 返回评论模式列表
  return patterns

# %%
#print(extract_feature_word_patterns(data['评论']))
print(len(extract_feature_word_patterns(data['评论'])))
# Out:
# 225

# %%
data
# Out:
#       序号                                                 评论
# 0      1  飞卢小说的更新速度相当快，实时更新，是一款相当方便的电子书阅读器。界面构造简约而不简单，非常...
# 1      2                      很好，有多种功能，而且界面好看不单调用着不错，你值得拥有。
# 2      3  为什么打不开了？更新完后打开就黑屏！后台根本没问题！软件打不开界面！昨天从新下载能用！今天又...
# 3      4                        一款相当不错的手游软件，界面漂亮，使用方便，值得拥有！
# 4      5                 新版本终于不再闪退了，界面优化的也好了很多，于是更想购物了，OMG！
# ..   ...                                                ...
# 495  496                         每次出行都能在以前收藏的记录里找到地址直接导航很方便
# 496  497                            有没有人和我一样微信漂流瓶扔出去无法收到回复。
# 497  498                               没见过这么垃圾的软件，这么多广告直接无语
# 498  499                        按自己需求设置快捷功能，更贴合个人使用习惯。感谢百度~
# 499  500                                  为什么我现在更新之后图片一直看不见
#
# [500 rows x 2 columns]

# %%
#复制一份评论数据，避免直接对原始样本修改
data_copy=data.copy()
data_copy = data_copy.assign(label=0)
data_copy
# Out:
#       序号                                                 评论  label
# 0      1  飞卢小说的更新速度相当快，实时更新，是一款相当方便的电子书阅读器。界面构造简约而不简单，非常...      0
# 1      2                      很好，有多种功能，而且界面好看不单调用着不错，你值得拥有。      0
# 2      3  为什么打不开了？更新完后打开就黑屏！后台根本没问题！软件打不开界面！昨天从新下载能用！今天又...      0
# 3      4                        一款相当不错的手游软件，界面漂亮，使用方便，值得拥有！      0
# 4      5                 新版本终于不再闪退了，界面优化的也好了很多，于是更想购物了，OMG！      0
# ..   ...                                                ...    ...
# 495  496                         每次出行都能在以前收藏的记录里找到地址直接导航很方便      0
# 496  497                            有没有人和我一样微信漂流瓶扔出去无法收到回复。      0
# 497  498                               没见过这么垃圾的软件，这么多广告直接无语      0
# 498  499                        按自己需求设置快捷功能，更贴合个人使用习惯。感谢百度~      0
# 499  500                                  为什么我现在更新之后图片一直看不见      0
#
# [500 rows x 3 columns]

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   序号      500 non-null    int64
#  1   评论      500 non-null    object
#  2   label   500 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 11.8+ KB

# %%
comment_seed = load_file('comment_seed.txt')
i=0
for index,comment in enumerate(data_copy['评论']):
    
# 调用match_score函数，计算用户评论与评论种子之间的综合匹配值，并获取最大的综合匹配值和对应的使用反馈类型
    score_dict = match_score(comment)
    max_score = max(score_dict.values())
    max_feedback = max(score_dict, key=score_dict.get)
# 如果最大的综合匹配值大于0.5，则表示用户评论与某个评论种子匹配成功，将该使用反馈类型写入数据表格的label列中
    if max_score > 0.4:
        i=i+1
        print(f"index为：{index} ,{comment}匹配种子成功, 值为：{max_score}，当前匹配成功共{i}个\n")
        data_copy.loc[index,'label']=1
# 否则，表示用户评论与所有评论种子匹配失败，调用extract_seed函数，从用户评论中抽取新的评论种子，并将它们加入到候选评论种子库中
    else:
        pass#print(f"{line}匹配种子不成功,值为：{max_score}")
# Out:
# index为：0 ,飞卢小说的更新速度相当快，实时更新，是一款相当方便的电子书阅读器。界面构造简约而不简单，非常适合读者，是一款便利的读书软件和看书软件匹配种子成功, 值为：0.75，当前匹配成功共1个
#
# index为：2 ,为什么打不开了？更新完后打开就黑屏！后台根本没问题！软件打不开界面！昨天从新下载能用！今天又打不开了？什么鬼？倒闭了？匹配种子成功, 值为：0.5，当前匹配成功共2个
#
# index为：3 ,一款相当不错的手游软件，界面漂亮，使用方便，值得拥有！匹配种子成功, 值为：0.75，当前匹配成功共3个
#
# index为：4 ,新版本终于不再闪退了，界面优化的也好了很多，于是更想购物了，OMG！匹配种子成功, 值为：0.5，当前匹配成功共4个
#
# index为：14 ,界面简单明快，所以用起来才更加的舒服安逸，用户基数很大，已经找到了好几个发展对象了匹配种子成功, 值为：0.75，当前匹配成功共5个
#
# index为：28 ,好，但界面没有任意页面可选匹配种子成功, 值为：0.5，当前匹配成功共6个
#
# index为：30 ,为什么显示完拇指玩界面就黑屏匹配种子成功, 值为：0.5，当前匹配成功共7个
#
# index为：38 ,好用，就是界面一般。匹配种子成功, 值为：0.5，当前匹配成功共8个
#
# index为：43 ,卡在拇指玩界面怎么破匹配种子成功, 值为：0.75，当前匹配成功共9个
#
# index为：44 ,应用操作简单，界面给力超好用一款非常好用的应用匹配种子成功, 值为：0.75，当前匹配成功共10个
#
# index为：45 , 挺喜欢的，界面挺精美的，精彩的书需要懂它的人才有价值，所以喜欢看书的人都可以进来看看吧。匹配种子成功, 值为：0.75，当前匹配成功共11个
#
# index为：49 ,界面简洁实用匹配种子成功, 值为：0.5，当前匹配成功共12个
#
# index为：61 ,很不错，好玩，可以用语音匹配种子成功, 值为：0.44999999999999996，当前匹配成功共13个
#
# index为：62 ,拼多多，是个最大的坑！一进界面，各种套路就开始搞你！最讨厌的一款软件！没有之一！！！匹配种子成功, 值为：0.5，当前匹配成功共14个
#
# index为：63 ,界面不错，用起来很方便匹配种子成功, 值为：0.5，当前匹配成功共15个
#
# index为：67 ,对于喜欢干净的，简单的界面的孩子来说是个不错的选择！.匹配种子成功, 值为：0.75，当前匹配成功共16个
#
# index为：74 ,苹果都出6.6可以改微信号了，安卓为啥还不能？快更新可以改号匹配种子成功, 值为：0.5，当前匹配成功共17个
#
# index为：80 ,我喜欢这界面，够简洁，而且内容丰富匹配种子成功, 值为：0.5，当前匹配成功共18个
#
# index为：81 ,刚下载下，冲着这优质欢迎界面，觉得应该很值得信赖，我先使用几天试试看。匹配种子成功, 值为：0.5，当前匹配成功共19个
#
# index为：87 ,垃圾 没了vip下载视频速度特别慢就1两百 在其他软件2000多都上去了匹配种子成功, 值为：0.75，当前匹配成功共20个
#
# index为：92 ,整个界面都很清爽☆喜欢☆匹配种子成功, 值为：0.5，当前匹配成功共21个
#
# index为：93 ,不错的看书软件。界面很舒服。流畅。匹配种子成功, 值为：0.5，当前匹配成功共22个
#
# index为：94 ,很喜欢它的界面，很简洁，给人高大上的感觉！?匹配种子成功, 值为：0.5，当前匹配成功共23个
#
# index为：107 ,这个软件真的很烂。点击忘记密码，结果一直往登录界面跳转。害得我删了重新装。360有意刷下载量就把软件搞成这样，恶心匹配种子成功, 值为：0.5，当前匹配成功共24个
#
# index为：110 ,很不错的播放器，界面简洁，支持文件类型很多。匹配种子成功, 值为：0.5，当前匹配成功共25个
#
# index为：124 ,界面比以前好看很多匹配种子成功, 值为：0.5，当前匹配成功共26个
#
# index为：130 ,小说app界面非常干净有序 可以找到很多想看的小说目录 而且还是 无广告 支持 这么好的app真的是太方便了匹配种子成功, 值为：1.0，当前匹配成功共27个
#
# index为：131 ,界面很舒适，但是消息同步不及时，有时候群里发的信息半天看不到，望改进。匹配种子成功, 值为：0.5，当前匹配成功共28个
#
# index为：135 ,好用好用非常好用，哈哈，终于被我找到这么好用的软件了，软件页面简洁没有广告，界面简单易用一点都不复杂，CCTV手机电视cctv6的电影不少，看电影首选CCTV手机电视匹配种子成功, 值为：0.5，当前匹配成功共29个
#
# index为：136 ,很不错，界面朴实实用，操作简单！！匹配种子成功, 值为：0.5，当前匹配成功共30个
#
# index为：146 ,好东西，界面挺清新，不错不错吧匹配种子成功, 值为：0.75，当前匹配成功共31个
#
# index为：148 ,使用后感觉这个软件真的非常实用吧，界面清晰简洁也很出类拔萃，操作灵活多变。总体收益率也比其他软件高。以前朋友介绍过，不太好用，后来在朋友圈上看见许多人都发这软件的广告才用匹配种子成功, 值为：0.75，当前匹配成功共32个
#
# index为：151 ,杀毒很给力，界面再美观一下。匹配种子成功, 值为：0.5，当前匹配成功共33个
#
# index为：153 ,功能实用！界面简洁！速度很快。挺不错的 书城书城很好。这书城书城棒极了！赞一个 大家放心下载，还不错。 很好，有多种功能，而且界面好看不单调匹配种子成功, 值为：0.75，当前匹配成功共34个
#
# index为：157 ,泰捷视频可以看直播的，您可以在安装完后，在主界面选择“添加应用”，里面有直播软件绑定即可，能看免费的国内外直播频道！匹配种子成功, 值为：0.5，当前匹配成功共35个
#
# index为：161 ,天了噜。是同类应用软件中的王者啊呢 很棒啊呢。速度很快。界面也很个性真挺好得 挺优惠券app好用的，功能都很完善匹配种子成功, 值为：0.5，当前匹配成功共36个
#
# index为：163 ,为什么今天一直卡在这个界面啊匹配种子成功, 值为：0.5，当前匹配成功共37个
#
# index为：166 ,不错不错，体验了各种模式都有很棒，特别是语音识别，开车用这个，太方便啦~匹配种子成功, 值为：0.44999999999999996，当前匹配成功共38个
#
# index为：175 ,界面很不错，书籍也齐全。匹配种子成功, 值为：0.5，当前匹配成功共39个
#
# index为：176 ,uc折腾的已经无爱，刚才看uc评论 一堆托，太失望了 。欧朋的设置界面和塞班那会的版本好像，有点怀念。 好久没用欧朋，下来看看匹配种子成功, 值为：0.5，当前匹配成功共40个
#
# index为：179 ,不错的看书软件。界面很舒服。流畅。匹配种子成功, 值为：0.5，当前匹配成功共41个
#
# index为：185 ,很好啊～界面看着超级舒服！没有那么多花花绿绿的，视觉享受。匹配种子成功, 值为：0.5，当前匹配成功共42个
#
# index为：190 ,最棒的应用，我们店好多服务员都在用吧，约会神器呀，简单的界面的孩子来说是个不错的选择，新版本太棒了匹配种子成功, 值为：0.5，当前匹配成功共43个
#
# index为：193 ,界面挺清新。挺好挺好 给力的app。挺好 在应用强推里下的。感觉还不错 挺的应用app，值得强推给大家！匹配种子成功, 值为：0.75，当前匹配成功共44个
#
# index为：194 ,新版界面很不错，我很喜欢这种感觉，适合！匹配种子成功, 值为：0.5，当前匹配成功共45个
#
# index为：195 ,一直卡在界面上。进不去。怎么办匹配种子成功, 值为：0.5，当前匹配成功共46个
#
# index为：196 ,用着真不错，界面很舒服哦，很好！匹配种子成功, 值为：0.5，当前匹配成功共47个
#
# index为：197 ,支持，章节很清晰非常实用界面可以再增加点功能会更不错得人啊呢！匹配种子成功, 值为：0.5，当前匹配成功共48个
#
# index为：201 ,挺不错，好玩又有趣，简约风的界面我很喜欢。匹配种子成功, 值为：0.5，当前匹配成功共49个
#
# index为：203 ,为什么每次配图的时候，一按插入到说说就返回到登录界面匹配种子成功, 值为：0.5，当前匹配成功共50个
#
# index为：208 ,用了几款直播软件，真心觉得这个软件好用，不卡，界面简洁美观，喜欢，呵呵！匹配种子成功, 值为：0.5，当前匹配成功共51个
#
# index为：212 ,挺很好界面流畅，很有意思！ 更新几次以后，新系统明显比之前的好用多了！匹配种子成功, 值为：0.5，当前匹配成功共52个
#
# index为：213 ,界面清爽，资源丰富！呵呵广泛覆盖挺好的？看小说好多年，很多书都有，为了晚上看的时候可以调夜间模式保护眼睛下的。不错哦感觉免费的。。匹配种子成功, 值为：0.5，当前匹配成功共53个
#
# index为：218 ,我是纵横书界多年的老书虫，对于手机阅读器的要求是很高的。界面设计要好看，网络阅读一定有本地阅读要给力，翻页速度一定要快，所有这些实用的功能都必须要有，咱在看小说的时候才能爽，这款阅读软件完全能满足需求匹配种子成功, 值为：0.75，当前匹配成功共54个
#
# index为：219 ,更新之后，界面更漂亮了匹配种子成功, 值为：0.75，当前匹配成功共55个
#
# index为：222 ,云顶天天赚界面整齐，符合用户的操作习惯匹配种子成功, 值为：0.5，当前匹配成功共56个
#
# index为：223 ,真心很实用，没有花哨的界面匹配种子成功, 值为：0.5，当前匹配成功共57个
#
# index为：224 ,常喜欢这个界面，感觉看起来特别的舒心，太棒了！ 反应速度快，用起来顺手。 非常好得东西。找了好久了匹配种子成功, 值为：0.5，当前匹配成功共58个
#
# index为：225 ,主播数量比较多，类型也多 界面非常优美 现在天天觉得已经离不开这个软件了.匹配种子成功, 值为：0.75，当前匹配成功共59个
#
# index为：226 ,不错一个软件赞一个，阅读器界面做的挺好的。匹配种子成功, 值为：0.5，当前匹配成功共60个
#
# index为：228 ,对于喜欢干净的，简单的界面的孩子来说是个不错的选择！.匹配种子成功, 值为：0.75，当前匹配成功共61个
#
# index为：238 ,界面简单但是功能却非常强大！咨询了客服各个问题.客服都详细给我解答了，点赞匹配种子成功, 值为：0.5，当前匹配成功共62个
#
# index为：240 ,用着真不错，界面很舒服匹配种子成功, 值为：0.5，当前匹配成功共63个
#
# index为：247 ,交友软件性不错设计界面流程合理易懂非常好玩！匹配种子成功, 值为：0.75，当前匹配成功共64个
#
# index为：248 ,新版本居然将vp电竞社区专区界面优化了，看来这次vp电竞全新改版真的蛮给力的，幸好更新了。匹配种子成功, 值为：0.5，当前匹配成功共65个
#
# index为：249 ,看漫画的夜间模式不要用到界面上啊…太暗了…要瞎了…匹配种子成功, 值为：0.5，当前匹配成功共66个
#
# index为：259 ,感觉界面比之前的普通版好，就是更新之后加的背景音乐感觉有点多余匹配种子成功, 值为：0.75，当前匹配成功共67个
#
# index为：263 ,多种语音通话。实在太好了。匹配种子成功, 值为：0.44999999999999996，当前匹配成功共68个
#
# index为：266 ,超喜欢这个图标，内容界面都更新了的，主要是价格比较优惠匹配种子成功, 值为：0.5，当前匹配成功共69个
#
# index为：276 ,最新版本的界面好丑，聊天语音条的秒数这么突兀也不好看匹配种子成功, 值为：0.5，当前匹配成功共70个
#
# index为：280 ,界面简洁实用匹配种子成功, 值为：0.5，当前匹配成功共71个
#
# index为：285 ,只能说，非常不错的，能推荐的 很实用界面可以再增加点功能会更好的人啊！！ 不错，不错，不错，非常不错匹配种子成功, 值为：0.5，当前匹配成功共72个
#
# index为：286 ,这款狼人杀游戏界面清晰，游戏好玩易上手，音效也不错，值得一玩的游戏。匹配种子成功, 值为：0.5，当前匹配成功共73个
#
# index为：290 ,还行，就是不知道为什么发语音的时候会卡，也不是手机配置不行。匹配种子成功, 值为：0.44999999999999996，当前匹配成功共74个
#
# index为：297 ,界面比较简洁，我喜欢占用手机内存少。匹配种子成功, 值为：0.75，当前匹配成功共75个
#
# index为：302 ,功能强大。界面简洁。操作流畅。很不错 身边的朋友都在用直播，平台有很多帅哥漂亮的妹子，大家可以随时随地分享彼此的快乐。匹配种子成功, 值为：0.5，当前匹配成功共76个
#
# index为：306 ,最近在登陆界面老是闪退匹配种子成功, 值为：0.5，当前匹配成功共77个
#
# index为：307 ,不错！更新速度很快。客服也很细心..非常好。试起来特别顺手 挺好好得看书软件看书软件界面流畅，很有意思！ 很好用的看书软件看书软件，很强大 一直都有使用。希望越做越不错不错咯匹配种子成功, 值为：0.5，当前匹配成功共78个
#
# index为：311 ,更新之后，界面更漂亮了匹配种子成功, 值为：0.75，当前匹配成功共79个
#
# index为：313 ,朋友介绍的软件界面挺简单的。匹配种子成功, 值为：1.0，当前匹配成功共80个
#
# index为：316 ,游戏界面和游戏设计是我玩过几种狼人杀里最好的，但是高素质玩家的游戏？你去进阶区看看，不是拿了狼人就离线，就是好人贴脸，经常三狼战群雄，举报了又怎么样？他们有很多号！游戏可玩性大打折扣，自己玩了就知道，鸡肋！！！！！匹配种子成功, 值为：0.75，当前匹配成功共81个
#
# index为：319 ,里面的直播都挺好看的，是一款不错的直播软件！界面也是我喜欢的风格匹配种子成功, 值为：0.5，当前匹配成功共82个
#
# index为：322 ,这个软件真不错，很多平时找不到的书一下就找到了，而且整个软件界面精良，看书不累，棒棒的匹配种子成功, 值为：0.5，当前匹配成功共83个
#
# index为：330 ,为什么oppoR7Plus录音和视频通话可以，不能发语音了，限权设置也是正常的，软件不支持吗匹配种子成功, 值为：0.65，当前匹配成功共84个
#
# index为：332 ,为什么手机游戏界面上方会显示版本号和手机型号啊？有人知道吗？能关闭吗？强迫症看着真不舒服啊匹配种子成功, 值为：0.5，当前匹配成功共85个
#
# index为：335 ,七猫免费小说是一款非常好用免费阅读小说软件，品种多界面整洁，向大家推荐。匹配种子成功, 值为：0.5，当前匹配成功共86个
#
# index为：337 ,很好的阅读器。。每次装机我必装的软件。主要是看书界面很舒服。。很养眼匹配种子成功, 值为：0.5，当前匹配成功共87个
#
# index为：344 ,突然发现小度导航的小度语音模式很好用，很节省时间，匹配种子成功, 值为：0.44999999999999996，当前匹配成功共88个
#
# index为：346 ,这次的版本界面更好看呢，排版也比之前好很多。匹配种子成功, 值为：0.5，当前匹配成功共89个
#
# index为：352 ,不错，真是免费的，因为好多都是骗人的，写着免费的但还要钱，这里书也挺全的，好多地方没找到的，都在这找到啦，希望你们加油！不知道能不能听书，小界面比较舒服，图书查找很方便，小说分类挺详细的，最重要的是，免费小说现在真的很少了，良心啊。匹配种子成功, 值为：0.75，当前匹配成功共90个
#
# index为：353 ,界面不错，有Wifi传书就更好了匹配种子成功, 值为：0.5，当前匹配成功共91个
#
# index为：358 ,用着真不错，界面很舒服匹配种子成功, 值为：0.5，当前匹配成功共92个
#
# index为：365 ,非常不错的一款读书读书软件，可以找到很多在其他软件上找不到的书，而且还是免费的，要是界面做得更Q一点就更好啦匹配种子成功, 值为：0.5，当前匹配成功共93个
#
# index为：371 ,为什么界面没有换？？？？？？？？？？匹配种子成功, 值为：0.5，当前匹配成功共94个
#
# index为：378 ,更新之后游戏界面都进不去了，闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退闪退，，，匹配种子成功, 值为：0.5，当前匹配成功共95个
#
# index为：379 ,能不能开放个充值界面匹配种子成功, 值为：0.5，当前匹配成功共96个
#
# index为：380 ,好用，推荐下载对于喜欢干净的。简单的界面的孩子来说是个不错的选择！匹配种子成功, 值为：0.5，当前匹配成功共97个
#
# index为：385 ,大众点评很棒，界面美观使用方便，希望更多人知道它并且使用它，我个人觉得同类型的其他软件都不如大众点评。匹配种子成功, 值为：1.0，当前匹配成功共98个
#
# index为：392 ,界面非常简洁很耐看赞匹配种子成功, 值为：0.75，当前匹配成功共99个
#
# index为：393 ,界面挺清新，不错不错。 好的不能再好。赞赞赞。快下吧！！ 我觉得这个挺不错用的，个人非常喜欢！支持！匹配种子成功, 值为：0.75，当前匹配成功共100个
#
# index为：398 ,界面挺清新。很不错很不错！ 我不喜欢追剧，只喜欢看完结版小说。每次等人或等车时看小说打发时间。点赞。匹配种子成功, 值为：0.75，当前匹配成功共101个
#
# index为：399 ,挺不错界面流畅。很有意思！ 给力的软件，继续加油哦，程序猿哥哥们，宝宝看我你们哦匹配种子成功, 值为：0.5，当前匹配成功共102个
#
# index为：402 ,界面清新不华丽，我喜欢匹配种子成功, 值为：0.5，当前匹配成功共103个
#
# index为：415 ,最近版本 股票代码输入那个界面颜色白的不能修改，没有以前的舒服，怎么越做越倒退了啊匹配种子成功, 值为：0.75，当前匹配成功共104个
#
# index为：417 ,精美的界面，柔和流畅舒服的运行方式，下载的好几款听书软件中唯一留下的一款，其他全部删除。匹配种子成功, 值为：0.75，当前匹配成功共105个
#
# index为：420 ,超级赞哦！方便又不错不错用！ 超好好用的！！要什么有什么！棒棒哒 挺不错的应用界面流畅，很有意思！匹配种子成功, 值为：0.5，当前匹配成功共106个
#
# index为：423 ,很好的应用软件。很好的开发者 对于喜欢干净得。简单得界面得孩子来说是个很不错得选择！！ 一直用这个。超不错得匹配种子成功, 值为：0.5，当前匹配成功共107个
#
# index为：424 ,要想知道游戏界面的意思可以去4399看看，有翻译。匹配种子成功, 值为：0.5，当前匹配成功共108个
#
# index为：429 ,后续会跟进大家的反馈优化界面~匹配种子成功, 值为：0.5，当前匹配成功共109个
#
# index为：431 ,最近一段时间，我在使用360手机助手时发现，点击360手机助手后，进入界面时有很长一段时间是黑屏状态，需要删除数据后才能恢复正常，希望尽快解决此问题匹配种子成功, 值为：0.5，当前匹配成功共110个
#
# index为：432 ,界面整齐，符合用户的操作习惯匹配种子成功, 值为：0.5，当前匹配成功共111个
#
# index为：434 ,太好用了，除了开发工具之外全布界面都能覆盖，功能多，实用，必须五星匹配种子成功, 值为：0.5，当前匹配成功共112个
#
# index为：437 ,界面美观，功能完善匹配种子成功, 值为：0.5，当前匹配成功共113个
#
# index为：439 ,挺好界面流畅。很有意思！ 独立思考的人，用得上。不同于市面上其他新闻播报匹配种子成功, 值为：0.5，当前匹配成功共114个
#
# index为：440 ,可以出双键布局的界面吗？还有按键音太难听了匹配种子成功, 值为：0.5，当前匹配成功共115个
#
# index为：441 ,一直卡在标志界面匹配种子成功, 值为：0.5，当前匹配成功共116个
#
# index为：443 ,界面合理的设计才没让眼睛不疲劳匹配种子成功, 值为：0.5，当前匹配成功共117个
#
# index为：448 ,更新之后，界面更漂亮了匹配种子成功, 值为：0.75，当前匹配成功共118个
#
# index为：450 ,播放看电视剧经常卡顿界面太差！央视出品的软件就不能好好做做吗？匹配种子成功, 值为：0.75，当前匹配成功共119个
#
# index为：451 ,轻量的内容，简单的界面，比较适合我。希望能一直用下去匹配种子成功, 值为：0.75，当前匹配成功共120个
#
# index为：452 ,对于喜欢干净的，简单的界面的孩子来说是个不错的选择！.匹配种子成功, 值为：0.75，当前匹配成功共121个
#
# index为：454 ,刚下载下，冲着这优质欢迎界面，觉得应该很值得信赖，我先使用几天试试看。匹配种子成功, 值为：0.5，当前匹配成功共122个
#
# index为：461 ,扁平化 界面真丑匹配种子成功, 值为：0.75，当前匹配成功共123个
#
# index为：462 ,确实很快。倒是界面有点过于单调了呢匹配种子成功, 值为：0.5，当前匹配成功共124个
#
# index为：464 ,界面非常优美 太好玩了，一发不可收拾啊。 用过一段时间才来评价的，整体感觉不错，速度还很快匹配种子成功, 值为：0.75，当前匹配成功共125个
#
# index为：470 ,用起来性能越来越不错不错 还算好用，符合我的使用习惯 非常实用界面可以再增加点功能会更好的人啊！！匹配种子成功, 值为：0.5，当前匹配成功共126个
#
# index为：472 ,这个版本给老年人用合适，操作简单，图标大，界面比微信还简洁匹配种子成功, 值为：0.5，当前匹配成功共127个
#
# index为：473 ,比起之前用过的其他券商软件，国金证券佣金宝看行情非常便捷，完美，界面分配清晰，指标比较丰富匹配种子成功, 值为：0.75，当前匹配成功共128个
#
# index为：486 ,很好，天气准确，界面简单明了匹配种子成功, 值为：0.5，当前匹配成功共129个
#
# index为：488 ,可以找到自己喜欢的主播，总能看到各种搞笑有趣的直播，完爆了花椒映客之类的 直播可以在线互动，界面很清新 周围的朋友都在用，.匹配种子成功, 值为：0.5，当前匹配成功共130个

# %%
#第一轮匹配种子中已确定130评论为与软件功能相关的评论
data_copy['label'].sum()
data_copy.loc[data_copy['label'] == 0]['评论']
# Out:
# 1               很好，有多种功能，而且界面好看不单调用着不错，你值得拥有。
# 5                                  翻译准确，内容丰富。
# 6                                     好看的贴纸太少
# 7                        一般般吧，可是没银行卡怎么抢红包????
# 8      地图包含了各种交通形式，只是步行用的最多，各种交互和使用习惯了之后都很方便。
#                         ...
# 495                每次出行都能在以前收藏的记录里找到地址直接导航很方便
# 496                   有没有人和我一样微信漂流瓶扔出去无法收到回复。
# 497                      没见过这么垃圾的软件，这么多广告直接无语
# 498               按自己需求设置快捷功能，更贴合个人使用习惯。感谢百度~
# 499                         为什么我现在更新之后图片一直看不见
# Name: 评论, Length: 370, dtype: object

# %%
print(extract_modal_verb_patterns(data_copy.loc[data_copy['label'] == 0]['评论']))
print(len(extract_modal_verb_patterns(data_copy.loc[data_copy['label'] == 0]['评论'])))
# Out:
# ['地图包含了各种交通形式，只是步行用的最多，各种交互和使用习惯了之后都很方便。', '还是喜欢用老版本的，1.85包括以前的版本用得都很顺手，后来出的要么很卡，要么界面不顺手。我觉得还不如不出新的，越出越差。我还是钟爱老的版本啊。坚决不下新版本', '界面看起来很好看舒服好看，就是看界面有种很熟悉的感觉，团队很强大，希望平台越来越好。', '这个很棒赞一个。来啊。 功能实用！界面简洁！速度很快。挺好的 我刚从市场上看到这个，很不错。', '以前可以换昵称，搞得现在昵称都不能换，我本以为QQ号好的可现在垃圾', '修改个头像都换不了，', '好是好了点，就是还有个地方要改进。要是能把话框改成有趣的像QQ那样的气泡就好了，而且还要免费的！', '详尽的公交路线查询乘车很方便，即使换乘也不用担心找不到站台，准确率高，不错加油', '界面很不错。用的很不错。看着也很顺眼！ 我觉得应该有个抓娃娃排行榜，膜拜一下大神.....', '更新后，收付款打不开扫描码，想找客服都不知道在哪找。。。', '不能忍，为什么一定要新手机登陆要旧手机验证，我呸，万一那旧手机坏了呢？里面的钱就拿不出来了啊。你是不是有毛病哦。你有短信验证还不行？你说你到底要怎样啊你一天天的这么作。一点也不考虑感受，提现还收钱。', '现在要银行卡才能用钱，什么鬼啊，垃圾软件', '很实用，很好，我就选它了呵呵，你们也要好样噢，很好真得很好，而且很好好，阅读起来很方便', '为什么不能修改昵称？', '这个软件还是非常赞的，在学习上帮了不少忙，词和句的翻译都特别准确，很赞哦，五颗星好评?', '一直都在使用这款小黑鱼软件，出门旅游可以用他提前预定酒店，使用方便快速简单，很适合各位经常出差的人使用赞', '超级赞哦！方便又不错！ 很方便，qq号直接登陆，很多看电视剧都能找到！~~~~', '昨晚手机被恶意软件侵袭一直在安装软件的信息 在百度上查是怎么回事 它说可能手机有病毒了 后来下载360急救箱 病毒都没了 赞赞赞', '活该好评和差评差不多，真的很无语对这个软件。动不动就闪退。几乎都要VIP！还很卡。追完双世宠妃就删????', '不如高德显示的信息全面了', '以后找不见路怎么办！就用百度地图随时随地查找公交车打滴，方便省事', 'QQ真是太垃圾，不能修改资料，修改完不能保存', '挺不错不错用得。很方便 很好人啦。 界面挺清新。很好很好！！', '小说也挺的我感觉这是我用过最用的读软件了不错，给个赞，明，很方便，而且全部免费，除了有部分小说章节漏掉之外，好吧，功能挺实用的.......', '垃圾，手机恢复出厂，或者清除数据，重新登陆，每次都要短信验证，还要好友验证，我的好友都在忙，我都不想联系他们，都已经有短信了还要用好友验证，真是很困难', '很少主动来评论，但是这个太不错太有用了！推荐大家下载使用～ 很好，有自己的产品特色，打开界面清新大方，可观赏性很强！赞~', '软件现在是真的一点都不会用，我都后悔更新了，我觉得以前的比较好用，想找什么，什么都找的到，现在要找个东西，都要找好久都有可能找不到。', '我就是冲着郭德纲来的，可惜就是在播放视频的时候画面和音频不同步。希望能够快点改进。', '现在不能改网名了，整个人都抑郁了', '软件真得很不错，没想到还有这么不错不错得软件 原来得界面就很不错。改了干嘛？ 现在流行的软甲。赞一个', '很好好得手机必备，太好样了，了还想 广告时间希望缩短 其他都还不错~~~~', '界面简单明了，多年使用，看盘很不错，让你轻松赚钱，确实方便。', '不能VR观看了？？？', '界面很清晰简单，不复杂，操作很也方便呢', '使用特别方便。跟远在他乡的家人，时常可以面对面聊天儿。真的特别实用。', '其他都挺好的，不方便的就是不能微信支付，希望能有个微信支付', '界面挺清新的，功能也简单，用起来很方便', '什么时候可以修改微信号啊？', '给满分是不可能的，这么多年的微信了还只能发10秒的视频，10秒能看到什么？干脆叫动图算了。应该允许发送不超过10分钟的视频。还有就是朋友圈发动态时还必须要发一张图片，不发图片就发不了文字，这是在扯蛋。', '什么滤镜，真的不能忍，好好的把你照成网红，果断差评', '建议拍摄时间长一点。。。其他的我觉得很棒。。。', '挺好的，功能挺全的，除了有的收费，其他挺好的。赞一个！', '简直不能太赞了，书的品种齐全！软件很好，最喜欢爱奇艺阅读app的手势书签功能了，想收就收，很方便界面很漂亮，是我喜欢的风格哦！很方便，可以看到最近小伙伴推荐的好书', '辣鸡微信，创号都还要好友辅助，而且无论怎样辅助都不能创号，辣鸡微信', '不能更改微信号，不能分组！没有QQ使用方便', '界面简单，功能也简单，用起来很方便', '我觉得都更改不了名字有点儿不太好。', '用腾讯会员已经下载到手机的视频，在腾讯会员过期后不能看？what？没见过这么坑的软件！！！', '为啥不能改资料，也没有提示i什么楼逼东西', '不能换头像', '简洁，不错用，挺喜欢的 从内容的广度和深度来看。背后开发的团队绝对付出了很大的血本和努力啦。希望这款软件会越来越很好。我会一如既往的支持你们的！！ 界面设计的很华丽，功能非常强大，个人觉得很棒！', '界面挺清新的，功能也简单，用起来很方便', '我是一个强迫症，最不能忍的就是兴趣部落里官方推荐的那些东西，每次打开都有红点，然后就看见恶心的兴趣部落有我最恶心的官方推送！！！！！移除这个板块还移除不了', '我就想知道 维修时间都过了 怎么头像依然换不了 我都下载卸载n遍了', '不错不错东西呀！！界面简单方便我喜欢得调调 书类种类齐全，追书神器，很不错的看书软件。', '希望增加扫描翻译短文或者可以翻译短文的功能。', '这个应用软件确实很好用。感觉很得满意。希望大家都喜欢！！ 我觉得挺有意思的。你们觉得呢 挺好好得应用软件界面流畅。很有意思！！', '从三年级就开始玩QQ，现在高二，我觉得真的挺好使，除了不能手机支付', '用过了才感觉不错的。 界面清爽。功能也很好！！很好！！ 不错不错用，方便', '也还行吧。就是有很多动漫不能看。继续努力', '不如其他视频软件，虽说大王卡免流量了，可是能免费看的没几个，而且更新不及时，没有新片，果断卸载', '大家都用的到的拼团电商，很实惠而且方便，嘴馋的时候随时下单还有不菲的优惠力度', '各种热门的网文都有并且全本免费小说,里面有别的软件搜不到的小说,为开发人员点32个赞~,太棒了,界面干净、书架版块分的很清晰。', '能不能在别人删了我的时候 在我的通讯录里也消失。。。。。', '还不错，值得推荐的软件！界面设计很贴心。挺好的应用，软件界面挺好看的，今天刚下的，感觉非常不错，用上挺顺手的，赞！第一次评价，分类很多，而且内容新颖，这下不发愁晚上睡觉没事干了！加油给力', '这个软件很不错不错用非常不错不错！！ 一直用这个来着，感觉非常很好 界面设计得很华丽，功能很强大，个人觉得很棒，我喜欢。', '小度查找充电桩好方便，小度是最胖的！！！！哈哈', '在软件推荐里下得，感觉还很不错 从内容得广度和深度来看，希望这款软件会越来越好，我会一如既往得支持你们得。 界面简洁美观，智能分类很强大，占用内存小，很好一', 'POI指引粹别方向可以更容易使用，骑车也可能有，方便不得了', '信息太多不能像QQ一样删，要一个一个删除太麻烦', '辣鸡应用不能忍！头一回打差评 简直不要太过分 恢复出厂设置再登录居然要扫描二维码后才能用！我特么上哪借手机去！去你大爷的微信！不玩了！', '开了会员，却不能同时缓存三个视频，唉，有点失望', '干嘛要银行卡登录啊！我都没有银行卡，要我怎么用啊！给差评', '手机要会员所以我开通了但是电视上还他妈要超级会员怎么想的', '软件很好。这软件棒极了！赞一个 用着真很好，界面很舒服 不错不错是不错不错。就是装了之后每天刷不错不错几遍', '改个资料都不能改，现在。', '自己做主播很不错，感觉得到了关注 相比较而言，感觉比歪歪之类的好用. 直播可以在线互动，界面很清新，功能强大，大赞哦', '朋友推荐的！用了之后！没想到效果不错！强力推荐 我觉得电影方面并不是很全！我不是说影院！是老片方面！很少！大多要转借其他的平台！~~~~', 'POP民认为挺方便的，不知道是谁弄出来的，不错！这是一款非常值得推荐的软件，非常方便你交到朋友，而且内容界面很丰富明了，里面有很多人在玩，值得推荐说实话，表里不一，呵呵呵，给五星真的是昧着良心交友很真', '非常赞的团购平台，在这里可以买到物美价廉的东西，里面物品非常丰富，经常和朋友一起拼团，想要团购，就来拼多多吧', '手机号注册第二个微信之后，第一个微信不记得密码了那么要怎样才可以找回第一个微信，第一个微信没绑定QQ邮箱', '能不能设置一个好友推荐的开关。', '要是能有留言功能就好了', '更新后文字和图片不能一起发送', '头像不能更换玩', '界面设计得很华丽，功能很强大，个人觉得很棒！ 好软件', '美图一直是我想删不想删的软件，直到刚刚发现一个神奇的功能，可以消除图片上一些文字贴', '同学推荐的！用了之后！没想到效果不错！强力推荐 很好用，一直在用，挺方便的~~~~', '微信怎么不能换主题呢？', '能不能更新一下，朋友圈发了，还能更改，不用删了重发！QQ空间都有这个功能！', '我特别欣赏拼多多购物软件，可以和很多朋友一起拼团买水果非常的实惠，以后要网购只来这里了', '其实大家不用担心为什 ...
# 131

# %%
#data_copy[data_copy['评论'].apply(has_modal_verb)]
data_copy[data_copy['label'] == 0][data_copy['评论'].apply(has_modal_verb)]
# Out:
# C:\Users\28294\AppData\Local\Temp\ipykernel_6768\2974382110.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_copy[data_copy['label'] == 0][data_copy['评论'].apply(has_modal_verb)]
#       序号                                                 评论  label  Unnamed: 2
# 8      9             地图包含了各种交通形式，只是步行用的最多，各种交互和使用习惯了之后都很方便。      0         NaN
# 10    11  还是喜欢用老版本的，1.85包括以前的版本用得都很顺手，后来出的要么很卡，要么界面不顺手。我...      0         NaN
# 15    16         界面看起来很好看舒服好看，就是看界面有种很熟悉的感觉，团队很强大，希望平台越来越好。      0         NaN
# 19    20     这个很棒赞一个。来啊。 功能实用！界面简洁！速度很快。挺好的 我刚从市场上看到这个，很不错。      0         NaN
# 23    24                  以前可以换昵称，搞得现在昵称都不能换，我本以为QQ号好的可现在垃圾      0         NaN
# ..   ...                                                ...    ...         ...
# 483  484                                   感觉还不错，就是不能关联其他账号      0         NaN
# 485  486  酷狗繁星新版本很好，界面清晰，给人不一样的感觉，能快速找到自己喜欢的主播，很适合新人使用。当...      0         NaN
# 487  488                                界面挺清新的，功能也简单，用起来很方便      0         NaN
# 492  493                                          很好！希望有歌词！      0         NaN
# 495  496                         每次出行都能在以前收藏的记录里找到地址直接导航很方便      0         NaN
#
# [131 rows x 4 columns]

# %%
idx=data_copy[data_copy['label'] == 0][data_copy['评论'].apply(has_modal_verb)].index
# Out:
# C:\Users\28294\AppData\Local\Temp\ipykernel_6768\3608715103.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   idx=data_copy[data_copy['label'] == 0][data_copy['评论'].apply(has_modal_verb)].index

# %%
data_copy.loc[idx, 'label'] = 2#label记为2，说明进入候选库

# %%
data_copy
# Out:
#       序号                                                 评论  label  Unnamed: 2
# 0      1  飞卢小说的更新速度相当快，实时更新，是一款相当方便的电子书阅读器。界面构造简约而不简单，非常...      1         1.0
# 1      2                      很好，有多种功能，而且界面好看不单调用着不错，你值得拥有。      0         NaN
# 2      3  为什么打不开了？更新完后打开就黑屏！后台根本没问题！软件打不开界面！昨天从新下载能用！今天又...      1         1.0
# 3      4                        一款相当不错的手游软件，界面漂亮，使用方便，值得拥有！      1         1.0
# 4      5                 新版本终于不再闪退了，界面优化的也好了很多，于是更想购物了，OMG！      1         1.0
# ..   ...                                                ...    ...         ...
# 495  496                         每次出行都能在以前收藏的记录里找到地址直接导航很方便      2         NaN
# 496  497                            有没有人和我一样微信漂流瓶扔出去无法收到回复。      0         NaN
# 497  498                               没见过这么垃圾的软件，这么多广告直接无语      0         NaN
# 498  499                        按自己需求设置快捷功能，更贴合个人使用习惯。感谢百度~      0         NaN
# 499  500                                  为什么我现在更新之后图片一直看不见      0         NaN
#
# [500 rows x 4 columns]

# %%
def extract_feature_word_patterns(df): 
    df1 = df[df['label'] == 0]
    df2 = df1[df1['评论'].apply(has_feature_word)] #100
    return df2                  
extract_feature_word_patterns(data_copy)
# Out:
#       序号                                                 评论  label  Unnamed: 2
# 1      2                      很好，有多种功能，而且界面好看不单调用着不错，你值得拥有。      0         NaN
# 5      6                                         翻译准确，内容丰富。      0         NaN
# 9     10  非常不错不错的东西，找了不错不错久了 支持支持！！很好 功能实用！！界面简洁！！速度很快。挺很好得      0         NaN
# 13    14              发现有两个毛病，一个是别人把头像改了别人看不出来，还有一个是发签名出现错误      0         NaN
# 31    32                            很不错，兼容格式多，界面朴实实用，操作简单！！      0         NaN
# ..   ...                                                ...    ...         ...
# 490  491   终于找一个省心的导航真是不容易，百度算是比较不错的了，语音就可以操作导航，功能很全面。大爱汤唯！      0         NaN
# 493  494  2020.10.29历史性大更，换游戏引擎后，手机发热严重，贴吧说，已经炸了两部手机，画面刺...      0         NaN
# 494  495                                          微信公众号免流量吗      0         NaN
# 496  497                            有没有人和我一样微信漂流瓶扔出去无法收到回复。      0         NaN
# 498  499                        按自己需求设置快捷功能，更贴合个人使用习惯。感谢百度~      0         NaN
#
# [100 rows x 4 columns]

# %%
def get_sentiment(df):
    sentiment = df['评论'].apply(lambda x: SnowNLP(x).sentiments)
    df = df[(sentiment > 0.7) | (sentiment < 0.3)]
    return df
get_sentiment(extract_feature_word_patterns(data_copy))
# Out:
#       序号                                                 评论  label  Unnamed: 2
# 1      2                      很好，有多种功能，而且界面好看不单调用着不错，你值得拥有。      0         NaN
# 5      6                                         翻译准确，内容丰富。      0         NaN
# 9     10  非常不错不错的东西，找了不错不错久了 支持支持！！很好 功能实用！！界面简洁！！速度很快。挺很好得      0         NaN
# 13    14              发现有两个毛病，一个是别人把头像改了别人看不出来，还有一个是发签名出现错误      0         NaN
# 31    32                            很不错，兼容格式多，界面朴实实用，操作简单！！      0         NaN
# ..   ...                                                ...    ...         ...
# 479  480                                      qq头像为什么不可以换了？      0         NaN
# 490  491   终于找一个省心的导航真是不容易，百度算是比较不错的了，语音就可以操作导航，功能很全面。大爱汤唯！      0         NaN
# 493  494  2020.10.29历史性大更，换游戏引擎后，手机发热严重，贴吧说，已经炸了两部手机，画面刺...      0         NaN
# 494  495                                          微信公众号免流量吗      0         NaN
# 496  497                            有没有人和我一样微信漂流瓶扔出去无法收到回复。      0         NaN
#
# [92 rows x 4 columns]

# %%
data_copy.loc[get_sentiment(extract_feature_word_patterns(data_copy)).index, 'label'] = 2#label记为2，说明进入候选库

# %%
data_copy
# Out:
#       序号                                                 评论  label  Unnamed: 2
# 0      1  飞卢小说的更新速度相当快，实时更新，是一款相当方便的电子书阅读器。界面构造简约而不简单，非常...      1         1.0
# 1      2                      很好，有多种功能，而且界面好看不单调用着不错，你值得拥有。      2         NaN
# 2      3  为什么打不开了？更新完后打开就黑屏！后台根本没问题！软件打不开界面！昨天从新下载能用！今天又...      1         1.0
# 3      4                        一款相当不错的手游软件，界面漂亮，使用方便，值得拥有！      1         1.0
# 4      5                 新版本终于不再闪退了，界面优化的也好了很多，于是更想购物了，OMG！      1         1.0
# ..   ...                                                ...    ...         ...
# 495  496                         每次出行都能在以前收藏的记录里找到地址直接导航很方便      2         NaN
# 496  497                            有没有人和我一样微信漂流瓶扔出去无法收到回复。      2         NaN
# 497  498                               没见过这么垃圾的软件，这么多广告直接无语      0         NaN
# 498  499                        按自己需求设置快捷功能，更贴合个人使用习惯。感谢百度~      0         NaN
# 499  500                                  为什么我现在更新之后图片一直看不见      0         NaN
#
# [500 rows x 4 columns]

# %%
import Levenshtein
str1 = "不能忍，为什么一定要新手机登陆要旧手机验证，我呸，万一那旧手机坏了呢？里面的钱就拿不出来了啊...	"
str2 = "昨晚手机被恶意软件侵袭一直在安装软件的信息 在百度上查是怎么回事 它说可能手机有病毒了 后来...	"
distance = Levenshtein.distance(str1, str2) # distance是编辑距离，为3
ratio = Levenshtein.ratio(str1, str2) # ratio是莱文斯坦比，为0.5714285714285714
print(distance, ratio)
# Out:
# 46 0.21999999999999997

# %%
from difflib import SequenceMatcher
import Levenshtein

#获取文本差异最大的Top 3行
def find_top3_diff(df):
    df1 = df[df['label']==2]
    distances = []
    for i in range(len(df1['评论'])):
        for j in range(i+1, len(df1['评论'])):
            t1 = df1['评论'].iloc[i] 
            t2 = df1['评论'].iloc[j]
            distance = Levenshtein.distance(t1, t2)
            distances.append((i, j, distance))
    top3 = sorted(distances, key=lambda x: x[2], reverse=True)[:3]  

    # 取行索引
    rows = [x[0] for x in top3]
    return df1.iloc[rows]


find_top3_diff(data_copy)
# Out:
#       序号       评论  label  Unnamed: 2
# 118  119    翻译都很棒      2         NaN
# 120  121   嗯，翻译精准      2         NaN
# 162  163  为何没法换头像      2         NaN

# %%
for comment in find_top3_diff(data_copy)['评论']:
    print(comment)
    extract_obj_opinion(comment)
    print('\n')
# Out:
# 翻译都很棒
# 评论对象为：[('翻译/v/', 'v')],10
# 评价观点为[('都/d/很棒/a/', 'a')],2
#
#
# 嗯，翻译精准
# 评论对象为：['精准/n/'],9
# 评价观点为[('翻译/v/', 'v')],10
#
#
# 为何没法换头像
# 评论对象为：['头像/n/'],9
# 评价观点为[('没法/v/', 'v')],10

# %%
#制作新的评论种子共三个，名字：new.txt

# %%
comment_seed = load_file('new.txt')
i=0
for index,comment in enumerate(data_copy.loc[data_copy['label'] != 1, '评论']):
    
# 调用match_score函数，计算用户评论与评论种子之间的综合匹配值，并获取最大的综合匹配值和对应的使用反馈类型
    score_dict = match_score(comment)
    max_score = max(score_dict.values())
    max_feedback = max(score_dict, key=score_dict.get)
# 如果最大的综合匹配值大于0.5，则表示用户评论与某个评论种子匹配成功，将该使用反馈类型写入数据表格的label列中
    if max_score > 0.4:
        i=i+1
        print(f"index为：{index} ,{comment}匹配种子成功, 值为：{max_score}，当前匹配成功共{i}个\n")
        data_copy.loc[index,'label']=1
# 否则，表示用户评论与所有评论种子匹配失败，调用extract_seed函数，从用户评论中抽取新的评论种子，并将它们加入到候选评论种子库中
    else:
        pass#print(f"{line}匹配种子不成功,值为：{max_score}")
# Out:
# index为：19 ,修改个头像都换不了，匹配种子成功, 值为：0.8500000000000001，当前匹配成功共1个
#
# index为：126 ,为何没法换头像匹配种子成功, 值为：0.7，当前匹配成功共2个
#
# index为：145 ,不能换头像匹配种子成功, 值为：0.55，当前匹配成功共3个
#
# index为：219 ,为什么现在没法改名字，没法改头像？匹配种子成功, 值为：1.05，当前匹配成功共4个
#
# index为：231 ,头像不能更换玩匹配种子成功, 值为：0.5，当前匹配成功共5个
#
# index为：240 ,QQ头像换不了，资料改不了，给一星算不错了！匹配种子成功, 值为：0.5，当前匹配成功共6个
#
# index为：262 ,垃圾越来越差头像还不能换网名还不能改匹配种子成功, 值为：0.5，当前匹配成功共7个
#
# index为：270 ,显示有问题头像气泡业务表示挂件都有问题匹配种子成功, 值为：0.55，当前匹配成功共8个
#
# index为：319 ,QQ头像不能换匹配种子成功, 值为：0.5，当前匹配成功共9个
#
# index为：351 ,qq头像为什么不可以换了？匹配种子成功, 值为：0.55，当前匹配成功共10个

# %%
data_copy
# Out:
#       序号                                                 评论  label  Unnamed: 2
# 0      1  飞卢小说的更新速度相当快，实时更新，是一款相当方便的电子书阅读器。界面构造简约而不简单，非常...      1         1.0
# 1      2                      很好，有多种功能，而且界面好看不单调用着不错，你值得拥有。      2         NaN
# 2      3  为什么打不开了？更新完后打开就黑屏！后台根本没问题！软件打不开界面！昨天从新下载能用！今天又...      1         1.0
# 3      4                        一款相当不错的手游软件，界面漂亮，使用方便，值得拥有！      1         1.0
# 4      5                 新版本终于不再闪退了，界面优化的也好了很多，于是更想购物了，OMG！      1         1.0
# ..   ...                                                ...    ...         ...
# 495  496                         每次出行都能在以前收藏的记录里找到地址直接导航很方便      2         NaN
# 496  497                            有没有人和我一样微信漂流瓶扔出去无法收到回复。      2         NaN
# 497  498                               没见过这么垃圾的软件，这么多广告直接无语      0         NaN
# 498  499                        按自己需求设置快捷功能，更贴合个人使用习惯。感谢百度~      0         NaN
# 499  500                                  为什么我现在更新之后图片一直看不见      0         NaN
#
# [500 rows x 4 columns]

# %%
data_copy['label'] == 1
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: label, Length: 500, dtype: bool
